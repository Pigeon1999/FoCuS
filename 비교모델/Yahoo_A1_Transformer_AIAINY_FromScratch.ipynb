# %% [markdown]
# # Yahoo A1 · **Attention Is All You Need (from scratch)** · Encoder–Decoder · Supervised (Binary)
#
# - **Model**: Hand-rolled **Transformer (Vaswani et al., 2017)** — Multi-Head Attention, FFN, Add&Norm, sinusoidal PE
# - **Data**: `./yahoo/A1Benchmark/real_*.csv` (univariate), RobustScaler (train-only), sliding window `[t−L..t−1] → y_t`
# - **Head**: Decoder consumes a single **BOS** token and outputs one **logit** for `y_t`
# - **Metrics**: Precision / Recall / F1 / Accuracy; **threshold chosen on validation (best F1)** and applied to test

# %% [markdown]
# ## 0) Requirements
# ```
# pip install torch numpy pandas scikit-learn
# ```

# %%
# 1) Configuration
from dataclasses import dataclass

@dataclass
class Config:
    a1_dir: str = "./yahoo/A1Benchmark"
    seq_len: int = 100
    # AIAINY Transformer hyperparams
    d_model: int = 64
    n_heads: int = 4
    n_enc_layers: int = 2
    n_dec_layers: int = 2
    dim_ff: int = 128
    dropout: float = 0.1
    # Training
    lr: float = 1e-3
    batch: int = 256
    epochs: int = 1000
    patience: int = 15
    device: str = "cuda"  # "cuda" or "cpu"
    # RobustScaler params
    robust_q_low: float = 25.0
    robust_q_high: float = 75.0
    robust_with_centering: bool = True
    robust_with_scaling: bool = True

cfg = Config()
cfg
# Out:
# Config(a1_dir='./yahoo/A1Benchmark', seq_len=100, d_model=64, n_heads=4, n_enc_layers=2, n_dec_layers=2, dim_ff=128, dropout=0.1, lr=0.001, batch=256, epochs=1000, patience=15, device='cuda', robust_q_low=25.0, robust_q_high=75.0, robust_with_centering=True, robust_with_scaling=True)

# %%
# 2) Imports
import os, glob, json
import numpy as np
import random
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch: 2.5.1+cu124
# CUDA available: True

# %% [markdown]
# ## 3) Data utilities (RobustScaler + Sliding Window)

# %%
def _find_cols(df: pd.DataFrame):
    ts_candidates = {"timestamp", "time", "ts", "date"}
    val_candidates = {"value", "values", "metric"}
    lab_candidates = {"is_anomaly", "anomaly", "label", "isoutlier"}
    ts_col = next((c for c in df.columns if str(c).lower() in ts_candidates), None)
    val_col = next((c for c in df.columns if str(c).lower() in val_candidates), None)
    lab_col = next((c for c in df.columns if str(c).lower() in lab_candidates), None)
    if val_col is None or lab_col is None:
        raise ValueError(f"Required columns not found in CSV. Columns: {df.columns.tolist()}")
    return ts_col, val_col, lab_col

def load_yahoo_a1(csv_path: str):
    df = pd.read_csv(csv_path)
    ts_col, val_col, lab_col = _find_cols(df)
    if ts_col is not None:
        df = df.sort_values(ts_col)
    x = df[val_col].to_numpy(dtype=np.float32)
    y = df[lab_col].astype(int).to_numpy()
    return x, y

def fit_robust_scaler(x_train: np.ndarray, cfg):
    rs = RobustScaler(
        with_centering=cfg.robust_with_centering,
        with_scaling=cfg.robust_with_scaling,
        quantile_range=(cfg.robust_q_low, cfg.robust_q_high)
    )
    rs.fit(x_train.reshape(-1, 1))
    return rs

def apply_scaler(x: np.ndarray, scaler: RobustScaler):
    return scaler.transform(x.reshape(-1, 1)).astype(np.float32).squeeze(-1)

def make_windows(x: np.ndarray, y: np.ndarray, L: int):
    Xs, Ys, idx = [], [], []
    for t in range(L, len(x)):
        Xs.append(x[t - L:t])
        Ys.append(y[t])
        idx.append(t)
    X = np.asarray(Xs, dtype=np.float32)[..., None]  # [N, L, 1]
    Y = np.asarray(Ys, dtype=np.int64)               # [N]
    return X, Y, np.asarray(idx)

class WindowDataset(Dataset):
    def __init__(self, X: np.ndarray, Y: np.ndarray):
        self.X = torch.from_numpy(X)       # [N, L, 1]
        self.Y = torch.from_numpy(Y)       # [N]
    def __len__(self): return self.X.shape[0]
    def __getitem__(self, i):
        return self.X[i], self.Y[i]

def compute_pos_weight(y_train: np.ndarray) -> float:
    pos = int((y_train == 1).sum())
    neg = int((y_train == 0).sum())
    if pos == 0:
        return 1.0
    return float(neg / pos)

# %% [markdown]
# ## 4) AIAINY Transformer (from scratch)

# %%
def subsequent_mask(size: int):
    attn_shape = (1, size, size)
    subsequent = torch.triu(torch.ones(attn_shape, dtype=torch.bool), diagonal=1)
    return subsequent

class ScaledDotProductAttention(nn.Module):
    def __init__(self, dropout=0.0):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
    def forward(self, Q, K, V, mask=None):
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / np.sqrt(d_k)
        if mask is not None:
            scores = scores.masked_fill(mask, float('-inf'))
        attn = torch.softmax(scores, dim=-1)
        attn = self.dropout(attn)
        out = torch.matmul(attn, V)
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_heads, dropout=0.1):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_k = self.d_v = d_model // n_heads
        self.n_heads = n_heads
        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)
        self.w_o = nn.Linear(d_model, d_model)
        self.attn = ScaledDotProductAttention(dropout=dropout)
        self.dropout = nn.Dropout(dropout)

    def forward(self, q, k, v, mask=None):
        B, Lq, d = q.shape
        Lk = k.size(1)
        h = self.n_heads
        Q = self.w_q(q).view(B, Lq, h, self.d_k).transpose(1, 2)
        K = self.w_k(k).view(B, Lk, h, self.d_k).transpose(1, 2)
        V = self.w_v(v).view(B, Lk, h, self.d_v).transpose(1, 2)
        if mask is not None:
            if mask.dim() == 3:
                mask = mask.unsqueeze(1)
        out = self.attn(Q, K, V, mask=mask)
        out = out.transpose(1, 2).contiguous().view(B, Lq, h * self.d_v)
        out = self.w_o(out)
        return self.dropout(out)

class PositionwiseFFN(nn.Module):
    def __init__(self, d_model, d_ff, dropout=0.1):
        super().__init__()
        self.lin1 = nn.Linear(d_model, d_ff)
        self.lin2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)
    def forward(self, x):
        return self.lin2(self.dropout(F.gelu(self.lin1(x))))

class EncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, n_heads, dropout)
        self.ffn = PositionwiseFFN(d_model, d_ff, dropout)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.drop = nn.Dropout(dropout)
    def forward(self, x, src_mask=None):
        attn_out = self.self_attn(x, x, x, mask=src_mask)
        x = self.norm1(x + self.drop(attn_out))
        ffn_out = self.ffn(x)
        x = self.norm2(x + self.drop(ffn_out))
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, n_heads, dropout)
        self.cross_attn = MultiHeadAttention(d_model, n_heads, dropout)
        self.ffn = PositionwiseFFN(d_model, d_ff, dropout)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.drop = nn.Dropout(dropout)
    def forward(self, x, memory, tgt_mask=None, memory_mask=None):
        x2 = self.self_attn(x, x, x, mask=tgt_mask)
        x = self.norm1(x + self.drop(x2))
        x2 = self.cross_attn(x, memory, memory, mask=memory_mask)
        x = self.norm2(x + self.drop(x2))
        x2 = self.ffn(x)
        x = self.norm3(x + self.drop(x2))
        return x

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=8192):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2, dtype=torch.float32) * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
    def forward(self, x):
        L = x.size(1)
        return x + self.pe[:, :L, :]

class AIAINYTransformerEncDecBinary(nn.Module):
    def __init__(self, d_model=64, n_heads=4, n_enc_layers=2, n_dec_layers=2, d_ff=128, dropout=0.1):
        super().__init__()
        self.src_proj = nn.Linear(1, d_model)
        self.pe_src = PositionalEncoding(d_model)
        self.pe_tgt = PositionalEncoding(d_model)
        self.bos = nn.Parameter(torch.zeros(1, 1, d_model))
        nn.init.normal_(self.bos, mean=0.0, std=0.02)

        self.enc_layers = nn.ModuleList([
            EncoderLayer(d_model, n_heads, d_ff, dropout) for _ in range(n_enc_layers)
        ])
        self.dec_layers = nn.ModuleList([
            DecoderLayer(d_model, n_heads, d_ff, dropout) for _ in range(n_dec_layers)
        ])
        self.head = nn.Linear(d_model, 1)
        self.dropout = nn.Dropout(dropout)

    def forward(self, src):  # src: [B, L, 1]
        B, L, _ = src.shape
        src = self.src_proj(src)
        src = self.pe_src(src)
        enc = src
        for layer in self.enc_layers:
            enc = layer(enc, src_mask=None)

        tgt = self.bos.expand(B, 1, -1)
        tgt = self.pe_tgt(tgt)
        tgt_mask = subsequent_mask(tgt.size(1)).to(tgt.device)
        mem_mask = None
        dec = tgt
        for layer in self.dec_layers:
            dec = layer(dec, enc, tgt_mask=tgt_mask, memory_mask=mem_mask)

        logit = self.head(dec[:, 0, :])
        return logit.squeeze(-1)

# %% [markdown]
# ## 5) Train & Evaluation (+ best-F1 threshold on validation)

# %%
def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total = 0.0
    for X, Y in loader:
        X = X.to(device)
        Y = Y.to(device).float()
        logit = model(X)
        loss = criterion(logit, Y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total += loss.item() * X.size(0)
    return total / max(1, len(loader.dataset))

@torch.no_grad()
def infer_probs(model, loader, device):
    model.eval()
    probs, labels = [], []
    for X, Y in loader:
        X = X.to(device)
        p = torch.sigmoid(model(X)).cpu().numpy()
        probs.append(p)
        labels.append(Y.numpy())
    return np.concatenate(probs), np.concatenate(labels)

from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
def metrics_prfa(y_true: np.ndarray, y_prob: np.ndarray, thr: float = 0.5):
    y_pred = (y_prob >= thr).astype(np.int64)
    P = precision_score(y_true, y_pred, zero_division=0)
    R = recall_score(y_true, y_pred, zero_division=0)
    F1 = f1_score(y_true, y_pred, zero_division=0)
    # AUROC는 예측 확률값(y_prob)을 직접 사용
    try:
        auroc = roc_auc_score(y_true, y_prob)
    except ValueError:  # 단일 클래스만 있는 경우
        auroc = 0.0
    return {
        "Precision": float(P),
        "Recall": float(R),
        "F1": float(F1),
        "AUROC": float(auroc)
    }
def find_best_threshold(y_true, y_prob, grid=None):
    if grid is None:
        grid = np.linspace(0.05, 0.95, 19)
    best_thr, best_f1 = 0.5, -1.0
    for thr in grid:
        f1 = f1_score(y_true, (y_prob >= thr).astype(int), zero_division=0)
        if f1 > best_f1:
            best_f1, best_thr = f1, thr
    return float(best_thr), float(best_f1)

# %% [markdown]
# ## 6) Per-file Training & Testing

# %%
def run_one_file(csv_path: str, cfg):
    x, y = load_yahoo_a1(csv_path)
    n = len(x)
    if n < cfg.seq_len + 10:
        raise ValueError(f"Series too short for seq_len={cfg.seq_len}: {csv_path}")

    n_tr, n_va = int(0.6 * n), int(0.8 * n)
    x_tr, x_va, x_te = x[:n_tr], x[n_tr:n_va], x[n_va:]
    y_tr, y_va, y_te = y[:n_tr], y[n_tr:n_va], y[n_va:]

    rs = fit_robust_scaler(x_tr, cfg)
    x_tr = apply_scaler(x_tr, rs)
    x_va = apply_scaler(x_va, rs)
    x_te = apply_scaler(x_te, rs)

    L = cfg.seq_len
    Xtr, Ytr, _ = make_windows(x_tr, y_tr, L)
    Xva, Yva, _ = make_windows(np.concatenate([x_tr, x_va]),
                               np.concatenate([y_tr, y_va]), L)
    Xte, Yte, _ = make_windows(np.concatenate([x_tr, x_va, x_te]),
                               np.concatenate([y_tr, y_va, y_te]), L)

    ds_tr, ds_va, ds_te = WindowDataset(Xtr, Ytr), WindowDataset(Xva, Yva), WindowDataset(Xte, Yte)
    dl_tr = DataLoader(ds_tr, batch_size=cfg.batch, shuffle=True)
    dl_va = DataLoader(ds_va, batch_size=cfg.batch, shuffle=False)
    dl_te = DataLoader(ds_te, batch_size=cfg.batch, shuffle=False)

    device = cfg.device if (cfg.device == "cpu" or torch.cuda.is_available()) else "cpu"
    model = AIAINYTransformerEncDecBinary(
        d_model=cfg.d_model, n_heads=cfg.n_heads,
        n_enc_layers=cfg.n_enc_layers, n_dec_layers=cfg.n_dec_layers,
        d_ff=cfg.dim_ff, dropout=cfg.dropout
    ).to(device)
    pos_w = compute_pos_weight(Ytr)
    criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([pos_w], device=device))
    optimizer = torch.optim.Adam(model.parameters(), lr=cfg.lr)

    best_f1, best_state, bad = -1.0, None, 0
    for ep in range(1, cfg.epochs + 1):
        _ = train_one_epoch(model, dl_tr, optimizer, criterion, device)
        p_va, y_va = infer_probs(model, dl_va, device)
        f1 = metrics_prfa(y_va, p_va)["F1"]
        if f1 > best_f1:
            best_f1 = f1
            best_state = {k: v.detach().cpu() for k, v in model.state_dict().items()}
            bad = 0
        else:
            bad += 1
        if ep % 5 == 0 or bad == 0:
            print(f"[{os.path.basename(csv_path)}] epoch {ep} valF1={f1:.4f} best={best_f1:.4f}, bad={bad}")
        if bad >= cfg.patience:
            break

    if best_state is not None:
        model.load_state_dict(best_state)

    p_va, y_va = infer_probs(model, dl_va, device)
    best_thr, _ = find_best_threshold(y_va, p_va)

    p_te, y_te = infer_probs(model, dl_te, device)
    return metrics_prfa(y_te, p_te, thr=best_thr)

# %% [markdown]
# ## 7) Evaluate over all A1 files

# %%
def evaluate_all(cfg):
    paths = sorted(glob.glob(os.path.join(cfg.a1_dir, "real_*.csv")))
    if not paths:
        raise FileNotFoundError(f"No files matched: {cfg.a1_dir}/real_*.csv")
    rows = []
    for p in paths:
        print(f"\n### Processing: {p}")
        m = run_one_file(p, cfg)
        rows.append(m)
        print("=> Test metrics:", json.dumps(m, ensure_ascii=False))
    keys = rows[0].keys()
    macro = {k: float(np.mean([r[k] for r in rows])) for k in keys}
    return paths, rows, macro

paths, rows, macro = evaluate_all(cfg)

print("\n# Per-file metrics (Precision/Recall/F1/Accuracy)")
for p, m in zip(paths, rows):
    print(p, json.dumps(m, ensure_ascii=False))

print("\n# Macro mean (simple average over files)")
print(json.dumps(macro, ensure_ascii=False))
# Out:
# ### Processing: ./yahoo/A1Benchmark/real_1.csv
# [real_1.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_1.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_1.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_1.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.7515174506828528}
#
# ### Processing: ./yahoo/A1Benchmark/real_10.csv
# [real_10.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_10.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_10.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_10.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.017676767676767676, "Recall": 0.5384615384615384, "F1": 0.034229828850855744, "AUROC": 0.7496229260935143}
#
# ### Processing: ./yahoo/A1Benchmark/real_11.csv
# [real_11.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_11.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_11.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_11.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.6284688995215311}
#
# ### Processing: ./yahoo/A1Benchmark/real_12.csv
# [real_12.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_12.csv] epoch 3 valF1=0.0115 best=0.0115, bad=0
# [real_12.csv] epoch 5 valF1=0.0021 best=0.0115, bad=2
# [real_12.csv] epoch 10 valF1=0.0027 best=0.0115, bad=7
# [real_12.csv] epoch 15 valF1=0.0282 best=0.0282, bad=0
# [real_12.csv] epoch 18 valF1=0.0476 best=0.0476, bad=0
# [real_12.csv] epoch 19 valF1=0.0556 best=0.0556, bad=0
# [real_12.csv] epoch 20 valF1=0.0667 best=0.0667, bad=0
# [real_12.csv] epoch 21 valF1=0.0714 best=0.0714, bad=0
# [real_12.csv] epoch 22 valF1=0.2222 best=0.2222, bad=0
# [real_12.csv] epoch 25 valF1=0.0020 best=0.2222, bad=3
# [real_12.csv] epoch 30 valF1=0.0000 best=0.2222, bad=8
# [real_12.csv] epoch 35 valF1=0.0000 best=0.2222, bad=13
# => Test metrics: {"Precision": 0.125, "Recall": 0.3333333333333333, "F1": 0.18181818181818182, "AUROC": 0.7053393213572854}
#
# ### Processing: ./yahoo/A1Benchmark/real_13.csv
# [real_13.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_13.csv] epoch 3 valF1=0.0142 best=0.0142, bad=0
# [real_13.csv] epoch 5 valF1=0.0114 best=0.0142, bad=2
# [real_13.csv] epoch 6 valF1=0.0326 best=0.0326, bad=0
# [real_13.csv] epoch 9 valF1=0.1875 best=0.1875, bad=0
# [real_13.csv] epoch 10 valF1=0.0117 best=0.1875, bad=1
# [real_13.csv] epoch 13 valF1=0.3333 best=0.3333, bad=0
# [real_13.csv] epoch 15 valF1=0.0206 best=0.3333, bad=2
# [real_13.csv] epoch 16 valF1=0.3529 best=0.3529, bad=0
# [real_13.csv] epoch 20 valF1=0.1304 best=0.3529, bad=4
# [real_13.csv] epoch 21 valF1=0.4286 best=0.4286, bad=0
# [real_13.csv] epoch 25 valF1=0.1154 best=0.4286, bad=4
# [real_13.csv] epoch 26 valF1=0.4615 best=0.4615, bad=0
# [real_13.csv] epoch 30 valF1=0.2400 best=0.4615, bad=4
# [real_13.csv] epoch 35 valF1=0.4000 best=0.4615, bad=9
# [real_13.csv] epoch 37 valF1=0.5000 best=0.5000, bad=0
# [real_13.csv] epoch 40 valF1=0.4615 best=0.5000, bad=3
# [real_13.csv] epoch 45 valF1=0.2727 best=0.5000, bad=8
# [real_13.csv] epoch 47 valF1=0.5455 best=0.5455, bad=0
# [real_13.csv] epoch 48 valF1=0.6000 best=0.6000, bad=0
# [real_13.csv] epoch 50 valF1=0.0098 best=0.6000, bad=2
# [real_13.csv] epoch 55 valF1=0.0240 best=0.6000, bad=7
# [real_13.csv] epoch 60 valF1=0.1429 best=0.6000, bad=12
# => Test metrics: {"Precision": 0.75, "Recall": 0.25, "F1": 0.375, "AUROC": 0.6269467470484803}
#
# ### Processing: ./yahoo/A1Benchmark/real_14.csv
# [real_14.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_14.csv] epoch 2 valF1=0.0038 best=0.0038, bad=0
# [real_14.csv] epoch 4 valF1=0.0060 best=0.0060, bad=0
# [real_14.csv] epoch 5 valF1=0.0094 best=0.0094, bad=0
# [real_14.csv] epoch 10 valF1=0.0072 best=0.0094, bad=5
# [real_14.csv] epoch 15 valF1=0.0074 best=0.0094, bad=10
# [real_14.csv] epoch 18 valF1=0.0134 best=0.0134, bad=0
# [real_14.csv] epoch 20 valF1=0.0071 best=0.0134, bad=2
# [real_14.csv] epoch 22 valF1=0.0179 best=0.0179, bad=0
# [real_14.csv] epoch 25 valF1=0.0054 best=0.0179, bad=3
# [real_14.csv] epoch 30 valF1=0.0166 best=0.0179, bad=8
# [real_14.csv] epoch 35 valF1=0.0173 best=0.0179, bad=13
# => Test metrics: {"Precision": 0.008547008547008548, "Recall": 1.0, "F1": 0.01694915254237288, "AUROC": 0.8967838444278234}
#
# ### Processing: ./yahoo/A1Benchmark/real_15.csv
# [real_15.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_15.csv] epoch 2 valF1=0.0095 best=0.0095, bad=0
# [real_15.csv] epoch 5 valF1=0.0092 best=0.0095, bad=3
# [real_15.csv] epoch 8 valF1=0.0172 best=0.0172, bad=0
# [real_15.csv] epoch 9 valF1=0.0336 best=0.0336, bad=0
# [real_15.csv] epoch 10 valF1=0.0833 best=0.0833, bad=0
# [real_15.csv] epoch 13 valF1=0.1905 best=0.1905, bad=0
# [real_15.csv] epoch 15 valF1=0.0645 best=0.1905, bad=2
# [real_15.csv] epoch 16 valF1=0.3636 best=0.3636, bad=0
# [real_15.csv] epoch 20 valF1=0.4000 best=0.4000, bad=0
# [real_15.csv] epoch 25 valF1=0.5000 best=0.5000, bad=0
# [real_15.csv] epoch 30 valF1=0.0074 best=0.5000, bad=5
# [real_15.csv] epoch 35 valF1=0.1379 best=0.5000, bad=10
# [real_15.csv] epoch 40 valF1=0.1379 best=0.5000, bad=15
# => Test metrics: {"Precision": 0.6666666666666666, "Recall": 0.2, "F1": 0.3076923076923077, "AUROC": 0.7256960120391271}
#
# ### Processing: ./yahoo/A1Benchmark/real_16.csv
# [real_16.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_16.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_16.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_16.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0196078431372549, "Recall": 0.6666666666666666, "F1": 0.0380952380952381, "AUROC": 0.7334315169366715}
#
# ### Processing: ./yahoo/A1Benchmark/real_17.csv
# [real_17.csv] epoch 1 valF1=0.5967 best=0.5967, bad=0
# [real_17.csv] epoch 2 valF1=0.5979 best=0.5979, bad=0
# [real_17.csv] epoch 5 valF1=0.5955 best=0.5979, bad=3
# [real_17.csv] epoch 10 valF1=0.5984 best=0.5984, bad=0
# [real_17.csv] epoch 15 valF1=0.5947 best=0.5984, bad=5
# [real_17.csv] epoch 20 valF1=0.5984 best=0.5984, bad=10
# [real_17.csv] epoch 25 valF1=0.5984 best=0.5984, bad=15
# => Test metrics: {"Precision": 0.5271867612293144, "Recall": 0.9823788546255506, "F1": 0.6861538461538461, "AUROC": 0.8828221942903955}
#
# ### Processing: ./yahoo/A1Benchmark/real_18.csv
# [real_18.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_18.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_18.csv] epoch 8 valF1=0.0056 best=0.0056, bad=0
# [real_18.csv] epoch 10 valF1=0.0258 best=0.0258, bad=0
# [real_18.csv] epoch 15 valF1=0.0000 best=0.0258, bad=5
# [real_18.csv] epoch 20 valF1=0.0000 best=0.0258, bad=10
# [real_18.csv] epoch 21 valF1=0.4000 best=0.4000, bad=0
# [real_18.csv] epoch 22 valF1=0.6667 best=0.6667, bad=0
# [real_18.csv] epoch 25 valF1=0.0000 best=0.6667, bad=3
# [real_18.csv] epoch 30 valF1=0.0339 best=0.6667, bad=8
# [real_18.csv] epoch 31 valF1=0.8000 best=0.8000, bad=0
# [real_18.csv] epoch 35 valF1=1.0000 best=1.0000, bad=0
# [real_18.csv] epoch 40 valF1=0.5455 best=1.0000, bad=5
# [real_18.csv] epoch 45 valF1=0.3750 best=1.0000, bad=10
# [real_18.csv] epoch 50 valF1=0.8571 best=1.0000, bad=15
# => Test metrics: {"Precision": 1.0, "Recall": 1.0, "F1": 1.0, "AUROC": 1.0}
#
# ### Processing: ./yahoo/A1Benchmark/real_19.csv
# [real_19.csv] epoch 1 valF1=0.5744 best=0.5744, bad=0
# [real_19.csv] epoch 2 valF1=0.5996 best=0.5996, bad=0
# [real_19.csv] epoch 5 valF1=0.5996 best=0.5996, bad=3
# [real_19.csv] epoch 10 valF1=0.5996 best=0.5996, bad=8
# [real_19.csv] epoch 15 valF1=0.5996 best=0.5996, bad=13
# => Test metrics: {"Precision": 0.5285714285714286, "Recall": 0.9779735682819384, "F1": 0.6862442040185471, "AUROC": 0.8877053558162229}
#
# ### Processing: ./yahoo/A1Benchmark/real_2.csv
# [real_2.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_2.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_2.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_2.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.17105263157894737, "Recall": 0.8125, "F1": 0.2826086956521739, "AUROC": 0.9312641723356009}
#
# ### Processing: ./yahoo/A1Benchmark/real_20.csv
# [real_20.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_20.csv] epoch 4 valF1=0.0452 best=0.0452, bad=0
# [real_20.csv] epoch 5 valF1=0.0452 best=0.0452, bad=1
# [real_20.csv] epoch 10 valF1=0.0000 best=0.0452, bad=6
# [real_20.csv] epoch 12 valF1=0.0464 best=0.0464, bad=0
# [real_20.csv] epoch 13 valF1=0.0503 best=0.0503, bad=0
# [real_20.csv] epoch 14 valF1=0.0692 best=0.0692, bad=0
# [real_20.csv] epoch 15 valF1=0.0681 best=0.0692, bad=1
# [real_20.csv] epoch 16 valF1=0.0712 best=0.0712, bad=0
# [real_20.csv] epoch 18 valF1=0.0756 best=0.0756, bad=0
# [real_20.csv] epoch 19 valF1=0.4444 best=0.4444, bad=0
# [real_20.csv] epoch 20 valF1=0.5647 best=0.5647, bad=0
# [real_20.csv] epoch 21 valF1=0.6667 best=0.6667, bad=0
# [real_20.csv] epoch 25 valF1=0.8800 best=0.8800, bad=0
# [real_20.csv] epoch 30 valF1=0.3934 best=0.8800, bad=5
# [real_20.csv] epoch 35 valF1=0.4660 best=0.8800, bad=10
# [real_20.csv] epoch 40 valF1=0.5714 best=0.8800, bad=15
# => Test metrics: {"Precision": 0.8275862068965517, "Recall": 0.7272727272727273, "F1": 0.7741935483870968, "AUROC": 0.8403154900439618}
#
# ### Processing: ./yahoo/A1Benchmark/real_21.csv
# [real_21.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_21.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_21.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_21.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.004545454545454545, "Recall": 1.0, "F1": 0.00904977375565611, "AUROC": 0.6683155758498224}
#
# ### Processing: ./yahoo/A1Benchmark/real_22.csv
# [real_22.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_22.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_22.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_22.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.9905165991084846}
#
# ### Processing: ./yahoo/A1Benchmark/real_23.csv
# [real_23.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_23.csv] epoch 2 valF1=0.0285 best=0.0285, bad=0
# [real_23.csv] epoch 4 valF1=0.1154 best=0.1154, bad=0
# [real_23.csv] epoch 5 valF1=0.1031 best=0.1154, bad=1
# [real_23.csv] epoch 10 valF1=0.0780 best=0.1154, bad=6
# [real_23.csv] epoch 12 valF1=0.1538 best=0.1538, bad=0
# [real_23.csv] epoch 15 valF1=0.1404 best=0.1538, bad=3
# [real_23.csv] epoch 18 valF1=0.1940 best=0.1940, bad=0
# [real_23.csv] epoch 19 valF1=0.2921 best=0.2921, bad=0
# [real_23.csv] epoch 20 valF1=0.1529 best=0.2921, bad=1
# [real_23.csv] epoch 25 valF1=0.0513 best=0.2921, bad=6
# [real_23.csv] epoch 27 valF1=0.4348 best=0.4348, bad=0
# [real_23.csv] epoch 30 valF1=0.1677 best=0.4348, bad=3
# [real_23.csv] epoch 35 valF1=0.2074 best=0.4348, bad=8
# [real_23.csv] epoch 40 valF1=0.2564 best=0.4348, bad=13
# => Test metrics: {"Precision": 0.391304347826087, "Recall": 0.47368421052631576, "F1": 0.42857142857142855, "AUROC": 0.9270601561551843}
#
# ### Processing: ./yahoo/A1Benchmark/real_24.csv
# [real_24.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_24.csv] epoch 4 valF1=0.0023 best=0.0023, bad=0
# [real_24.csv] epoch 5 valF1=0.0000 best=0.0023, bad=1
# [real_24.csv] epoch 7 valF1=0.0059 best=0.0059, bad=0
# [real_24.csv] epoch 10 valF1=0.0000 best=0.0059, bad=3
# [real_24.csv] epoch 14 valF1=0.0198 best=0.0198, bad=0
# [real_24.csv] epoch 15 valF1=0.0198 best=0.0198, bad=1
# [real_24.csv] epoch 16 valF1=0.5000 best=0.5000, bad=0
# [real_24.csv] epoch 20 valF1=0.0400 best=0.5000, bad=4
# [real_24.csv] epoch 22 valF1=0.6667 best=0.6667, bad=0
# [real_24.csv] epoch 25 valF1=0.0062 best=0.6667, bad=3
# [real_24.csv] epoch 30 valF1=0.0328 best=0.6667, bad=8
# [real_24.csv] epoch 35 valF1=0.5000 best=0.6667, bad=13
# => Test metrics: {"Precision": 0.00980392156862745, "Recall": 0.0625, "F1": 0.01694915254237288, "AUROC": 0.1803903345724907}
#
# ### Processing: ./yahoo/A1Benchmark/real_25.csv
# [real_25.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_25.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_25.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_25.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 1.0, "Recall": 0.9767441860465116, "F1": 0.9882352941176471, "AUROC": 0.9949600403196774}
#
# ### Processing: ./yahoo/A1Benchmark/real_26.csv
# [real_26.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_26.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_26.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_26.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.056179775280898875, "Recall": 1.0, "F1": 0.10638297872340426, "AUROC": 0.03614814814814815}
#
# ### Processing: ./yahoo/A1Benchmark/real_27.csv
# [real_27.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_27.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_27.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_27.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.7377358490566038}
#
# ### Processing: ./yahoo/A1Benchmark/real_28.csv
# [real_28.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_28.csv] epoch 3 valF1=0.0056 best=0.0056, bad=0
# [real_28.csv] epoch 4 valF1=0.0326 best=0.0326, bad=0
# [real_28.csv] epoch 5 valF1=0.0044 best=0.0326, bad=1
# [real_28.csv] epoch 10 valF1=0.0057 best=0.0326, bad=6
# [real_28.csv] epoch 15 valF1=0.0108 best=0.0326, bad=11
# => Test metrics: {"Precision": 0.061148396718866516, "Recall": 1.0, "F1": 0.11524947294448348, "AUROC": 0.0404405354617486}
#
# ### Processing: ./yahoo/A1Benchmark/real_29.csv
# [real_29.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_29.csv] epoch 2 valF1=0.0113 best=0.0113, bad=0
# [real_29.csv] epoch 5 valF1=0.0000 best=0.0113, bad=3
# [real_29.csv] epoch 10 valF1=0.0064 best=0.0113, bad=8
# [real_29.csv] epoch 13 valF1=0.0126 best=0.0126, bad=0
# [real_29.csv] epoch 15 valF1=0.0106 best=0.0126, bad=2
# [real_29.csv] epoch 20 valF1=0.0152 best=0.0152, bad=0
# [real_29.csv] epoch 23 valF1=0.0173 best=0.0173, bad=0
# [real_29.csv] epoch 25 valF1=0.0185 best=0.0185, bad=0
# [real_29.csv] epoch 26 valF1=0.0193 best=0.0193, bad=0
# [real_29.csv] epoch 28 valF1=0.0195 best=0.0195, bad=0
# [real_29.csv] epoch 29 valF1=0.0230 best=0.0230, bad=0
# [real_29.csv] epoch 30 valF1=0.0183 best=0.0230, bad=1
# [real_29.csv] epoch 35 valF1=0.0124 best=0.0230, bad=6
# [real_29.csv] epoch 37 valF1=0.0262 best=0.0262, bad=0
# [real_29.csv] epoch 40 valF1=0.0203 best=0.0262, bad=3
# [real_29.csv] epoch 43 valF1=0.0265 best=0.0265, bad=0
# [real_29.csv] epoch 44 valF1=0.0291 best=0.0291, bad=0
# [real_29.csv] epoch 45 valF1=0.0276 best=0.0291, bad=1
# [real_29.csv] epoch 47 valF1=0.0299 best=0.0299, bad=0
# [real_29.csv] epoch 48 valF1=0.0321 best=0.0321, bad=0
# [real_29.csv] epoch 50 valF1=0.0244 best=0.0321, bad=2
# [real_29.csv] epoch 52 valF1=0.0323 best=0.0323, bad=0
# [real_29.csv] epoch 55 valF1=0.0199 best=0.0323, bad=3
# [real_29.csv] epoch 60 valF1=0.0212 best=0.0323, bad=8
# [real_29.csv] epoch 65 valF1=0.0096 best=0.0323, bad=13
# => Test metrics: {"Precision": 0.017543859649122806, "Recall": 0.42857142857142855, "F1": 0.033707865168539325, "AUROC": 0.7969586635253801}
#
# ### Processing: ./yahoo/A1Benchmark/real_3.csv
# [real_3.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_3.csv] epoch 3 valF1=0.0625 best=0.0625, bad=0
# [real_3.csv] epoch 5 valF1=0.0019 best=0.0625, bad=2
# [real_3.csv] epoch 10 valF1=0.0000 best=0.0625, bad=7
# [real_3.csv] epoch 15 valF1=0.0571 best=0.0625, bad=12
# => Test metrics: {"Precision": 0.015151515151515152, "Recall": 0.06666666666666667, "F1": 0.024691358024691357, "AUROC": 0.43382862803368005}
#
# ### Processing: ./yahoo/A1Benchmark/real_30.csv
# [real_30.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_30.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_30.csv] epoch 6 valF1=0.0019 best=0.0019, bad=0
# [real_30.csv] epoch 10 valF1=0.0000 best=0.0019, bad=4
# [real_30.csv] epoch 15 valF1=0.0000 best=0.0019, bad=9
# [real_30.csv] epoch 20 valF1=0.0000 best=0.0019, bad=14
# => Test metrics: {"Precision": 0.006612784717119765, "Recall": 1.0, "F1": 0.013138686131386862, "AUROC": 0.19682774490466798}
#
# ### Processing: ./yahoo/A1Benchmark/real_31.csv
# [real_31.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_31.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_31.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_31.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.015463917525773196, "Recall": 0.125, "F1": 0.027522935779816515, "AUROC": 0.8390573036582246}
#
# ### Processing: ./yahoo/A1Benchmark/real_32.csv
# [real_32.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_32.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_32.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_32.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.04081632653061224, "Recall": 0.9787234042553191, "F1": 0.07836456558773425, "AUROC": 0.8735538563829787}
#
# ### Processing: ./yahoo/A1Benchmark/real_33.csv
# [real_33.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_33.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_33.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_33.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.787210172026926}
#
# ### Processing: ./yahoo/A1Benchmark/real_34.csv
# [real_34.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_34.csv] epoch 3 valF1=0.0038 best=0.0038, bad=0
# [real_34.csv] epoch 5 valF1=0.0081 best=0.0081, bad=0
# [real_34.csv] epoch 10 valF1=0.0038 best=0.0081, bad=5
# [real_34.csv] epoch 12 valF1=0.0274 best=0.0274, bad=0
# [real_34.csv] epoch 15 valF1=0.0000 best=0.0274, bad=3
# [real_34.csv] epoch 20 valF1=0.0031 best=0.0274, bad=8
# [real_34.csv] epoch 23 valF1=0.0303 best=0.0303, bad=0
# [real_34.csv] epoch 24 valF1=0.0909 best=0.0909, bad=0
# [real_34.csv] epoch 25 valF1=0.0290 best=0.0909, bad=1
# [real_34.csv] epoch 29 valF1=0.1429 best=0.1429, bad=0
# [real_34.csv] epoch 30 valF1=0.0247 best=0.1429, bad=1
# [real_34.csv] epoch 35 valF1=0.0204 best=0.1429, bad=6
# [real_34.csv] epoch 40 valF1=0.1333 best=0.1429, bad=11
# => Test metrics: {"Precision": 0.1111111111111111, "Recall": 0.14285714285714285, "F1": 0.125, "AUROC": 0.498917748917749}
#
# ### Processing: ./yahoo/A1Benchmark/real_35.csv
# [real_35.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_35.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_35.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_35.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
#
# ### Processing: ./yahoo/A1Benchmark/real_36.csv
# [real_36.csv] epoch 1 valF1=0.0239 best=0.0239, bad=0
# [real_36.csv] epoch 3 valF1=0.0556 best=0.0556, bad=0
# [real_36.csv] epoch 5 valF1=0.0224 best=0.0556, bad=2
# [real_36.csv] epoch 10 valF1=0.0493 best=0.0556, bad=7
# [real_36.csv] epoch 15 valF1=0.0233 best=0.0556, bad=12
# => Test metrics: {"Precision": 0.07692307692307693, "Recall": 0.6, "F1": 0.13636363636363635, "AUROC": 0.8014749262536873}
#
# ### Processing: ./yahoo/A1Benchmark/real_37.csv
# [real_37.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_37.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_37.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_37.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.026153846153846153, "Recall": 1.0, "F1": 0.050974512743628186, "AUROC": 0.7580769230769231}
#
# ### Processing: ./yahoo/A1Benchmark/real_38.csv
# [real_38.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_38.csv] epoch 4 valF1=0.0057 best=0.0057, bad=0
# [real_38.csv] epoch 5 valF1=0.0057 best=0.0057, bad=1
# [real_38.csv] epoch 10 valF1=0.0000 best=0.0057, bad=6
# [real_38.csv] epoch 15 valF1=0.0000 best=0.0057, bad=11
# => Test metrics: {"Precision": 0.006782215523737754, "Recall": 1.0, "F1": 0.01347305389221557, "AUROC": 0.2486511549485753}
#
# ### Processing: ./yahoo/A1Benchmark/real_39.csv
# [real_39.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_39.csv] epoch 2 valF1=0.0171 best=0.0171, bad=0
# [real_39.csv] epoch 5 valF1=0.0000 best=0.0171, bad=3
# [real_39.csv] epoch 7 valF1=0.1364 best=0.1364, bad=0
# [real_39.csv] epoch 10 valF1=0.0642 best=0.1364, bad=3
# [real_39.csv] epoch 15 valF1=0.1132 best=0.1364, bad=8
# [real_39.csv] epoch 16 valF1=0.1538 best=0.1538, bad=0
# [real_39.csv] epoch 17 valF1=0.6154 best=0.6154, bad=0
# [real_39.csv] epoch 20 valF1=0.0882 best=0.6154, bad=3
# [real_39.csv] epoch 24 valF1=0.7500 best=0.7500, bad=0
# [real_39.csv] epoch 25 valF1=0.2182 best=0.7500, bad=1
# [real_39.csv] epoch 30 valF1=0.2069 best=0.7500, bad=6
# [real_39.csv] epoch 35 valF1=0.0755 best=0.7500, bad=11
# => Test metrics: {"Precision": 1.0, "Recall": 0.6, "F1": 0.75, "AUROC": 0.8871678056188307}
#
# ### Processing: ./yahoo/A1Benchmark/real_4.csv
# [real_4.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_4.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_4.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_4.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.9582701062215477}
#
# ### Processing: ./yahoo/A1Benchmark/real_40.csv
# [real_40.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_40.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_40.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_40.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.3910891089108911, "Recall": 0.9875, "F1": 0.5602836879432624, "AUROC": 0.9729350441058541}
#
# ### Processing: ./yahoo/A1Benchmark/real_41.csv
# [real_41.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_41.csv] epoch 2 valF1=0.0019 best=0.0019, bad=0
# [real_41.csv] epoch 5 valF1=0.0019 best=0.0019, bad=3
# [real_41.csv] epoch 6 valF1=0.0094 best=0.0094, bad=0
# [real_41.csv] epoch 10 valF1=0.0021 best=0.0094, bad=4
# [real_41.csv] epoch 13 valF1=0.0117 best=0.0117, bad=0
# [real_41.csv] epoch 14 valF1=0.6667 best=0.6667, bad=0
# [real_41.csv] epoch 15 valF1=0.1667 best=0.6667, bad=1
# [real_41.csv] epoch 20 valF1=0.2857 best=0.6667, bad=6
# [real_41.csv] epoch 25 valF1=0.6667 best=0.6667, bad=11
# => Test metrics: {"Precision": 0.009523809523809525, "Recall": 0.3333333333333333, "F1": 0.018518518518518517, "AUROC": 0.481981981981982}
#
# ### Processing: ./yahoo/A1Benchmark/real_42.csv
# [real_42.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_42.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_42.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_42.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.2857142857142857, "Recall": 1.0, "F1": 0.4444444444444444, "AUROC": 0.9948267396184063}
#
# ### Processing: ./yahoo/A1Benchmark/real_43.csv
# [real_43.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_43.csv] epoch 2 valF1=0.0181 best=0.0181, bad=0
# [real_43.csv] epoch 3 valF1=0.0188 best=0.0188, bad=0
# [real_43.csv] epoch 4 valF1=0.0278 best=0.0278, bad=0
# [real_43.csv] epoch 5 valF1=0.0000 best=0.0278, bad=1
# [real_43.csv] epoch 8 valF1=0.0284 best=0.0284, bad=0
# [real_43.csv] epoch 9 valF1=0.0297 best=0.0297, bad=0
# [real_43.csv] epoch 10 valF1=0.0298 best=0.0298, bad=0
# [real_43.csv] epoch 11 valF1=0.0322 best=0.0322, bad=0
# [real_43.csv] epoch 14 valF1=0.0342 best=0.0342, bad=0
# [real_43.csv] epoch 15 valF1=0.0725 best=0.0725, bad=0
# [real_43.csv] epoch 18 valF1=0.2857 best=0.2857, bad=0
# [real_43.csv] epoch 20 valF1=0.0318 best=0.2857, bad=2
# [real_43.csv] epoch 25 valF1=0.0641 best=0.2857, bad=7
# [real_43.csv] epoch 29 valF1=0.3333 best=0.3333, bad=0
# [real_43.csv] epoch 30 valF1=0.3333 best=0.3333, bad=1
# [real_43.csv] epoch 34 valF1=0.3448 best=0.3448, bad=0
# [real_43.csv] epoch 35 valF1=0.3226 best=0.3448, bad=1
# [real_43.csv] epoch 40 valF1=0.4444 best=0.4444, bad=0
# [real_43.csv] epoch 44 valF1=0.5556 best=0.5556, bad=0
# [real_43.csv] epoch 45 valF1=0.5882 best=0.5882, bad=0
# [real_43.csv] epoch 50 valF1=0.4762 best=0.5882, bad=5
# [real_43.csv] epoch 55 valF1=0.1282 best=0.5882, bad=10
# [real_43.csv] epoch 60 valF1=0.4348 best=0.5882, bad=15
# => Test metrics: {"Precision": 0.8333333333333334, "Recall": 0.15625, "F1": 0.2631578947368421, "AUROC": 0.6682315558103976}
#
# ### Processing: ./yahoo/A1Benchmark/real_44.csv
# [real_44.csv] epoch 1 valF1=0.0167 best=0.0167, bad=0
# [real_44.csv] epoch 5 valF1=0.0174 best=0.0174, bad=0
# [real_44.csv] epoch 10 valF1=0.0000 best=0.0174, bad=5
# [real_44.csv] epoch 13 valF1=0.0784 best=0.0784, bad=0
# [real_44.csv] epoch 15 valF1=0.0167 best=0.0784, bad=2
# [real_44.csv] epoch 20 valF1=0.0000 best=0.0784, bad=7
# [real_44.csv] epoch 25 valF1=0.0167 best=0.0784, bad=12
# [real_44.csv] epoch 27 valF1=0.0845 best=0.0845, bad=0
# [real_44.csv] epoch 28 valF1=0.2857 best=0.2857, bad=0
# [real_44.csv] epoch 30 valF1=0.2083 best=0.2857, bad=2
# [real_44.csv] epoch 35 valF1=0.2286 best=0.2857, bad=7
# [real_44.csv] epoch 39 valF1=0.3721 best=0.3721, bad=0
# [real_44.csv] epoch 40 valF1=0.0938 best=0.3721, bad=1
# [real_44.csv] epoch 45 valF1=0.1224 best=0.3721, bad=6
# [real_44.csv] epoch 50 valF1=0.1667 best=0.3721, bad=11
# => Test metrics: {"Precision": 0.5, "Recall": 0.6666666666666666, "F1": 0.5714285714285714, "AUROC": 0.986439842209073}
#
# ### Processing: ./yahoo/A1Benchmark/real_45.csv
# [real_45.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_45.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_45.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_45.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.3749066467513069}
#
# ### Processing: ./yahoo/A1Benchmark/real_46.csv
# [real_46.csv] epoch 1 valF1=0.4196 best=0.4196, bad=0
# [real_46.csv] epoch 2 valF1=0.6062 best=0.6062, bad=0
# [real_46.csv] epoch 3 valF1=0.7181 best=0.7181, bad=0
# [real_46.csv] epoch 4 valF1=0.7509 best=0.7509, bad=0
# [real_46.csv] epoch 5 valF1=0.8735 best=0.8735, bad=0
# [real_46.csv] epoch 7 valF1=0.8770 best=0.8770, bad=0
# [real_46.csv] epoch 8 valF1=0.9187 best=0.9187, bad=0
# [real_46.csv] epoch 10 valF1=0.8075 best=0.9187, bad=2
# [real_46.csv] epoch 15 valF1=0.8664 best=0.9187, bad=7
# [real_46.csv] epoch 20 valF1=0.8770 best=0.9187, bad=12
# => Test metrics: {"Precision": 0.9385964912280702, "Recall": 0.981651376146789, "F1": 0.9596412556053812, "AUROC": 0.9887071071130704}
#
# ### Processing: ./yahoo/A1Benchmark/real_47.csv
# [real_47.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_47.csv] epoch 2 valF1=0.0171 best=0.0171, bad=0
# [real_47.csv] epoch 5 valF1=0.0245 best=0.0245, bad=0
# [real_47.csv] epoch 6 valF1=0.0327 best=0.0327, bad=0
# [real_47.csv] epoch 7 valF1=0.0352 best=0.0352, bad=0
# [real_47.csv] epoch 10 valF1=0.0438 best=0.0438, bad=0
# [real_47.csv] epoch 13 valF1=0.0621 best=0.0621, bad=0
# [real_47.csv] epoch 14 valF1=0.0625 best=0.0625, bad=0
# [real_47.csv] epoch 15 valF1=0.0202 best=0.0625, bad=1
# [real_47.csv] epoch 19 valF1=0.0645 best=0.0645, bad=0
# [real_47.csv] epoch 20 valF1=0.0661 best=0.0661, bad=0
# [real_47.csv] epoch 25 valF1=0.0840 best=0.0840, bad=0
# [real_47.csv] epoch 26 valF1=0.1020 best=0.1020, bad=0
# [real_47.csv] epoch 30 valF1=0.0847 best=0.1020, bad=4
# [real_47.csv] epoch 31 valF1=0.1149 best=0.1149, bad=0
# [real_47.csv] epoch 32 valF1=0.1408 best=0.1408, bad=0
# [real_47.csv] epoch 35 valF1=0.0289 best=0.1408, bad=3
# [real_47.csv] epoch 40 valF1=0.0364 best=0.1408, bad=8
# [real_47.csv] epoch 45 valF1=0.1064 best=0.1408, bad=13
# => Test metrics: {"Precision": 0.049019607843137254, "Recall": 0.5, "F1": 0.08928571428571429, "AUROC": 0.700303720577069}
#
# ### Processing: ./yahoo/A1Benchmark/real_48.csv
# [real_48.csv] epoch 1 valF1=0.1446 best=0.1446, bad=0
# [real_48.csv] epoch 2 valF1=0.1455 best=0.1455, bad=0
# [real_48.csv] epoch 3 valF1=0.1745 best=0.1745, bad=0
# [real_48.csv] epoch 4 valF1=0.2637 best=0.2637, bad=0
# [real_48.csv] epoch 5 valF1=0.1784 best=0.2637, bad=1
# [real_48.csv] epoch 10 valF1=0.2060 best=0.2637, bad=6
# [real_48.csv] epoch 13 valF1=0.3333 best=0.3333, bad=0
# [real_48.csv] epoch 15 valF1=0.3721 best=0.3721, bad=0
# [real_48.csv] epoch 16 valF1=0.5161 best=0.5161, bad=0
# [real_48.csv] epoch 20 valF1=0.2060 best=0.5161, bad=4
# [real_48.csv] epoch 25 valF1=0.2513 best=0.5161, bad=9
# [real_48.csv] epoch 29 valF1=0.5517 best=0.5517, bad=0
# [real_48.csv] epoch 30 valF1=0.4706 best=0.5517, bad=1
# [real_48.csv] epoch 35 valF1=0.2963 best=0.5517, bad=6
# [real_48.csv] epoch 37 valF1=0.6957 best=0.6957, bad=0
# [real_48.csv] epoch 40 valF1=0.1967 best=0.6957, bad=3
# [real_48.csv] epoch 45 valF1=0.4324 best=0.6957, bad=8
# [real_48.csv] epoch 50 valF1=0.7164 best=0.7164, bad=0
# [real_48.csv] epoch 51 valF1=0.8000 best=0.8000, bad=0
# [real_48.csv] epoch 55 valF1=0.5217 best=0.8000, bad=4
# [real_48.csv] epoch 60 valF1=0.7164 best=0.8000, bad=9
# [real_48.csv] epoch 65 valF1=0.7273 best=0.8000, bad=14
# => Test metrics: {"Precision": 0.8518518518518519, "Recall": 0.9583333333333334, "F1": 0.9019607843137255, "AUROC": 0.9996197718631179}
#
# ### Processing: ./yahoo/A1Benchmark/real_49.csv
# [real_49.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_49.csv] epoch 5 valF1=0.0056 best=0.0056, bad=0
# [real_49.csv] epoch 10 valF1=0.0000 best=0.0056, bad=5
# [real_49.csv] epoch 14 valF1=0.0462 best=0.0462, bad=0
# [real_49.csv] epoch 15 valF1=0.0000 best=0.0462, bad=1
# [real_49.csv] epoch 17 valF1=0.1333 best=0.1333, bad=0
# [real_49.csv] epoch 20 valF1=0.0202 best=0.1333, bad=3
# [real_49.csv] epoch 25 valF1=0.0000 best=0.1333, bad=8
# [real_49.csv] epoch 30 valF1=0.0000 best=0.1333, bad=13
# => Test metrics: {"Precision": 0.058823529411764705, "Recall": 0.3333333333333333, "F1": 0.1, "AUROC": 0.9867452135493372}
#
# ### Processing: ./yahoo/A1Benchmark/real_5.csv
# [real_5.csv] epoch 1 valF1=0.0183 best=0.0183, bad=0
# [real_5.csv] epoch 5 valF1=0.0076 best=0.0183, bad=4
# [real_5.csv] epoch 6 valF1=0.0345 best=0.0345, bad=0
# [real_5.csv] epoch 7 valF1=0.0714 best=0.0714, bad=0
# [real_5.csv] epoch 10 valF1=0.6667 best=0.6667, bad=0
# [real_5.csv] epoch 15 valF1=0.3636 best=0.6667, bad=5
# [real_5.csv] epoch 20 valF1=0.0078 best=0.6667, bad=10
# [real_5.csv] epoch 25 valF1=0.6667 best=0.6667, bad=15
# => Test metrics: {"Precision": 0.034482758620689655, "Recall": 0.5, "F1": 0.06451612903225806, "AUROC": 0.987658937920718}
#
# ### Processing: ./yahoo/A1Benchmark/real_50.csv
# [real_50.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_50.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_50.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_50.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.005227781926811053, "Recall": 1.0, "F1": 0.010401188707280832, "AUROC": 1.0}
#
# ### Processing: ./yahoo/A1Benchmark/real_51.csv
# [real_51.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_51.csv] epoch 4 valF1=0.0057 best=0.0057, bad=0
# [real_51.csv] epoch 5 valF1=0.0057 best=0.0057, bad=1
# [real_51.csv] epoch 10 valF1=0.0000 best=0.0057, bad=6
# [real_51.csv] epoch 15 valF1=0.0057 best=0.0057, bad=11
# => Test metrics: {"Precision": 0.003014318010550113, "Recall": 1.0, "F1": 0.006010518407212622, "AUROC": 0.350151171579743}
#
# ### Processing: ./yahoo/A1Benchmark/real_52.csv
# [real_52.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_52.csv] epoch 2 valF1=0.0095 best=0.0095, bad=0
# [real_52.csv] epoch 4 valF1=0.0161 best=0.0161, bad=0
# [real_52.csv] epoch 5 valF1=0.0000 best=0.0161, bad=1
# [real_52.csv] epoch 10 valF1=0.0000 best=0.0161, bad=6
# [real_52.csv] epoch 15 valF1=0.0000 best=0.0161, bad=11
# [real_52.csv] epoch 19 valF1=0.0177 best=0.0177, bad=0
# [real_52.csv] epoch 20 valF1=0.0000 best=0.0177, bad=1
# [real_52.csv] epoch 25 valF1=0.0000 best=0.0177, bad=6
# [real_52.csv] epoch 26 valF1=0.0179 best=0.0179, bad=0
# [real_52.csv] epoch 30 valF1=0.0149 best=0.0179, bad=4
# [real_52.csv] epoch 31 valF1=0.0186 best=0.0186, bad=0
# [real_52.csv] epoch 32 valF1=0.0227 best=0.0227, bad=0
# [real_52.csv] epoch 34 valF1=0.0286 best=0.0286, bad=0
# [real_52.csv] epoch 35 valF1=0.0000 best=0.0286, bad=1
# [real_52.csv] epoch 40 valF1=0.0139 best=0.0286, bad=6
# [real_52.csv] epoch 42 valF1=0.0293 best=0.0293, bad=0
# [real_52.csv] epoch 43 valF1=0.0620 best=0.0620, bad=0
# [real_52.csv] epoch 44 valF1=0.0625 best=0.0625, bad=0
# [real_52.csv] epoch 45 valF1=0.0426 best=0.0625, bad=1
# [real_52.csv] epoch 50 valF1=0.0494 best=0.0625, bad=6
# [real_52.csv] epoch 51 valF1=0.0822 best=0.0822, bad=0
# [real_52.csv] epoch 54 valF1=0.1067 best=0.1067, bad=0
# [real_52.csv] epoch 55 valF1=0.0734 best=0.1067, bad=1
# [real_52.csv] epoch 60 valF1=0.0372 best=0.1067, bad=6
# [real_52.csv] epoch 65 valF1=0.0833 best=0.1067, bad=11
# => Test metrics: {"Precision": 0.13043478260869565, "Recall": 0.2727272727272727, "F1": 0.17647058823529413, "AUROC": 0.572156080104604}
#
# ### Processing: ./yahoo/A1Benchmark/real_53.csv
# [real_53.csv] epoch 1 valF1=0.0037 best=0.0037, bad=0
# [real_53.csv] epoch 5 valF1=0.0000 best=0.0037, bad=4
# [real_53.csv] epoch 8 valF1=0.0047 best=0.0047, bad=0
# [real_53.csv] epoch 10 valF1=0.0000 best=0.0047, bad=2
# [real_53.csv] epoch 15 valF1=0.0000 best=0.0047, bad=7
# [real_53.csv] epoch 20 valF1=0.0220 best=0.0220, bad=0
# [real_53.csv] epoch 21 valF1=0.2500 best=0.2500, bad=0
# [real_53.csv] epoch 25 valF1=0.0741 best=0.2500, bad=4
# [real_53.csv] epoch 29 valF1=0.2857 best=0.2857, bad=0
# [real_53.csv] epoch 30 valF1=0.0070 best=0.2857, bad=1
# [real_53.csv] epoch 32 valF1=0.3636 best=0.3636, bad=0
# [real_53.csv] epoch 33 valF1=0.4444 best=0.4444, bad=0
# [real_53.csv] epoch 35 valF1=0.1818 best=0.4444, bad=2
# [real_53.csv] epoch 36 valF1=0.5000 best=0.5000, bad=0
# [real_53.csv] epoch 37 valF1=0.5714 best=0.5714, bad=0
# [real_53.csv] epoch 40 valF1=0.2353 best=0.5714, bad=3
# [real_53.csv] epoch 45 valF1=0.1481 best=0.5714, bad=8
# [real_53.csv] epoch 50 valF1=0.3636 best=0.5714, bad=13
# => Test metrics: {"Precision": 0.2571428571428571, "Recall": 0.5294117647058824, "F1": 0.34615384615384615, "AUROC": 0.9461221988795518}
#
# ### Processing: ./yahoo/A1Benchmark/real_54.csv
# [real_54.csv] epoch 1 valF1=0.0081 best=0.0081, bad=0
# [real_54.csv] epoch 2 valF1=0.0412 best=0.0412, bad=0
# [real_54.csv] epoch 5 valF1=0.0000 best=0.0412, bad=3
# [real_54.csv] epoch 10 valF1=0.0081 best=0.0412, bad=8
# [real_54.csv] epoch 15 valF1=0.0081 best=0.0412, bad=13
# [real_54.csv] epoch 16 valF1=0.0702 best=0.0702, bad=0
# [real_54.csv] epoch 20 valF1=0.0000 best=0.0702, bad=4
# [real_54.csv] epoch 25 valF1=0.0310 best=0.0702, bad=9
# [real_54.csv] epoch 26 valF1=0.1481 best=0.1481, bad=0
# [real_54.csv] epoch 27 valF1=0.2500 best=0.2500, bad=0
# [real_54.csv] epoch 29 valF1=0.3077 best=0.3077, bad=0
# [real_54.csv] epoch 30 valF1=0.1000 best=0.3077, bad=1
# [real_54.csv] epoch 35 valF1=0.1429 best=0.3077, bad=6
# [real_54.csv] epoch 40 valF1=0.0106 best=0.3077, bad=11
# => Test metrics: {"Precision": 0.5, "Recall": 1.0, "F1": 0.6666666666666666, "AUROC": 0.9976525821596244}
#
# ### Processing: ./yahoo/A1Benchmark/real_55.csv
# [real_55.csv] epoch 1 valF1=0.0057 best=0.0057, bad=0
# [real_55.csv] epoch 5 valF1=0.0116 best=0.0116, bad=0
# [real_55.csv] epoch 10 valF1=0.0063 best=0.0116, bad=5
# [real_55.csv] epoch 12 valF1=0.0145 best=0.0145, bad=0
# [real_55.csv] epoch 13 valF1=0.0178 best=0.0178, bad=0
# [real_55.csv] epoch 14 valF1=0.0182 best=0.0182, bad=0
# [real_55.csv] epoch 15 valF1=0.0123 best=0.0182, bad=1
# [real_55.csv] epoch 20 valF1=0.0103 best=0.0182, bad=6
# [real_55.csv] epoch 25 valF1=0.0105 best=0.0182, bad=11
# => Test metrics: {"Precision": 0.0066815144766146995, "Recall": 0.6, "F1": 0.013215859030837005, "AUROC": 0.7346444780635402}
#
# ### Processing: ./yahoo/A1Benchmark/real_56.csv
# [real_56.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_56.csv] epoch 4 valF1=0.0057 best=0.0057, bad=0
# [real_56.csv] epoch 5 valF1=0.0057 best=0.0057, bad=1
# [real_56.csv] epoch 8 valF1=0.0061 best=0.0061, bad=0
# [real_56.csv] epoch 9 valF1=0.0089 best=0.0089, bad=0
# [real_56.csv] epoch 10 valF1=0.0161 best=0.0161, bad=0
# [real_56.csv] epoch 15 valF1=0.0073 best=0.0161, bad=5
# [real_56.csv] epoch 20 valF1=0.0136 best=0.0161, bad=10
# [real_56.csv] epoch 21 valF1=0.0208 best=0.0208, bad=0
# [real_56.csv] epoch 25 valF1=0.0214 best=0.0214, bad=0
# [real_56.csv] epoch 26 valF1=0.0250 best=0.0250, bad=0
# [real_56.csv] epoch 30 valF1=0.0085 best=0.0250, bad=4
# [real_56.csv] epoch 35 valF1=0.0194 best=0.0250, bad=9
# [real_56.csv] epoch 40 valF1=0.0245 best=0.0250, bad=14
# [real_56.csv] epoch 41 valF1=0.0254 best=0.0254, bad=0
# [real_56.csv] epoch 42 valF1=0.0261 best=0.0261, bad=0
# [real_56.csv] epoch 43 valF1=0.0275 best=0.0275, bad=0
# [real_56.csv] epoch 44 valF1=0.0300 best=0.0300, bad=0
# [real_56.csv] epoch 45 valF1=0.0208 best=0.0300, bad=1
# [real_56.csv] epoch 50 valF1=0.0213 best=0.0300, bad=6
# [real_56.csv] epoch 55 valF1=0.0213 best=0.0300, bad=11
# => Test metrics: {"Precision": 0.012618296529968454, "Recall": 0.8, "F1": 0.024844720496894408, "AUROC": 0.662178517397882}
#
# ### Processing: ./yahoo/A1Benchmark/real_57.csv
# [real_57.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_57.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_57.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_57.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.6497259591429996}
#
# ### Processing: ./yahoo/A1Benchmark/real_58.csv
# [real_58.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_58.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_58.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_58.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 1.0, "Recall": 0.3953488372093023, "F1": 0.5666666666666667, "AUROC": 0.9963820289437684}
#
# ### Processing: ./yahoo/A1Benchmark/real_59.csv
# [real_59.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_59.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_59.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_59.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
#
# ### Processing: ./yahoo/A1Benchmark/real_6.csv
# [real_6.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_6.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_6.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_6.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.00597460791635549, "Recall": 1.0, "F1": 0.011878247958426132, "AUROC": 0.5615138993238167}
#
# ### Processing: ./yahoo/A1Benchmark/real_60.csv
# [real_60.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_60.csv] epoch 2 valF1=0.2105 best=0.2105, bad=0
# [real_60.csv] epoch 5 valF1=0.0205 best=0.2105, bad=3
# [real_60.csv] epoch 10 valF1=0.0370 best=0.2105, bad=8
# [real_60.csv] epoch 15 valF1=0.0386 best=0.2105, bad=13
# => Test metrics: {"Precision": 0.04424778761061947, "Recall": 0.3125, "F1": 0.07751937984496124, "AUROC": 0.779228624535316}
#
# ### Processing: ./yahoo/A1Benchmark/real_61.csv
# [real_61.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_61.csv] epoch 2 valF1=0.0741 best=0.0741, bad=0
# [real_61.csv] epoch 3 valF1=0.0811 best=0.0811, bad=0
# [real_61.csv] epoch 4 valF1=0.0857 best=0.0857, bad=0
# [real_61.csv] epoch 5 valF1=0.6780 best=0.6780, bad=0
# [real_61.csv] epoch 8 valF1=0.7241 best=0.7241, bad=0
# [real_61.csv] epoch 9 valF1=0.8462 best=0.8462, bad=0
# [real_61.csv] epoch 10 valF1=0.8800 best=0.8800, bad=0
# [real_61.csv] epoch 12 valF1=0.9565 best=0.9565, bad=0
# [real_61.csv] epoch 15 valF1=0.7458 best=0.9565, bad=3
# [real_61.csv] epoch 20 valF1=0.6567 best=0.9565, bad=8
# [real_61.csv] epoch 23 valF1=0.9778 best=0.9778, bad=0
# [real_61.csv] epoch 25 valF1=0.8980 best=0.9778, bad=2
# [real_61.csv] epoch 30 valF1=1.0000 best=1.0000, bad=0
# [real_61.csv] epoch 35 valF1=0.8519 best=1.0000, bad=5
# [real_61.csv] epoch 40 valF1=0.9583 best=1.0000, bad=10
# [real_61.csv] epoch 45 valF1=0.8519 best=1.0000, bad=15
# => Test metrics: {"Precision": 1.0, "Recall": 0.9583333333333334, "F1": 0.9787234042553191, "AUROC": 0.9803847127309542}
#
# ### Processing: ./yahoo/A1Benchmark/real_62.csv
# [real_62.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_62.csv] epoch 4 valF1=0.0714 best=0.0714, bad=0
# [real_62.csv] epoch 5 valF1=0.0051 best=0.0714, bad=1
# [real_62.csv] epoch 10 valF1=0.0833 best=0.0833, bad=0
# [real_62.csv] epoch 15 valF1=0.0556 best=0.0833, bad=5
# [real_62.csv] epoch 16 valF1=0.0909 best=0.0909, bad=0
# [real_62.csv] epoch 17 valF1=0.1429 best=0.1429, bad=0
# [real_62.csv] epoch 18 valF1=0.1818 best=0.1818, bad=0
# [real_62.csv] epoch 20 valF1=0.0377 best=0.1818, bad=2
# [real_62.csv] epoch 25 valF1=0.0161 best=0.1818, bad=7
# [real_62.csv] epoch 30 valF1=0.1538 best=0.1818, bad=12
# [real_62.csv] epoch 32 valF1=0.2000 best=0.2000, bad=0
# [real_62.csv] epoch 35 valF1=0.1429 best=0.2000, bad=3
# [real_62.csv] epoch 40 valF1=0.0870 best=0.2000, bad=8
# [real_62.csv] epoch 45 valF1=0.1429 best=0.2000, bad=13
# => Test metrics: {"Precision": 0.14285714285714285, "Recall": 0.2, "F1": 0.16666666666666666, "AUROC": 0.8952830188679245}
#
# ### Processing: ./yahoo/A1Benchmark/real_63.csv
# [real_63.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_63.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_63.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_63.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.5364387678437266}
#
# ### Processing: ./yahoo/A1Benchmark/real_64.csv
# [real_64.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_64.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_64.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_64.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
#
# ### Processing: ./yahoo/A1Benchmark/real_65.csv
# [real_65.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_65.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_65.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_65.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.01283987915407855, "Recall": 1.0, "F1": 0.02535421327367636, "AUROC": 0.8810927584499753}
#
# ### Processing: ./yahoo/A1Benchmark/real_66.csv
# [real_66.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_66.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_66.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_66.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.1891891891891892, "Recall": 1.0, "F1": 0.3181818181818182, "AUROC": 0.9591419069546467}
#
# ### Processing: ./yahoo/A1Benchmark/real_67.csv
# [real_67.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_67.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_67.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_67.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.5789473684210527, "Recall": 0.9565217391304348, "F1": 0.7213114754098361, "AUROC": 0.9617725752508363}
#
# ### Processing: ./yahoo/A1Benchmark/real_7.csv
# [real_7.csv] epoch 1 valF1=0.2186 best=0.2186, bad=0
# [real_7.csv] epoch 4 valF1=0.2222 best=0.2222, bad=0
# [real_7.csv] epoch 5 valF1=0.2266 best=0.2266, bad=0
# [real_7.csv] epoch 6 valF1=0.2289 best=0.2289, bad=0
# [real_7.csv] epoch 7 valF1=0.2323 best=0.2323, bad=0
# [real_7.csv] epoch 8 valF1=0.2359 best=0.2359, bad=0
# [real_7.csv] epoch 9 valF1=0.2706 best=0.2706, bad=0
# [real_7.csv] epoch 10 valF1=0.4400 best=0.4400, bad=0
# [real_7.csv] epoch 11 valF1=0.8148 best=0.8148, bad=0
# [real_7.csv] epoch 12 valF1=0.8800 best=0.8800, bad=0
# [real_7.csv] epoch 14 valF1=0.9778 best=0.9778, bad=0
# [real_7.csv] epoch 15 valF1=0.8302 best=0.9778, bad=1
# [real_7.csv] epoch 20 valF1=0.4314 best=0.9778, bad=6
# [real_7.csv] epoch 25 valF1=0.8302 best=0.9778, bad=11
# => Test metrics: {"Precision": 1.0, "Recall": 0.36065573770491804, "F1": 0.5301204819277109, "AUROC": 0.875763165415292}
#
# ### Processing: ./yahoo/A1Benchmark/real_8.csv
# [real_8.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_8.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_8.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_8.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.03065134099616858, "Recall": 0.8, "F1": 0.05904059040590406, "AUROC": 0.8112213740458016}
#
# ### Processing: ./yahoo/A1Benchmark/real_9.csv
# [real_9.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_9.csv] epoch 3 valF1=0.0123 best=0.0123, bad=0
# [real_9.csv] epoch 5 valF1=0.0123 best=0.0123, bad=2
# [real_9.csv] epoch 7 valF1=0.0476 best=0.0476, bad=0
# [real_9.csv] epoch 10 valF1=0.0000 best=0.0476, bad=3
# [real_9.csv] epoch 11 valF1=0.0684 best=0.0684, bad=0
# [real_9.csv] epoch 15 valF1=0.0696 best=0.0696, bad=0
# [real_9.csv] epoch 16 valF1=0.4211 best=0.4211, bad=0
# [real_9.csv] epoch 20 valF1=0.4000 best=0.4211, bad=4
# [real_9.csv] epoch 24 valF1=0.5000 best=0.5000, bad=0
# [real_9.csv] epoch 25 valF1=0.5714 best=0.5714, bad=0
# [real_9.csv] epoch 30 valF1=0.5000 best=0.5714, bad=5
# [real_9.csv] epoch 35 valF1=0.1277 best=0.5714, bad=10
# [real_9.csv] epoch 40 valF1=0.0800 best=0.5714, bad=15
# => Test metrics: {"Precision": 0.8333333333333334, "Recall": 0.625, "F1": 0.7142857142857143, "AUROC": 0.9727457501847746}
#
# # Per-file metrics (Precision/Recall/F1/Accuracy)
# ./yahoo/A1Benchmark/real_1.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.7515174506828528}
# ./yahoo/A1Benchmark/real_10.csv {"Precision": 0.017676767676767676, "Recall": 0.5384615384615384, "F1": 0.034229828850855744, "AUROC": 0.7496229260935143}
# ./yahoo/A1Benchmark/real_11.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.6284688995215311}
# ./yahoo/A1Benchmark/real_12.csv {"Precision": 0.125, "Recall": 0.3333333333333333, "F1": 0.18181818181818182, "AUROC": 0.7053393213572854}
# ./yahoo/A1Benchmark/real_13.csv {"Precision": 0.75, "Recall": 0.25, "F1": 0.375, "AUROC": 0.6269467470484803}
# ./yahoo/A1Benchmark/real_14.csv {"Precision": 0.008547008547008548, "Recall": 1.0, "F1": 0.01694915254237288, "AUROC": 0.8967838444278234}
# ./yahoo/A1Benchmark/real_15.csv {"Precision": 0.6666666666666666, "Recall": 0.2, "F1": 0.3076923076923077, "AUROC": 0.7256960120391271}
# ./yahoo/A1Benchmark/real_16.csv {"Precision": 0.0196078431372549, "Recall": 0.6666666666666666, "F1": 0.0380952380952381, "AUROC": 0.7334315169366715}
# ./yahoo/A1Benchmark/real_17.csv {"Precision": 0.5271867612293144, "Recall": 0.9823788546255506, "F1": 0.6861538461538461, "AUROC": 0.8828221942903955}
# ./yahoo/A1Benchmark/real_18.csv {"Precision": 1.0, "Recall": 1.0, "F1": 1.0, "AUROC": 1.0}
# ./yahoo/A1Benchmark/real_19.csv {"Precision": 0.5285714285714286, "Recall": 0.9779735682819384, "F1": 0.6862442040185471, "AUROC": 0.8877053558162229}
# ./yahoo/A1Benchmark/real_2.csv {"Precision": 0.17105263157894737, "Recall": 0.8125, "F1": 0.2826086956521739, "AUROC": 0.9312641723356009}
# ./yahoo/A1Benchmark/real_20.csv {"Precision": 0.8275862068965517, "Recall": 0.7272727272727273, "F1": 0.7741935483870968, "AUROC": 0.8403154900439618}
# ./yahoo/A1Benchmark/real_21.csv {"Precision": 0.004545454545454545, "Recall": 1.0, "F1": 0.00904977375565611, "AUROC": 0.6683155758498224}
# ./yahoo/A1Benchmark/real_22.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.9905165991084846}
# ./yahoo/A1Benchmark/real_23.csv {"Precision": 0.391304347826087, "Recall": 0.47368421052631576, "F1": 0.42857142857142855, "AUROC": 0.9270601561551843}
# ./yahoo/A1Benchmark/real_24.csv {"Precision": 0.00980392156862745, "Recall": 0.0625, "F1": 0.01694915254237288, "AUROC": 0.1803903345724907}
# ./yahoo/A1Benchmark/real_25.csv {"Precision": 1.0, "Recall": 0.9767441860465116, "F1": 0.9882352941176471, "AUROC": 0.9949600403196774}
# ./yahoo/A1Benchmark/real_26.csv {"Precision": 0.056179775280898875, "Recall": 1.0, "F1": 0.10638297872340426, "AUROC": 0.03614814814814815}
# ./yahoo/A1Benchmark/real_27.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.7377358490566038}
# ./yahoo/A1Benchmark/real_28.csv {"Precision": 0.061148396718866516, "Recall": 1.0, "F1": 0.11524947294448348, "AUROC": 0.0404405354617486}
# ./yahoo/A1Benchmark/real_29.csv {"Precision": 0.017543859649122806, "Recall": 0.42857142857142855, "F1": 0.033707865168539325, "AUROC": 0.7969586635253801}
# ./yahoo/A1Benchmark/real_3.csv {"Precision": 0.015151515151515152, "Recall": 0.06666666666666667, "F1": 0.024691358024691357, "AUROC": 0.43382862803368005}
# ./yahoo/A1Benchmark/real_30.csv {"Precision": 0.006612784717119765, "Recall": 1.0, "F1": 0.013138686131386862, "AUROC": 0.19682774490466798}
# ./yahoo/A1Benchmark/real_31.csv {"Precision": 0.015463917525773196, "Recall": 0.125, "F1": 0.027522935779816515, "AUROC": 0.8390573036582246}
# ./yahoo/A1Benchmark/real_32.csv {"Precision": 0.04081632653061224, "Recall": 0.9787234042553191, "F1": 0.07836456558773425, "AUROC": 0.8735538563829787}
# ./yahoo/A1Benchmark/real_33.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.787210172026926}
# ./yahoo/A1Benchmark/real_34.csv {"Precision": 0.1111111111111111, "Recall": 0.14285714285714285, "F1": 0.125, "AUROC": 0.498917748917749}
# ./yahoo/A1Benchmark/real_35.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
# ./yahoo/A1Benchmark/real_36.csv {"Precision": 0.07692307692307693, "Recall": 0.6, "F1": 0.13636363636363635, "AUROC": 0.8014749262536873}
# ./yahoo/A1Benchmark/real_37.csv {"Precision": 0.026153846153846153, "Recall": 1.0, "F1": 0.050974512743628186, "AUROC": 0.7580769230769231}
# ./yahoo/A1Benchmark/real_38.csv {"Precision": 0.006782215523737754, "Recall": 1.0, "F1": 0.01347305389221557, "AUROC": 0.2486511549485753}
# ./yahoo/A1Benchmark/real_39.csv {"Precision": 1.0, "Recall": 0.6, "F1": 0.75, "AUROC": 0.8871678056188307}
# ./yahoo/A1Benchmark/real_4.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.9582701062215477}
# ./yahoo/A1Benchmark/real_40.csv {"Precision": 0.3910891089108911, "Recall": 0.9875, "F1": 0.5602836879432624, "AUROC": 0.9729350441058541}
# ./yahoo/A1Benchmark/real_41.csv {"Precision": 0.009523809523809525, "Recall": 0.3333333333333333, "F1": 0.018518518518518517, "AUROC": 0.481981981981982}
# ./yahoo/A1Benchmark/real_42.csv {"Precision": 0.2857142857142857, "Recall": 1.0, "F1": 0.4444444444444444, "AUROC": 0.9948267396184063}
# ./yahoo/A1Benchmark/real_43.csv {"Precision": 0.8333333333333334, "Recall": 0.15625, "F1": 0.2631578947368421, "AUROC": 0.6682315558103976}
# ./yahoo/A1Benchmark/real_44.csv {"Precision": 0.5, "Recall": 0.6666666666666666, "F1": 0.5714285714285714, "AUROC": 0.986439842209073}
# ./yahoo/A1Benchmark/real_45.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.3749066467513069}
# ./yahoo/A1Benchmark/real_46.csv {"Precision": 0.9385964912280702, "Recall": 0.981651376146789, "F1": 0.9596412556053812, "AUROC": 0.9887071071130704}
# ./yahoo/A1Benchmark/real_47.csv {"Precision": 0.049019607843137254, "Recall": 0.5, "F1": 0.08928571428571429, "AUROC": 0.700303720577069}
# ./yahoo/A1Benchmark/real_48.csv {"Precision": 0.8518518518518519, "Recall": 0.9583333333333334, "F1": 0.9019607843137255, "AUROC": 0.9996197718631179}
# ./yahoo/A1Benchmark/real_49.csv {"Precision": 0.058823529411764705, "Recall": 0.3333333333333333, "F1": 0.1, "AUROC": 0.9867452135493372}
# ./yahoo/A1Benchmark/real_5.csv {"Precision": 0.034482758620689655, "Recall": 0.5, "F1": 0.06451612903225806, "AUROC": 0.987658937920718}
# ./yahoo/A1Benchmark/real_50.csv {"Precision": 0.005227781926811053, "Recall": 1.0, "F1": 0.010401188707280832, "AUROC": 1.0}
# ./yahoo/A1Benchmark/real_51.csv {"Precision": 0.003014318010550113, "Recall": 1.0, "F1": 0.006010518407212622, "AUROC": 0.350151171579743}
# ./yahoo/A1Benchmark/real_52.csv {"Precision": 0.13043478260869565, "Recall": 0.2727272727272727, "F1": 0.17647058823529413, "AUROC": 0.572156080104604}
# ./yahoo/A1Benchmark/real_53.csv {"Precision": 0.2571428571428571, "Recall": 0.5294117647058824, "F1": 0.34615384615384615, "AUROC": 0.9461221988795518}
# ./yahoo/A1Benchmark/real_54.csv {"Precision": 0.5, "Recall": 1.0, "F1": 0.6666666666666666, "AUROC": 0.9976525821596244}
# ./yahoo/A1Benchmark/real_55.csv {"Precision": 0.0066815144766146995, "Recall": 0.6, "F1": 0.013215859030837005, "AUROC": 0.7346444780635402}
# ./yahoo/A1Benchmark/real_56.csv {"Precision": 0.012618296529968454, "Recall": 0.8, "F1": 0.024844720496894408, "AUROC": 0.662178517397882}
# ./yahoo/A1Benchmark/real_57.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.6497259591429996}
# ./yahoo/A1Benchmark/real_58.csv {"Precision": 1.0, "Recall": 0.3953488372093023, "F1": 0.5666666666666667, "AUROC": 0.9963820289437684}
# ./yahoo/A1Benchmark/real_59.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
# ./yahoo/A1Benchmark/real_6.csv {"Precision": 0.00597460791635549, "Recall": 1.0, "F1": 0.011878247958426132, "AUROC": 0.5615138993238167}
# ./yahoo/A1Benchmark/real_60.csv {"Precision": 0.04424778761061947, "Recall": 0.3125, "F1": 0.07751937984496124, "AUROC": 0.779228624535316}
# ./yahoo/A1Benchmark/real_61.csv {"Precision": 1.0, "Recall": 0.9583333333333334, "F1": 0.9787234042553191, "AUROC": 0.9803847127309542}
# ./yahoo/A1Benchmark/real_62.csv {"Precision": 0.14285714285714285, "Recall": 0.2, "F1": 0.16666666666666666, "AUROC": 0.8952830188679245}
# ./yahoo/A1Benchmark/real_63.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.5364387678437266}
# ./yahoo/A1Benchmark/real_64.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
# ./yahoo/A1Benchmark/real_65.csv {"Precision": 0.01283987915407855, "Recall": 1.0, "F1": 0.02535421327367636, "AUROC": 0.8810927584499753}
# ./yahoo/A1Benchmark/real_66.csv {"Precision": 0.1891891891891892, "Recall": 1.0, "F1": 0.3181818181818182, "AUROC": 0.9591419069546467}
# ./yahoo/A1Benchmark/real_67.csv {"Precision": 0.5789473684210527, "Recall": 0.9565217391304348, "F1": 0.7213114754098361, "AUROC": 0.9617725752508363}
# ./yahoo/A1Benchmark/real_7.csv {"Precision": 1.0, "Recall": 0.36065573770491804, "F1": 0.5301204819277109, "AUROC": 0.875763165415292}
# ./yahoo/A1Benchmark/real_8.csv {"Precision": 0.03065134099616858, "Recall": 0.8, "F1": 0.05904059040590406, "AUROC": 0.8112213740458016}
# ./yahoo/A1Benchmark/real_9.csv {"Precision": 0.8333333333333334, "Recall": 0.625, "F1": 0.7142857142857143, "AUROC": 0.9727457501847746}
#
# # Macro mean (simple average over files)
# {"Precision": 0.2565228483603143, "Recall": 0.5547895590326827, "F1": 0.24906580245433893, "AUROC": 0.7206183930479091}
