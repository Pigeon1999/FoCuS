# %% [markdown]
# # Yahoo A1 · Vanilla RNN (Supervised, Binary) · Point-level Anomaly Detection
#
# - **Dataset path**: `./yahoo/A1Benchmark/real_*.csv`
# - **Model**: PyTorch `nn.RNN(input_size=1, hidden_size=H, num_layers=1, tanh)` → `Linear(H→1)`
# - **Task**: Supervised **binary classification** of anomalies at time `t` using past `L` values (`[t-L..t-1]`).
# - **Metrics**: Precision / Recall / F1 / Accuracy (point-level).
# - **Split per file**: 60% train / 20% val / 20% test (time order preserved).
# - **Scaling**: z-score using **train** μ,σ only.

# %% [markdown]
# ## 0) Requirements
# ```
# pip install torch numpy pandas scikit-learn
# ```

# %%
# 1) Configuration
from dataclasses import dataclass

@dataclass
class Config:
    # a1_dir: str = "./TSB-AD-U/WSD"
    a1_dir: str = "./yahoo/A1Benchmark"
    seq_len: int = 100
    hidden: int = 256
    lr: float = 1e-3
    batch: int = 256
    epochs: int = 1000
    patience: int = 15
    device: str = "cuda"  # "cuda" or "cpu"

cfg = Config()
cfg
# Out:
# Config(a1_dir='./yahoo/A1Benchmark', seq_len=100, hidden=256, lr=0.001, batch=256, epochs=1000, patience=15, device='cuda')

# %%
# 2) Imports
import random
import os, glob, json
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# SEED = 1234
# random.seed(SEED)
# np.random.seed(SEED)
# torch.manual_seed(SEED)
# torch.cuda.manual_seed_all(SEED)

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch: 2.5.1+cu124
# CUDA available: True

# %% [markdown]
# ## 3) Data utilities (Yahoo A1)

# %%
# Defensive column detection and CSV loader
def _find_cols(df: pd.DataFrame):
    ts_candidates = {"timestamp", "time", "ts", "date"}
    val_candidates = {"value", "values", "metric"}
    lab_candidates = {"is_anomaly", "anomaly", "label", "isoutlier"}
    ts_col = next((c for c in df.columns if str(c).lower() in ts_candidates), None)
    val_col = next((c for c in df.columns if str(c).lower() in val_candidates), None)
    lab_col = next((c for c in df.columns if str(c).lower() in lab_candidates), None)
    if val_col is None or lab_col is None:
        raise ValueError(f"Required columns not found in CSV. Columns: {df.columns.tolist()}")
    return ts_col, val_col, lab_col

def load_yahoo_a1(csv_path: str):
    df = pd.read_csv(csv_path)
    ts_col, val_col, lab_col = _find_cols(df)
    if ts_col is not None:
        df = df.sort_values(ts_col)
    x = df[val_col].to_numpy(dtype=np.float32)
    y = df[lab_col].astype(int).to_numpy()
    return x, y

def load_wsd(csv_path: str):
    df = pd.read_csv(csv_path)
    data_col = df.columns[0]
    label_col = df.columns[1]
    x = df[data_col].to_numpy(dtype=np.float32)
    y = df[label_col].astype(int).to_numpy()
    return x, y

def fit_robust_scaler(x_train: np.ndarray, cfg):
    # sklearn expects 2D; our series is 1D → reshape
    rs = RobustScaler()
    rs.fit(x_train.reshape(-1, 1))
    return rs

def apply_scaler(x: np.ndarray, scaler: RobustScaler):
    return scaler.transform(x.reshape(-1, 1)).astype(np.float32).squeeze(-1)

def make_windows(x: np.ndarray, y: np.ndarray, L: int):
    Xs, Ys, idx = [], [], []
    for t in range(L, len(x)):
        Xs.append(x[t - L:t])
        Ys.append(y[t])
        idx.append(t)
    X = np.asarray(Xs, dtype=np.float32)[..., None]  # [N, L, 1]
    Y = np.asarray(Ys, dtype=np.int64)               # [N]
    return X, Y, np.asarray(idx)

class WindowDataset(Dataset):
    def __init__(self, X: np.ndarray, Y: np.ndarray):
        self.X = torch.from_numpy(X)       # [N, L, 1]
        self.Y = torch.from_numpy(Y)       # [N]
    def __len__(self): return self.X.shape[0]
    def __getitem__(self, i):
        return self.X[i], self.Y[i]

def compute_pos_weight(y_train: np.ndarray) -> float:
    pos = int((y_train == 1).sum())
    neg = int((y_train == 0).sum())
    if pos == 0:
        return 1.0
    return float(neg / pos)

# %% [markdown]
# ## 4) Model (Vanilla RNN → Binary)

# %%
class VanillaRNNBinary(nn.Module):
    def __init__(self, hidden_size: int = 64):
        super().__init__()
        self.rnn = nn.RNN(
            input_size=1,
            hidden_size=hidden_size,
            num_layers=1,
            nonlinearity="tanh",
            batch_first=True,
        )
        self.head = nn.Linear(hidden_size, 1)  # logit output

    def forward(self, x):           # x: [B, L, 1]
        out, _ = self.rnn(x)        # [B, L, H]
        h_last = out[:, -1, :]      # [B, H]
        logit = self.head(h_last)   # [B, 1]
        return logit.squeeze(-1)    # [B]

class VanillaLSTMBinary(nn.Module):
    def __init__(self, hidden_size: int = 64):
        super().__init__()
        # nn.RNN -> nn.LSTM
        self.lstm = nn.LSTM(
            input_size=1,
            hidden_size=hidden_size,
            num_layers=1,       # 1-layer (Vanilla)
            batch_first=True,
        )
        self.head = nn.Linear(hidden_size, 1)  # 동일한 헤드

    def forward(self, x):          # x: [B, L, 1]
        # self.rnn(x) -> self.lstm(x)
        out, _ = self.lstm(x)     # out shape: [B, L, H]
        
        # 동일한 로직: 마지막 hidden state 사용
        h_last = out[:, -1, :]    # [B, H]
        
        logit = self.head(h_last)   # [B, 1]
        return logit.squeeze(-1)    # [B]
    
class VanillaGRUBinary(nn.Module):
    def __init__(self, hidden_size: int = 64):
        super().__init__()
        # nn.RNN -> nn.GRU
        self.gru = nn.GRU(
            input_size=1,
            hidden_size=hidden_size,
            num_layers=1,       # 1-layer (Vanilla)
            batch_first=True,
        )
        self.head = nn.Linear(hidden_size, 1)  # 동일한 헤드

    def forward(self, x):          # x: [B, L, 1]
        # self.rnn(x) -> self.gru(x)
        out, _ = self.gru(x)      # out shape: [B, L, H]
        
        # 동일한 로직: 마지막 hidden state 사용
        h_last = out[:, -1, :]    # [B, H]
        
        logit = self.head(h_last)   # [B, 1]
        return logit.squeeze(-1)    # [B]

# %% [markdown]
# ## 5) Train & Evaluation Functions

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total = 0.0
    for X, Y in loader:
        X = X.to(device)
        Y = Y.to(device).float()
        logit = model(X)
        loss = criterion(logit, Y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total += loss.item() * X.size(0)
    return total / max(1, len(loader.dataset))

@torch.no_grad()
def infer_probs(model, loader, device):
    model.eval()
    probs, labels = [], []
    for X, Y in loader:
        X = X.to(device)
        p = torch.sigmoid(model(X)).cpu().numpy()
        probs.append(p)
        labels.append(Y.numpy())
    return np.concatenate(probs), np.concatenate(labels)

def metrics_prfa(y_true: np.ndarray, y_prob: np.ndarray, thr: float = 0.5):
    y_pred = (y_prob >= thr).astype(np.int64)
    P = precision_score(y_true, y_pred, zero_division=0)
    R = recall_score(y_true, y_pred, zero_division=0)
    F1 = f1_score(y_true, y_pred, zero_division=0)
    # AUROC는 예측 확률값(y_prob)을 직접 사용
    try:
        auroc = roc_auc_score(y_true, y_prob)
    except ValueError:  # 단일 클래스만 있는 경우
        auroc = 0.0
    return {
        "Precision": float(P),
        "Recall": float(R),
        "F1": float(F1),
        "AUROC": float(auroc)
    }

# %% [markdown]
# ## 6) Per-file Training & Testing Pipeline

# %%
# === 붙일 함수: F1이 최대가 되는 threshold 탐색 ===
import numpy as np
from sklearn.metrics import f1_score

def find_best_threshold(y_true, y_prob, grid=None):
    if grid is None:
        grid = np.linspace(0.05, 0.95, 19)  # 0.05 ~ 0.95
    best_thr, best_f1 = 0.5, -1.0
    for thr in grid:
        f1 = f1_score(y_true, (y_prob >= thr).astype(int), zero_division=0)
        if f1 > best_f1:
            best_f1, best_thr = f1, thr
    return float(best_thr), float(best_f1)

def run_one_file(csv_path: str, cfg):
    # Load
    x, y = load_yahoo_a1(csv_path)
    # x, y = load_wsd(csv_path)
    n = len(x)
    if n < cfg.seq_len + 10:
        raise ValueError(f"Series too short for seq_len={cfg.seq_len}: {csv_path}")

    # Split (time order preserved): 60/20/20
    n_tr, n_va = int(0.6 * n), int(0.8 * n)
    x_tr, x_va, x_te = x[:n_tr], x[n_tr:n_va], x[n_va:]
    y_tr, y_va, y_te = y[:n_tr], y[n_tr:n_va], y[n_va:]

    # Scale using TRAIN only
    rs = fit_robust_scaler(x_tr, cfg)
    x_tr = apply_scaler(x_tr, rs)
    x_va = apply_scaler(x_va, rs)
    x_te = apply_scaler(x_te, rs)

    # Windows (labels at current t)
    L = cfg.seq_len
    Xtr, Ytr, _ = make_windows(x_tr, y_tr, L)
    Xva, Yva, _ = make_windows(np.concatenate([x_tr, x_va]),
                               np.concatenate([y_tr, y_va]), L)
    Xte, Yte, _ = make_windows(np.concatenate([x_tr, x_va, x_te]),
                               np.concatenate([y_tr, y_va, y_te]), L)

    # DataLoaders
    ds_tr, ds_va, ds_te = WindowDataset(Xtr, Ytr), WindowDataset(Xva, Yva), WindowDataset(Xte, Yte)
    dl_tr = DataLoader(ds_tr, batch_size=cfg.batch, shuffle=True)
    dl_va = DataLoader(ds_va, batch_size=cfg.batch, shuffle=False)
    dl_te = DataLoader(ds_te, batch_size=cfg.batch, shuffle=False)

    # Model / Loss / Optim
    device = cfg.device if (cfg.device == "cpu" or torch.cuda.is_available()) else "cpu"
    model = VanillaRNNBinary(hidden_size=cfg.hidden).to(device)
    # model = VanillaLSTMBinary(hidden_size=cfg.hidden).to(device)
    # model = VanillaGRUBinary(hidden_size=cfg.hidden).to(device)
    pos_w = compute_pos_weight(Ytr)
    criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([pos_w], device=device))
    optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=1e-3)

    # Train with early stopping on val F1
    best_f1, best_state, bad = -1.0, None, 0
    for ep in range(1, cfg.epochs + 1):
        _ = train_one_epoch(model, dl_tr, optimizer, criterion, device)
        p_va, y_va = infer_probs(model, dl_va, device)
        f1 = metrics_prfa(y_va, p_va)["F1"]
        if f1 > best_f1:
            best_f1 = f1
            best_state = {k: v.detach().cpu() for k, v in model.state_dict().items()}
            bad = 0
        else:
            bad += 1
        # Simple log
        if ep % 5 == 0 or bad == 0:
            print(f"[{os.path.basename(csv_path)}] epoch {ep} valF1={f1:.4f} best={best_f1:.4f}, bad={bad}")
        if bad >= cfg.patience:
            break

    if best_state is not None:
        model.load_state_dict(best_state)

    p_va, y_va = infer_probs(model, dl_va, device)
    best_thr, best_va_f1 = find_best_threshold(y_va, p_va)

    p_te, y_te = infer_probs(model, dl_te, device)
    return metrics_prfa(y_te, p_te, thr=best_thr)

# %% [markdown]
# ## 7) Evaluate Over All A1 Files

# %%
def evaluate_all(cfg):
    # paths = sorted(glob.glob(os.path.join(cfg.a1_dir, "real_*.csv")))
    # if not paths:
    #     raise FileNotFoundError(f"No files matched: {cfg.a1_dir}/real_*.csv")
    
    paths = sorted(glob.glob(os.path.join(cfg.a1_dir, "*.csv")))
    if not paths:
        raise FileNotFoundError(f"No files matched: {cfg.a1_dir}/*.csv")
    rows = []
    for p in paths:
        print(f"\n### Processing: {p}")
        m = run_one_file(p, cfg)
        rows.append(m)
        print("=> Test metrics:", json.dumps(m, ensure_ascii=False))
    keys = rows[0].keys()
    macro = {k: float(np.mean([r[k] for r in rows])) for k in keys}
    return paths, rows, macro

paths, rows, macro = evaluate_all(cfg)

print("\n# Per-file metrics (Precision/Recall/F1/Accuracy)")
for p, m in zip(paths, rows):
    print(p, json.dumps(m, ensure_ascii=False))

print("\n# Macro mean (simple average over files)")
print(json.dumps(macro, ensure_ascii=False))
# Out:
# ### Processing: ./yahoo/A1Benchmark/real_1.csv
# [real_1.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_1.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_1.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_1.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0015151515151515152, "Recall": 1.0, "F1": 0.0030257186081694403, "AUROC": 0.48216995447647953}
#
# ### Processing: ./yahoo/A1Benchmark/real_10.csv
# [real_10.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_10.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_10.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_10.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.009708737864077669, "Recall": 1.0, "F1": 0.019230769230769232, "AUROC": 0.7061724097923192}
#
# ### Processing: ./yahoo/A1Benchmark/real_11.csv
# [real_11.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_11.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_11.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_11.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.014189693801344288, "Recall": 1.0, "F1": 0.027982326951399118, "AUROC": 0.06020733652312599}
#
# ### Processing: ./yahoo/A1Benchmark/real_12.csv
# [real_12.csv] epoch 1 valF1=0.0019 best=0.0019, bad=0
# [real_12.csv] epoch 2 valF1=0.0040 best=0.0040, bad=0
# [real_12.csv] epoch 3 valF1=0.0056 best=0.0056, bad=0
# [real_12.csv] epoch 5 valF1=0.0047 best=0.0056, bad=2
# [real_12.csv] epoch 6 valF1=0.0066 best=0.0066, bad=0
# [real_12.csv] epoch 8 valF1=0.0244 best=0.0244, bad=0
# [real_12.csv] epoch 10 valF1=0.0065 best=0.0244, bad=2
# [real_12.csv] epoch 15 valF1=0.0000 best=0.0244, bad=7
# [real_12.csv] epoch 20 valF1=0.0019 best=0.0244, bad=12
# => Test metrics: {"Precision": 0.01639344262295082, "Recall": 0.6666666666666666, "F1": 0.032, "AUROC": 0.7697105788423153}
#
# ### Processing: ./yahoo/A1Benchmark/real_13.csv
# [real_13.csv] epoch 1 valF1=0.0181 best=0.0181, bad=0
# [real_13.csv] epoch 2 valF1=0.0251 best=0.0251, bad=0
# [real_13.csv] epoch 3 valF1=0.0741 best=0.0741, bad=0
# [real_13.csv] epoch 5 valF1=0.0000 best=0.0741, bad=2
# [real_13.csv] epoch 10 valF1=0.0229 best=0.0741, bad=7
# [real_13.csv] epoch 15 valF1=0.0219 best=0.0741, bad=12
# => Test metrics: {"Precision": 0.15384615384615385, "Recall": 0.3333333333333333, "F1": 0.21052631578947367, "AUROC": 0.8207736749560411}
#
# ### Processing: ./yahoo/A1Benchmark/real_14.csv
# [real_14.csv] epoch 1 valF1=0.0370 best=0.0370, bad=0
# [real_14.csv] epoch 2 valF1=0.0408 best=0.0408, bad=0
# [real_14.csv] epoch 3 valF1=0.0571 best=0.0571, bad=0
# [real_14.csv] epoch 4 valF1=0.1176 best=0.1176, bad=0
# [real_14.csv] epoch 5 valF1=0.0952 best=0.1176, bad=1
# [real_14.csv] epoch 9 valF1=0.1600 best=0.1600, bad=0
# [real_14.csv] epoch 10 valF1=0.0541 best=0.1600, bad=1
# [real_14.csv] epoch 15 valF1=0.0061 best=0.1600, bad=6
# [real_14.csv] epoch 16 valF1=0.4000 best=0.4000, bad=0
# [real_14.csv] epoch 20 valF1=0.1600 best=0.4000, bad=4
# [real_14.csv] epoch 25 valF1=0.2353 best=0.4000, bad=9
# [real_14.csv] epoch 30 valF1=0.0909 best=0.4000, bad=14
# => Test metrics: {"Precision": 0.5, "Recall": 0.5, "F1": 0.5, "AUROC": 0.9902767389678385}
#
# ### Processing: ./yahoo/A1Benchmark/real_15.csv
# [real_15.csv] epoch 1 valF1=0.0117 best=0.0117, bad=0
# [real_15.csv] epoch 2 valF1=0.0188 best=0.0188, bad=0
# [real_15.csv] epoch 5 valF1=0.0000 best=0.0188, bad=3
# [real_15.csv] epoch 10 valF1=0.0169 best=0.0188, bad=8
# [real_15.csv] epoch 11 valF1=0.0239 best=0.0239, bad=0
# [real_15.csv] epoch 15 valF1=0.0348 best=0.0348, bad=0
# [real_15.csv] epoch 20 valF1=0.0168 best=0.0348, bad=5
# [real_15.csv] epoch 25 valF1=0.0164 best=0.0348, bad=10
# [real_15.csv] epoch 30 valF1=0.0138 best=0.0348, bad=15
# => Test metrics: {"Precision": 0.03773584905660377, "Recall": 0.2, "F1": 0.06349206349206349, "AUROC": 0.7672686230248307}
#
# ### Processing: ./yahoo/A1Benchmark/real_16.csv
# [real_16.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_16.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_16.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_16.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.002204261572373255, "Recall": 1.0, "F1": 0.004398826979472141, "AUROC": 0.6026018654884634}
#
# ### Processing: ./yahoo/A1Benchmark/real_17.csv
# [real_17.csv] epoch 1 valF1=0.6138 best=0.6138, bad=0
# [real_17.csv] epoch 2 valF1=0.8720 best=0.8720, bad=0
# [real_17.csv] epoch 5 valF1=0.9256 best=0.9256, bad=0
# [real_17.csv] epoch 6 valF1=0.9568 best=0.9568, bad=0
# [real_17.csv] epoch 10 valF1=0.8614 best=0.9568, bad=4
# [real_17.csv] epoch 15 valF1=0.9505 best=0.9568, bad=9
# [real_17.csv] epoch 20 valF1=0.9574 best=0.9574, bad=0
# [real_17.csv] epoch 25 valF1=0.6501 best=0.9574, bad=5
# [real_17.csv] epoch 30 valF1=0.5849 best=0.9574, bad=10
# [real_17.csv] epoch 35 valF1=0.5979 best=0.9574, bad=15
# => Test metrics: {"Precision": 0.9567099567099567, "Recall": 0.973568281938326, "F1": 0.9650655021834061, "AUROC": 0.9907035206148929}
#
# ### Processing: ./yahoo/A1Benchmark/real_18.csv
# [real_18.csv] epoch 1 valF1=0.0118 best=0.0118, bad=0
# [real_18.csv] epoch 5 valF1=0.0153 best=0.0153, bad=0
# [real_18.csv] epoch 10 valF1=0.0143 best=0.0153, bad=5
# [real_18.csv] epoch 14 valF1=0.0167 best=0.0167, bad=0
# [real_18.csv] epoch 15 valF1=0.0225 best=0.0225, bad=0
# [real_18.csv] epoch 16 valF1=0.0909 best=0.0909, bad=0
# [real_18.csv] epoch 17 valF1=0.5714 best=0.5714, bad=0
# [real_18.csv] epoch 20 valF1=0.0361 best=0.5714, bad=3
# [real_18.csv] epoch 25 valF1=0.0909 best=0.5714, bad=8
# [real_18.csv] epoch 30 valF1=0.0080 best=0.5714, bad=13
# => Test metrics: {"Precision": 0.5, "Recall": 0.6666666666666666, "F1": 0.5714285714285714, "AUROC": 0.9398625429553265}
#
# ### Processing: ./yahoo/A1Benchmark/real_19.csv
# [real_19.csv] epoch 1 valF1=0.6131 best=0.6131, bad=0
# [real_19.csv] epoch 2 valF1=0.8103 best=0.8103, bad=0
# [real_19.csv] epoch 4 valF1=0.9137 best=0.9137, bad=0
# [real_19.csv] epoch 5 valF1=0.9443 best=0.9443, bad=0
# [real_19.csv] epoch 10 valF1=0.9474 best=0.9474, bad=0
# [real_19.csv] epoch 14 valF1=0.9477 best=0.9477, bad=0
# [real_19.csv] epoch 15 valF1=0.9539 best=0.9539, bad=0
# [real_19.csv] epoch 20 valF1=0.9385 best=0.9539, bad=5
# [real_19.csv] epoch 25 valF1=0.9446 best=0.9539, bad=10
# [real_19.csv] epoch 26 valF1=0.9571 best=0.9571, bad=0
# [real_19.csv] epoch 28 valF1=0.9574 best=0.9574, bad=0
# [real_19.csv] epoch 30 valF1=0.9446 best=0.9574, bad=2
# [real_19.csv] epoch 35 valF1=0.9325 best=0.9574, bad=7
# [real_19.csv] epoch 40 valF1=0.9416 best=0.9574, bad=12
# => Test metrics: {"Precision": 0.973568281938326, "Recall": 0.973568281938326, "F1": 0.973568281938326, "AUROC": 0.9878965058891088}
#
# ### Processing: ./yahoo/A1Benchmark/real_2.csv
# [real_2.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_2.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_2.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_2.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.01194921583271098, "Recall": 1.0, "F1": 0.023616236162361623, "AUROC": 0.9184145880574452}
#
# ### Processing: ./yahoo/A1Benchmark/real_20.csv
# [real_20.csv] epoch 1 valF1=0.0508 best=0.0508, bad=0
# [real_20.csv] epoch 2 valF1=0.0586 best=0.0586, bad=0
# [real_20.csv] epoch 4 valF1=0.0684 best=0.0684, bad=0
# [real_20.csv] epoch 5 valF1=0.0657 best=0.0684, bad=1
# [real_20.csv] epoch 7 valF1=0.0711 best=0.0711, bad=0
# [real_20.csv] epoch 10 valF1=0.0679 best=0.0711, bad=3
# [real_20.csv] epoch 15 valF1=0.0459 best=0.0711, bad=8
# [real_20.csv] epoch 18 valF1=0.0807 best=0.0807, bad=0
# [real_20.csv] epoch 19 valF1=0.3359 best=0.3359, bad=0
# [real_20.csv] epoch 20 valF1=0.2981 best=0.3359, bad=1
# [real_20.csv] epoch 24 valF1=0.5854 best=0.5854, bad=0
# [real_20.csv] epoch 25 valF1=0.0825 best=0.5854, bad=1
# [real_20.csv] epoch 30 valF1=0.2172 best=0.5854, bad=6
# [real_20.csv] epoch 35 valF1=0.3622 best=0.5854, bad=11
# => Test metrics: {"Precision": 0.323943661971831, "Recall": 0.696969696969697, "F1": 0.4423076923076923, "AUROC": 0.7906763523520699}
#
# ### Processing: ./yahoo/A1Benchmark/real_21.csv
# [real_21.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_21.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_21.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_21.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.004545454545454545, "Recall": 1.0, "F1": 0.00904977375565611, "AUROC": 0.16818873668188739}
#
# ### Processing: ./yahoo/A1Benchmark/real_22.csv
# [real_22.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_22.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_22.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_22.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.04772727272727273, "Recall": 1.0, "F1": 0.0911062906724512, "AUROC": 0.523291788208256}
#
# ### Processing: ./yahoo/A1Benchmark/real_23.csv
# [real_23.csv] epoch 1 valF1=0.0417 best=0.0417, bad=0
# [real_23.csv] epoch 2 valF1=0.1037 best=0.1037, bad=0
# [real_23.csv] epoch 3 valF1=0.1351 best=0.1351, bad=0
# [real_23.csv] epoch 5 valF1=0.0981 best=0.1351, bad=2
# [real_23.csv] epoch 7 valF1=0.1461 best=0.1461, bad=0
# [real_23.csv] epoch 8 valF1=0.1890 best=0.1890, bad=0
# [real_23.csv] epoch 10 valF1=0.1387 best=0.1890, bad=2
# [real_23.csv] epoch 15 valF1=0.1405 best=0.1890, bad=7
# [real_23.csv] epoch 17 valF1=0.2031 best=0.2031, bad=0
# [real_23.csv] epoch 18 valF1=0.2131 best=0.2131, bad=0
# [real_23.csv] epoch 20 valF1=0.1898 best=0.2131, bad=2
# [real_23.csv] epoch 22 valF1=0.2185 best=0.2185, bad=0
# [real_23.csv] epoch 25 valF1=0.1161 best=0.2185, bad=3
# [real_23.csv] epoch 30 valF1=0.1985 best=0.2185, bad=8
# [real_23.csv] epoch 35 valF1=0.1818 best=0.2185, bad=13
# => Test metrics: {"Precision": 0.375, "Recall": 0.631578947368421, "F1": 0.47058823529411764, "AUROC": 0.9326024515554837}
#
# ### Processing: ./yahoo/A1Benchmark/real_24.csv
# [real_24.csv] epoch 1 valF1=0.0037 best=0.0037, bad=0
# [real_24.csv] epoch 2 valF1=0.0177 best=0.0177, bad=0
# [real_24.csv] epoch 3 valF1=0.0250 best=0.0250, bad=0
# [real_24.csv] epoch 4 valF1=0.0556 best=0.0556, bad=0
# [real_24.csv] epoch 5 valF1=0.0081 best=0.0556, bad=1
# [real_24.csv] epoch 10 valF1=0.0051 best=0.0556, bad=6
# [real_24.csv] epoch 15 valF1=0.0299 best=0.0556, bad=11
# => Test metrics: {"Precision": 0.2692307692307692, "Recall": 0.875, "F1": 0.4117647058823529, "AUROC": 0.9547862453531598}
#
# ### Processing: ./yahoo/A1Benchmark/real_25.csv
# [real_25.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_25.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_25.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_25.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.03220973782771536, "Recall": 1.0, "F1": 0.062409288824383166, "AUROC": 0.015137878896968826}
#
# ### Processing: ./yahoo/A1Benchmark/real_26.csv
# [real_26.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_26.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_26.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_26.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.056179775280898875, "Recall": 1.0, "F1": 0.10638297872340426, "AUROC": 0.011142857142857133}
#
# ### Processing: ./yahoo/A1Benchmark/real_27.csv
# [real_27.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_27.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_27.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_27.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0015071590052750565, "Recall": 1.0, "F1": 0.0030097817908201654, "AUROC": 0.5479245283018868}
#
# ### Processing: ./yahoo/A1Benchmark/real_28.csv
# [real_28.csv] epoch 1 valF1=0.0151 best=0.0151, bad=0
# [real_28.csv] epoch 5 valF1=0.0102 best=0.0151, bad=4
# [real_28.csv] epoch 6 valF1=0.1760 best=0.1760, bad=0
# [real_28.csv] epoch 10 valF1=0.0061 best=0.1760, bad=4
# [real_28.csv] epoch 15 valF1=0.0000 best=0.1760, bad=9
# [real_28.csv] epoch 16 valF1=0.4125 best=0.4125, bad=0
# [real_28.csv] epoch 17 valF1=0.7149 best=0.7149, bad=0
# [real_28.csv] epoch 20 valF1=0.0049 best=0.7149, bad=3
# [real_28.csv] epoch 25 valF1=0.0053 best=0.7149, bad=8
# [real_28.csv] epoch 30 valF1=0.0053 best=0.7149, bad=13
# => Test metrics: {"Precision": 0.5642857142857143, "Recall": 0.9634146341463414, "F1": 0.7117117117117117, "AUROC": 0.9708246963327456}
#
# ### Processing: ./yahoo/A1Benchmark/real_29.csv
# [real_29.csv] epoch 1 valF1=0.0193 best=0.0193, bad=0
# [real_29.csv] epoch 5 valF1=0.0160 best=0.0193, bad=4
# [real_29.csv] epoch 6 valF1=0.0242 best=0.0242, bad=0
# [real_29.csv] epoch 10 valF1=0.0131 best=0.0242, bad=4
# [real_29.csv] epoch 15 valF1=0.0061 best=0.0242, bad=9
# [real_29.csv] epoch 18 valF1=0.0422 best=0.0422, bad=0
# [real_29.csv] epoch 20 valF1=0.0123 best=0.0422, bad=2
# [real_29.csv] epoch 25 valF1=0.0160 best=0.0422, bad=7
# [real_29.csv] epoch 28 valF1=0.0513 best=0.0513, bad=0
# [real_29.csv] epoch 29 valF1=0.0522 best=0.0522, bad=0
# [real_29.csv] epoch 30 valF1=0.0148 best=0.0522, bad=1
# [real_29.csv] epoch 35 valF1=0.0625 best=0.0625, bad=0
# [real_29.csv] epoch 40 valF1=0.0145 best=0.0625, bad=5
# [real_29.csv] epoch 45 valF1=0.0114 best=0.0625, bad=10
# [real_29.csv] epoch 50 valF1=0.0150 best=0.0625, bad=15
# => Test metrics: {"Precision": 0.2, "Recall": 0.14285714285714285, "F1": 0.16666666666666666, "AUROC": 0.6496037695437995}
#
# ### Processing: ./yahoo/A1Benchmark/real_3.csv
# [real_3.csv] epoch 1 valF1=0.0019 best=0.0019, bad=0
# [real_3.csv] epoch 2 valF1=0.0032 best=0.0032, bad=0
# [real_3.csv] epoch 3 valF1=0.0085 best=0.0085, bad=0
# [real_3.csv] epoch 4 valF1=0.0116 best=0.0116, bad=0
# [real_3.csv] epoch 5 valF1=0.0071 best=0.0116, bad=1
# [real_3.csv] epoch 10 valF1=0.0044 best=0.0116, bad=6
# [real_3.csv] epoch 15 valF1=0.0024 best=0.0116, bad=11
# => Test metrics: {"Precision": 0.19444444444444445, "Recall": 0.9333333333333333, "F1": 0.3218390804597701, "AUROC": 0.9739970282317979}
#
# ### Processing: ./yahoo/A1Benchmark/real_30.csv
# [real_30.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_30.csv] epoch 4 valF1=0.0435 best=0.0435, bad=0
# [real_30.csv] epoch 5 valF1=0.0000 best=0.0435, bad=1
# [real_30.csv] epoch 10 valF1=0.0000 best=0.0435, bad=6
# [real_30.csv] epoch 15 valF1=0.0104 best=0.0435, bad=11
# => Test metrics: {"Precision": 0.11290322580645161, "Recall": 0.7777777777777778, "F1": 0.19718309859154928, "AUROC": 0.879766600920447}
#
# ### Processing: ./yahoo/A1Benchmark/real_31.csv
# [real_31.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_31.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_31.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_31.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.01808590806330068, "Recall": 1.0, "F1": 0.03552923760177646, "AUROC": 0.9334228702993093}
#
# ### Processing: ./yahoo/A1Benchmark/real_32.csv
# [real_32.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_32.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_32.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_32.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.03541823662396383, "Recall": 1.0, "F1": 0.06841339155749636, "AUROC": 0.15564328457446808}
#
# ### Processing: ./yahoo/A1Benchmark/real_33.csv
# [real_33.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_33.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_33.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_33.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0014936519790888724, "Recall": 1.0, "F1": 0.002982848620432513, "AUROC": 0.45587135377711296}
#
# ### Processing: ./yahoo/A1Benchmark/real_34.csv
# [real_34.csv] epoch 1 valF1=0.0031 best=0.0031, bad=0
# [real_34.csv] epoch 2 valF1=0.0053 best=0.0053, bad=0
# [real_34.csv] epoch 3 valF1=0.0054 best=0.0054, bad=0
# [real_34.csv] epoch 4 valF1=0.0061 best=0.0061, bad=0
# [real_34.csv] epoch 5 valF1=0.0057 best=0.0061, bad=1
# [real_34.csv] epoch 7 valF1=0.0064 best=0.0064, bad=0
# [real_34.csv] epoch 8 valF1=0.0064 best=0.0064, bad=0
# [real_34.csv] epoch 10 valF1=0.0061 best=0.0064, bad=2
# [real_34.csv] epoch 15 valF1=0.0061 best=0.0064, bad=7
# [real_34.csv] epoch 20 valF1=0.0061 best=0.0064, bad=12
# [real_34.csv] epoch 21 valF1=0.0087 best=0.0087, bad=0
# [real_34.csv] epoch 25 valF1=0.0045 best=0.0087, bad=4
# [real_34.csv] epoch 28 valF1=0.0122 best=0.0122, bad=0
# [real_34.csv] epoch 30 valF1=0.0094 best=0.0122, bad=2
# [real_34.csv] epoch 35 valF1=0.0072 best=0.0122, bad=7
# [real_34.csv] epoch 40 valF1=0.0071 best=0.0122, bad=12
# => Test metrics: {"Precision": 0.012987012987012988, "Recall": 0.14285714285714285, "F1": 0.023809523809523808, "AUROC": 0.33549783549783546}
#
# ### Processing: ./yahoo/A1Benchmark/real_35.csv
# [real_35.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_35.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_35.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_35.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
#
# ### Processing: ./yahoo/A1Benchmark/real_36.csv
# [real_36.csv] epoch 1 valF1=0.0462 best=0.0462, bad=0
# [real_36.csv] epoch 2 valF1=0.0513 best=0.0513, bad=0
# [real_36.csv] epoch 3 valF1=0.1579 best=0.1579, bad=0
# [real_36.csv] epoch 5 valF1=0.0938 best=0.1579, bad=2
# [real_36.csv] epoch 7 valF1=0.2308 best=0.2308, bad=0
# [real_36.csv] epoch 8 valF1=0.4615 best=0.4615, bad=0
# [real_36.csv] epoch 10 valF1=0.2500 best=0.4615, bad=2
# [real_36.csv] epoch 15 valF1=0.0479 best=0.4615, bad=7
# [real_36.csv] epoch 20 valF1=0.0312 best=0.4615, bad=12
# => Test metrics: {"Precision": 0.5, "Recall": 0.6, "F1": 0.5454545454545454, "AUROC": 0.8979351032448377}
#
# ### Processing: ./yahoo/A1Benchmark/real_37.csv
# [real_37.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_37.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_37.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_37.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.025487256371814093, "Recall": 1.0, "F1": 0.049707602339181284, "AUROC": 0.06445701357466063}
#
# ### Processing: ./yahoo/A1Benchmark/real_38.csv
# [real_38.csv] epoch 1 valF1=0.0045 best=0.0045, bad=0
# [real_38.csv] epoch 3 valF1=0.0061 best=0.0061, bad=0
# [real_38.csv] epoch 4 valF1=0.0063 best=0.0063, bad=0
# [real_38.csv] epoch 5 valF1=0.0051 best=0.0063, bad=1
# [real_38.csv] epoch 10 valF1=0.0052 best=0.0063, bad=6
# [real_38.csv] epoch 15 valF1=0.0062 best=0.0063, bad=11
# [real_38.csv] epoch 16 valF1=0.0076 best=0.0076, bad=0
# [real_38.csv] epoch 20 valF1=0.0058 best=0.0076, bad=4
# [real_38.csv] epoch 25 valF1=0.0000 best=0.0076, bad=9
# [real_38.csv] epoch 30 valF1=0.0000 best=0.0076, bad=14
# => Test metrics: {"Precision": 0.015037593984962405, "Recall": 0.8888888888888888, "F1": 0.029574861367837338, "AUROC": 0.6196256954982297}
#
# ### Processing: ./yahoo/A1Benchmark/real_39.csv
# [real_39.csv] epoch 1 valF1=0.0214 best=0.0214, bad=0
# [real_39.csv] epoch 2 valF1=0.0363 best=0.0363, bad=0
# [real_39.csv] epoch 3 valF1=0.0678 best=0.0678, bad=0
# [real_39.csv] epoch 5 valF1=0.1538 best=0.1538, bad=0
# [real_39.csv] epoch 6 valF1=0.2381 best=0.2381, bad=0
# [real_39.csv] epoch 10 valF1=0.0694 best=0.2381, bad=4
# [real_39.csv] epoch 14 valF1=0.3846 best=0.3846, bad=0
# [real_39.csv] epoch 15 valF1=0.4167 best=0.4167, bad=0
# [real_39.csv] epoch 20 valF1=0.0859 best=0.4167, bad=5
# [real_39.csv] epoch 25 valF1=0.0843 best=0.4167, bad=10
# [real_39.csv] epoch 30 valF1=0.0588 best=0.4167, bad=15
# => Test metrics: {"Precision": 0.8, "Recall": 0.4, "F1": 0.5333333333333333, "AUROC": 0.7502657555049355}
#
# ### Processing: ./yahoo/A1Benchmark/real_4.csv
# [real_4.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_4.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_4.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_4.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.003779289493575208, "Recall": 1.0, "F1": 0.007530120481927711, "AUROC": 0.22534142640364188}
#
# ### Processing: ./yahoo/A1Benchmark/real_40.csv
# [real_40.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_40.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_40.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_40.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.06028636021100226, "Recall": 1.0, "F1": 0.11371712864250177, "AUROC": 0.9906776263031276}
#
# ### Processing: ./yahoo/A1Benchmark/real_41.csv
# [real_41.csv] epoch 1 valF1=0.0067 best=0.0067, bad=0
# [real_41.csv] epoch 2 valF1=0.0121 best=0.0121, bad=0
# [real_41.csv] epoch 3 valF1=0.0256 best=0.0256, bad=0
# [real_41.csv] epoch 4 valF1=0.1818 best=0.1818, bad=0
# [real_41.csv] epoch 5 valF1=0.2000 best=0.2000, bad=0
# [real_41.csv] epoch 9 valF1=0.2222 best=0.2222, bad=0
# [real_41.csv] epoch 10 valF1=0.2222 best=0.2222, bad=1
# [real_41.csv] epoch 15 valF1=0.2000 best=0.2222, bad=6
# [real_41.csv] epoch 18 valF1=0.2500 best=0.2500, bad=0
# [real_41.csv] epoch 20 valF1=0.2500 best=0.2500, bad=2
# [real_41.csv] epoch 25 valF1=0.2500 best=0.2500, bad=7
# [real_41.csv] epoch 30 valF1=0.2857 best=0.2857, bad=0
# [real_41.csv] epoch 35 valF1=0.2857 best=0.2857, bad=5
# [real_41.csv] epoch 40 valF1=0.0000 best=0.2857, bad=10
# [real_41.csv] epoch 45 valF1=0.0488 best=0.2857, bad=15
# => Test metrics: {"Precision": 0.1111111111111111, "Recall": 0.3333333333333333, "F1": 0.16666666666666666, "AUROC": 0.8681181181181181}
#
# ### Processing: ./yahoo/A1Benchmark/real_42.csv
# [real_42.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_42.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_42.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_42.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.03283582089552239, "Recall": 1.0, "F1": 0.06358381502890173, "AUROC": 0.9995966610549942}
#
# ### Processing: ./yahoo/A1Benchmark/real_43.csv
# [real_43.csv] epoch 1 valF1=0.0230 best=0.0230, bad=0
# [real_43.csv] epoch 2 valF1=0.0262 best=0.0262, bad=0
# [real_43.csv] epoch 3 valF1=0.0366 best=0.0366, bad=0
# [real_43.csv] epoch 5 valF1=0.0333 best=0.0366, bad=2
# [real_43.csv] epoch 10 valF1=0.0187 best=0.0366, bad=7
# [real_43.csv] epoch 15 valF1=0.0154 best=0.0366, bad=12
# => Test metrics: {"Precision": 0.5, "Recall": 0.15625, "F1": 0.23809523809523808, "AUROC": 0.46798547400611623}
#
# ### Processing: ./yahoo/A1Benchmark/real_44.csv
# [real_44.csv] epoch 1 valF1=0.0763 best=0.0763, bad=0
# [real_44.csv] epoch 2 valF1=0.2759 best=0.2759, bad=0
# [real_44.csv] epoch 3 valF1=0.5000 best=0.5000, bad=0
# [real_44.csv] epoch 5 valF1=0.1852 best=0.5000, bad=2
# [real_44.csv] epoch 7 valF1=0.5714 best=0.5714, bad=0
# [real_44.csv] epoch 10 valF1=0.1075 best=0.5714, bad=3
# [real_44.csv] epoch 15 valF1=0.5000 best=0.5714, bad=8
# [real_44.csv] epoch 17 valF1=0.6667 best=0.6667, bad=0
# [real_44.csv] epoch 20 valF1=0.4762 best=0.6667, bad=3
# [real_44.csv] epoch 25 valF1=0.4762 best=0.6667, bad=8
# [real_44.csv] epoch 30 valF1=0.0426 best=0.6667, bad=13
# => Test metrics: {"Precision": 0.8333333333333334, "Recall": 0.5555555555555556, "F1": 0.6666666666666666, "AUROC": 0.8237179487179488}
#
# ### Processing: ./yahoo/A1Benchmark/real_45.csv
# [real_45.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_45.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_45.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_45.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0007462686567164179, "Recall": 1.0, "F1": 0.0014914243102162564, "AUROC": 0.6960418222554146}
#
# ### Processing: ./yahoo/A1Benchmark/real_46.csv
# [real_46.csv] epoch 1 valF1=0.2927 best=0.2927, bad=0
# [real_46.csv] epoch 2 valF1=0.5404 best=0.5404, bad=0
# [real_46.csv] epoch 3 valF1=0.6383 best=0.6383, bad=0
# [real_46.csv] epoch 5 valF1=0.0670 best=0.6383, bad=2
# [real_46.csv] epoch 10 valF1=0.2071 best=0.6383, bad=7
# [real_46.csv] epoch 14 valF1=0.6524 best=0.6524, bad=0
# [real_46.csv] epoch 15 valF1=0.4602 best=0.6524, bad=1
# [real_46.csv] epoch 20 valF1=0.4246 best=0.6524, bad=6
# [real_46.csv] epoch 25 valF1=0.4440 best=0.6524, bad=11
# => Test metrics: {"Precision": 0.6369047619047619, "Recall": 0.981651376146789, "F1": 0.7725631768953068, "AUROC": 0.9887704039080186}
#
# ### Processing: ./yahoo/A1Benchmark/real_47.csv
# [real_47.csv] epoch 1 valF1=0.0243 best=0.0243, bad=0
# [real_47.csv] epoch 3 valF1=0.0298 best=0.0298, bad=0
# [real_47.csv] epoch 5 valF1=0.0281 best=0.0298, bad=2
# [real_47.csv] epoch 9 valF1=0.0303 best=0.0303, bad=0
# [real_47.csv] epoch 10 valF1=0.0306 best=0.0306, bad=0
# [real_47.csv] epoch 14 valF1=0.0415 best=0.0415, bad=0
# [real_47.csv] epoch 15 valF1=0.0408 best=0.0415, bad=1
# [real_47.csv] epoch 20 valF1=0.0253 best=0.0415, bad=6
# [real_47.csv] epoch 25 valF1=0.0304 best=0.0415, bad=11
# => Test metrics: {"Precision": 0.020202020202020204, "Recall": 0.4, "F1": 0.038461538461538464, "AUROC": 0.5672741078208049}
#
# ### Processing: ./yahoo/A1Benchmark/real_48.csv
# [real_48.csv] epoch 1 valF1=0.0933 best=0.0933, bad=0
# [real_48.csv] epoch 2 valF1=0.1229 best=0.1229, bad=0
# [real_48.csv] epoch 5 valF1=0.1368 best=0.1368, bad=0
# [real_48.csv] epoch 6 valF1=0.1538 best=0.1538, bad=0
# [real_48.csv] epoch 10 valF1=0.0781 best=0.1538, bad=4
# [real_48.csv] epoch 15 valF1=0.1221 best=0.1538, bad=9
# [real_48.csv] epoch 20 valF1=0.1228 best=0.1538, bad=14
# => Test metrics: {"Precision": 0.14285714285714285, "Recall": 0.2916666666666667, "F1": 0.1917808219178082, "AUROC": 0.8917300380228137}
#
# ### Processing: ./yahoo/A1Benchmark/real_49.csv
# [real_49.csv] epoch 1 valF1=0.0077 best=0.0077, bad=0
# [real_49.csv] epoch 2 valF1=0.0107 best=0.0107, bad=0
# [real_49.csv] epoch 4 valF1=0.0131 best=0.0131, bad=0
# [real_49.csv] epoch 5 valF1=0.0115 best=0.0131, bad=1
# [real_49.csv] epoch 6 valF1=0.2500 best=0.2500, bad=0
# [real_49.csv] epoch 10 valF1=0.0119 best=0.2500, bad=4
# [real_49.csv] epoch 15 valF1=0.0260 best=0.2500, bad=9
# [real_49.csv] epoch 16 valF1=0.4444 best=0.4444, bad=0
# [real_49.csv] epoch 20 valF1=0.0305 best=0.4444, bad=4
# [real_49.csv] epoch 25 valF1=0.0265 best=0.4444, bad=9
# [real_49.csv] epoch 30 valF1=0.0233 best=0.4444, bad=14
# => Test metrics: {"Precision": 0.5, "Recall": 0.6666666666666666, "F1": 0.5714285714285714, "AUROC": 0.948208149239077}
#
# ### Processing: ./yahoo/A1Benchmark/real_5.csv
# [real_5.csv] epoch 1 valF1=0.0200 best=0.0200, bad=0
# [real_5.csv] epoch 4 valF1=0.0258 best=0.0258, bad=0
# [real_5.csv] epoch 5 valF1=0.0190 best=0.0258, bad=1
# [real_5.csv] epoch 10 valF1=0.0064 best=0.0258, bad=6
# [real_5.csv] epoch 15 valF1=0.0180 best=0.0258, bad=11
# => Test metrics: {"Precision": 0.125, "Recall": 0.5, "F1": 0.2, "AUROC": 0.93754674644727}
#
# ### Processing: ./yahoo/A1Benchmark/real_50.csv
# [real_50.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_50.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_50.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_50.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.005227781926811053, "Recall": 1.0, "F1": 0.010401188707280832, "AUROC": 0.004290004290004288}
#
# ### Processing: ./yahoo/A1Benchmark/real_51.csv
# [real_51.csv] epoch 1 valF1=0.0072 best=0.0072, bad=0
# [real_51.csv] epoch 4 valF1=0.0120 best=0.0120, bad=0
# [real_51.csv] epoch 5 valF1=0.0066 best=0.0120, bad=1
# [real_51.csv] epoch 10 valF1=0.0000 best=0.0120, bad=6
# [real_51.csv] epoch 15 valF1=0.0057 best=0.0120, bad=11
# => Test metrics: {"Precision": 0.012987012987012988, "Recall": 0.25, "F1": 0.024691358024691357, "AUROC": 0.6793272864701436}
#
# ### Processing: ./yahoo/A1Benchmark/real_52.csv
# [real_52.csv] epoch 1 valF1=0.0096 best=0.0096, bad=0
# [real_52.csv] epoch 2 valF1=0.0197 best=0.0197, bad=0
# [real_52.csv] epoch 4 valF1=0.0249 best=0.0249, bad=0
# [real_52.csv] epoch 5 valF1=0.0200 best=0.0249, bad=1
# [real_52.csv] epoch 10 valF1=0.0149 best=0.0249, bad=6
# [real_52.csv] epoch 15 valF1=0.0073 best=0.0249, bad=11
# => Test metrics: {"Precision": 0.17391304347826086, "Recall": 0.36363636363636365, "F1": 0.23529411764705882, "AUROC": 0.8982864221319937}
#
# ### Processing: ./yahoo/A1Benchmark/real_53.csv
# [real_53.csv] epoch 1 valF1=0.0217 best=0.0217, bad=0
# [real_53.csv] epoch 2 valF1=0.0219 best=0.0219, bad=0
# [real_53.csv] epoch 5 valF1=0.0050 best=0.0219, bad=3
# [real_53.csv] epoch 10 valF1=0.0075 best=0.0219, bad=8
# [real_53.csv] epoch 15 valF1=0.0049 best=0.0219, bad=13
# => Test metrics: {"Precision": 0.14736842105263157, "Recall": 0.8235294117647058, "F1": 0.25, "AUROC": 0.9496673669467787}
#
# ### Processing: ./yahoo/A1Benchmark/real_54.csv
# [real_54.csv] epoch 1 valF1=0.0229 best=0.0229, bad=0
# [real_54.csv] epoch 2 valF1=0.1739 best=0.1739, bad=0
# [real_54.csv] epoch 5 valF1=0.2353 best=0.2353, bad=0
# [real_54.csv] epoch 10 valF1=0.0162 best=0.2353, bad=5
# [real_54.csv] epoch 15 valF1=0.0190 best=0.2353, bad=10
# [real_54.csv] epoch 20 valF1=0.0426 best=0.2353, bad=15
# => Test metrics: {"Precision": 0.13333333333333333, "Recall": 1.0, "F1": 0.23529411764705882, "AUROC": 0.9913928012519562}
#
# ### Processing: ./yahoo/A1Benchmark/real_55.csv
# [real_55.csv] epoch 1 valF1=0.0064 best=0.0064, bad=0
# [real_55.csv] epoch 2 valF1=0.0103 best=0.0103, bad=0
# [real_55.csv] epoch 3 valF1=0.0144 best=0.0144, bad=0
# [real_55.csv] epoch 5 valF1=0.0046 best=0.0144, bad=2
# [real_55.csv] epoch 10 valF1=0.0134 best=0.0144, bad=7
# [real_55.csv] epoch 13 valF1=0.0148 best=0.0148, bad=0
# [real_55.csv] epoch 14 valF1=0.0148 best=0.0148, bad=0
# [real_55.csv] epoch 15 valF1=0.0146 best=0.0148, bad=1
# [real_55.csv] epoch 20 valF1=0.0060 best=0.0148, bad=6
# [real_55.csv] epoch 25 valF1=0.0049 best=0.0148, bad=11
# => Test metrics: {"Precision": 0.00819672131147541, "Recall": 0.8, "F1": 0.016227180527383367, "AUROC": 0.6779122541603632}
#
# ### Processing: ./yahoo/A1Benchmark/real_56.csv
# [real_56.csv] epoch 1 valF1=0.0080 best=0.0080, bad=0
# [real_56.csv] epoch 2 valF1=0.0100 best=0.0100, bad=0
# [real_56.csv] epoch 3 valF1=0.0120 best=0.0120, bad=0
# [real_56.csv] epoch 4 valF1=0.0188 best=0.0188, bad=0
# [real_56.csv] epoch 5 valF1=0.0179 best=0.0188, bad=1
# [real_56.csv] epoch 6 valF1=0.0208 best=0.0208, bad=0
# [real_56.csv] epoch 10 valF1=0.0173 best=0.0208, bad=4
# [real_56.csv] epoch 14 valF1=0.0264 best=0.0264, bad=0
# [real_56.csv] epoch 15 valF1=0.0214 best=0.0264, bad=1
# [real_56.csv] epoch 20 valF1=0.0218 best=0.0264, bad=6
# [real_56.csv] epoch 21 valF1=0.0287 best=0.0287, bad=0
# [real_56.csv] epoch 24 valF1=0.0455 best=0.0455, bad=0
# [real_56.csv] epoch 25 valF1=0.0625 best=0.0625, bad=0
# [real_56.csv] epoch 30 valF1=0.0299 best=0.0625, bad=5
# [real_56.csv] epoch 35 valF1=0.0526 best=0.0625, bad=10
# [real_56.csv] epoch 36 valF1=0.0645 best=0.0645, bad=0
# [real_56.csv] epoch 40 valF1=0.0588 best=0.0645, bad=4
# [real_56.csv] epoch 45 valF1=0.0357 best=0.0645, bad=9
# [real_56.csv] epoch 50 valF1=0.0333 best=0.0645, bad=14
# => Test metrics: {"Precision": 0.125, "Recall": 0.2, "F1": 0.15384615384615385, "AUROC": 0.8071104387291982}
#
# ### Processing: ./yahoo/A1Benchmark/real_57.csv
# [real_57.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_57.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_57.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_57.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.002238805970149254, "Recall": 1.0, "F1": 0.004467609828741623, "AUROC": 0.5904334828101644}
#
# ### Processing: ./yahoo/A1Benchmark/real_58.csv
# [real_58.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_58.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_58.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_58.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.03220973782771536, "Recall": 1.0, "F1": 0.062409288824383166, "AUROC": 0.9832061343509252}
#
# ### Processing: ./yahoo/A1Benchmark/real_59.csv
# [real_59.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_59.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_59.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_59.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
#
# ### Processing: ./yahoo/A1Benchmark/real_6.csv
# [real_6.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_6.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_6.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_6.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.00597460791635549, "Recall": 1.0, "F1": 0.011878247958426132, "AUROC": 0.7160030052592036}
#
# ### Processing: ./yahoo/A1Benchmark/real_60.csv
# [real_60.csv] epoch 1 valF1=0.0161 best=0.0161, bad=0
# [real_60.csv] epoch 3 valF1=0.0211 best=0.0211, bad=0
# [real_60.csv] epoch 4 valF1=0.1860 best=0.1860, bad=0
# [real_60.csv] epoch 5 valF1=0.1714 best=0.1860, bad=1
# [real_60.csv] epoch 8 valF1=0.2162 best=0.2162, bad=0
# [real_60.csv] epoch 10 valF1=0.1951 best=0.2162, bad=2
# [real_60.csv] epoch 15 valF1=0.0243 best=0.2162, bad=7
# [real_60.csv] epoch 20 valF1=0.0196 best=0.2162, bad=12
# => Test metrics: {"Precision": 0.35714285714285715, "Recall": 0.625, "F1": 0.45454545454545453, "AUROC": 0.8842936802973977}
#
# ### Processing: ./yahoo/A1Benchmark/real_61.csv
# [real_61.csv] epoch 1 valF1=0.0779 best=0.0779, bad=0
# [real_61.csv] epoch 3 valF1=0.0803 best=0.0803, bad=0
# [real_61.csv] epoch 4 valF1=0.0840 best=0.0840, bad=0
# [real_61.csv] epoch 5 valF1=0.0864 best=0.0864, bad=0
# [real_61.csv] epoch 10 valF1=0.0839 best=0.0864, bad=5
# [real_61.csv] epoch 15 valF1=0.0919 best=0.0919, bad=0
# [real_61.csv] epoch 20 valF1=0.0786 best=0.0919, bad=5
# [real_61.csv] epoch 25 valF1=0.0780 best=0.0919, bad=10
# [real_61.csv] epoch 30 valF1=0.0812 best=0.0919, bad=15
# => Test metrics: {"Precision": 0.034161490683229816, "Recall": 0.9166666666666666, "F1": 0.0658682634730539, "AUROC": 0.6950771956466717}
#
# ### Processing: ./yahoo/A1Benchmark/real_62.csv
# [real_62.csv] epoch 1 valF1=0.0049 best=0.0049, bad=0
# [real_62.csv] epoch 2 valF1=0.0150 best=0.0150, bad=0
# [real_62.csv] epoch 5 valF1=0.0118 best=0.0150, bad=3
# [real_62.csv] epoch 10 valF1=0.0093 best=0.0150, bad=8
# [real_62.csv] epoch 15 valF1=0.0096 best=0.0150, bad=13
# => Test metrics: {"Precision": 0.021621621621621623, "Recall": 0.8, "F1": 0.042105263157894736, "AUROC": 0.8424528301886792}
#
# ### Processing: ./yahoo/A1Benchmark/real_63.csv
# [real_63.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_63.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_63.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_63.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.00597460791635549, "Recall": 1.0, "F1": 0.011878247958426132, "AUROC": 0.009109691960931629}
#
# ### Processing: ./yahoo/A1Benchmark/real_64.csv
# [real_64.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_64.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_64.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_64.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
#
# ### Processing: ./yahoo/A1Benchmark/real_65.csv
# [real_65.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_65.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_65.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_65.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.01283987915407855, "Recall": 1.0, "F1": 0.02535421327367636, "AUROC": 0.9504928214591116}
#
# ### Processing: ./yahoo/A1Benchmark/real_66.csv
# [real_66.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_66.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_66.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_66.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.015861027190332326, "Recall": 1.0, "F1": 0.031226765799256505, "AUROC": 0.9939334137338742}
#
# ### Processing: ./yahoo/A1Benchmark/real_67.csv
# [real_67.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_67.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_67.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_67.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.017384731670445956, "Recall": 1.0, "F1": 0.03417533432392273, "AUROC": 0.9616722408026755}
#
# ### Processing: ./yahoo/A1Benchmark/real_7.csv
# [real_7.csv] epoch 1 valF1=0.0484 best=0.0484, bad=0
# [real_7.csv] epoch 5 valF1=0.0436 best=0.0484, bad=4
# [real_7.csv] epoch 6 valF1=0.5000 best=0.5000, bad=0
# [real_7.csv] epoch 10 valF1=0.1917 best=0.5000, bad=4
# [real_7.csv] epoch 15 valF1=0.1749 best=0.5000, bad=9
# [real_7.csv] epoch 20 valF1=0.1098 best=0.5000, bad=14
# => Test metrics: {"Precision": 0.4107142857142857, "Recall": 0.3770491803278688, "F1": 0.39316239316239315, "AUROC": 0.6212621132212724}
#
# ### Processing: ./yahoo/A1Benchmark/real_8.csv
# [real_8.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [real_8.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [real_8.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [real_8.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.03255813953488372, "Recall": 0.7, "F1": 0.06222222222222222, "AUROC": 0.7385496183206106}
#
# ### Processing: ./yahoo/A1Benchmark/real_9.csv
# [real_9.csv] epoch 1 valF1=0.0356 best=0.0356, bad=0
# [real_9.csv] epoch 2 valF1=0.2105 best=0.2105, bad=0
# [real_9.csv] epoch 5 valF1=0.2353 best=0.2353, bad=0
# [real_9.csv] epoch 6 valF1=0.2581 best=0.2581, bad=0
# [real_9.csv] epoch 10 valF1=0.2105 best=0.2581, bad=4
# [real_9.csv] epoch 15 valF1=0.2000 best=0.2581, bad=9
# [real_9.csv] epoch 20 valF1=0.0825 best=0.2581, bad=14
# => Test metrics: {"Precision": 0.2222222222222222, "Recall": 0.5, "F1": 0.3076923076923077, "AUROC": 0.8806356245380634}
#
# # Per-file metrics (Precision/Recall/F1/Accuracy)
# ./yahoo/A1Benchmark/real_1.csv {"Precision": 0.0015151515151515152, "Recall": 1.0, "F1": 0.0030257186081694403, "AUROC": 0.48216995447647953}
# ./yahoo/A1Benchmark/real_10.csv {"Precision": 0.009708737864077669, "Recall": 1.0, "F1": 0.019230769230769232, "AUROC": 0.7061724097923192}
# ./yahoo/A1Benchmark/real_11.csv {"Precision": 0.014189693801344288, "Recall": 1.0, "F1": 0.027982326951399118, "AUROC": 0.06020733652312599}
# ./yahoo/A1Benchmark/real_12.csv {"Precision": 0.01639344262295082, "Recall": 0.6666666666666666, "F1": 0.032, "AUROC": 0.7697105788423153}
# ./yahoo/A1Benchmark/real_13.csv {"Precision": 0.15384615384615385, "Recall": 0.3333333333333333, "F1": 0.21052631578947367, "AUROC": 0.8207736749560411}
# ./yahoo/A1Benchmark/real_14.csv {"Precision": 0.5, "Recall": 0.5, "F1": 0.5, "AUROC": 0.9902767389678385}
# ./yahoo/A1Benchmark/real_15.csv {"Precision": 0.03773584905660377, "Recall": 0.2, "F1": 0.06349206349206349, "AUROC": 0.7672686230248307}
# ./yahoo/A1Benchmark/real_16.csv {"Precision": 0.002204261572373255, "Recall": 1.0, "F1": 0.004398826979472141, "AUROC": 0.6026018654884634}
# ./yahoo/A1Benchmark/real_17.csv {"Precision": 0.9567099567099567, "Recall": 0.973568281938326, "F1": 0.9650655021834061, "AUROC": 0.9907035206148929}
# ./yahoo/A1Benchmark/real_18.csv {"Precision": 0.5, "Recall": 0.6666666666666666, "F1": 0.5714285714285714, "AUROC": 0.9398625429553265}
# ./yahoo/A1Benchmark/real_19.csv {"Precision": 0.973568281938326, "Recall": 0.973568281938326, "F1": 0.973568281938326, "AUROC": 0.9878965058891088}
# ./yahoo/A1Benchmark/real_2.csv {"Precision": 0.01194921583271098, "Recall": 1.0, "F1": 0.023616236162361623, "AUROC": 0.9184145880574452}
# ./yahoo/A1Benchmark/real_20.csv {"Precision": 0.323943661971831, "Recall": 0.696969696969697, "F1": 0.4423076923076923, "AUROC": 0.7906763523520699}
# ./yahoo/A1Benchmark/real_21.csv {"Precision": 0.004545454545454545, "Recall": 1.0, "F1": 0.00904977375565611, "AUROC": 0.16818873668188739}
# ./yahoo/A1Benchmark/real_22.csv {"Precision": 0.04772727272727273, "Recall": 1.0, "F1": 0.0911062906724512, "AUROC": 0.523291788208256}
# ./yahoo/A1Benchmark/real_23.csv {"Precision": 0.375, "Recall": 0.631578947368421, "F1": 0.47058823529411764, "AUROC": 0.9326024515554837}
# ./yahoo/A1Benchmark/real_24.csv {"Precision": 0.2692307692307692, "Recall": 0.875, "F1": 0.4117647058823529, "AUROC": 0.9547862453531598}
# ./yahoo/A1Benchmark/real_25.csv {"Precision": 0.03220973782771536, "Recall": 1.0, "F1": 0.062409288824383166, "AUROC": 0.015137878896968826}
# ./yahoo/A1Benchmark/real_26.csv {"Precision": 0.056179775280898875, "Recall": 1.0, "F1": 0.10638297872340426, "AUROC": 0.011142857142857133}
# ./yahoo/A1Benchmark/real_27.csv {"Precision": 0.0015071590052750565, "Recall": 1.0, "F1": 0.0030097817908201654, "AUROC": 0.5479245283018868}
# ./yahoo/A1Benchmark/real_28.csv {"Precision": 0.5642857142857143, "Recall": 0.9634146341463414, "F1": 0.7117117117117117, "AUROC": 0.9708246963327456}
# ./yahoo/A1Benchmark/real_29.csv {"Precision": 0.2, "Recall": 0.14285714285714285, "F1": 0.16666666666666666, "AUROC": 0.6496037695437995}
# ./yahoo/A1Benchmark/real_3.csv {"Precision": 0.19444444444444445, "Recall": 0.9333333333333333, "F1": 0.3218390804597701, "AUROC": 0.9739970282317979}
# ./yahoo/A1Benchmark/real_30.csv {"Precision": 0.11290322580645161, "Recall": 0.7777777777777778, "F1": 0.19718309859154928, "AUROC": 0.879766600920447}
# ./yahoo/A1Benchmark/real_31.csv {"Precision": 0.01808590806330068, "Recall": 1.0, "F1": 0.03552923760177646, "AUROC": 0.9334228702993093}
# ./yahoo/A1Benchmark/real_32.csv {"Precision": 0.03541823662396383, "Recall": 1.0, "F1": 0.06841339155749636, "AUROC": 0.15564328457446808}
# ./yahoo/A1Benchmark/real_33.csv {"Precision": 0.0014936519790888724, "Recall": 1.0, "F1": 0.002982848620432513, "AUROC": 0.45587135377711296}
# ./yahoo/A1Benchmark/real_34.csv {"Precision": 0.012987012987012988, "Recall": 0.14285714285714285, "F1": 0.023809523809523808, "AUROC": 0.33549783549783546}
# ./yahoo/A1Benchmark/real_35.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
# ./yahoo/A1Benchmark/real_36.csv {"Precision": 0.5, "Recall": 0.6, "F1": 0.5454545454545454, "AUROC": 0.8979351032448377}
# ./yahoo/A1Benchmark/real_37.csv {"Precision": 0.025487256371814093, "Recall": 1.0, "F1": 0.049707602339181284, "AUROC": 0.06445701357466063}
# ./yahoo/A1Benchmark/real_38.csv {"Precision": 0.015037593984962405, "Recall": 0.8888888888888888, "F1": 0.029574861367837338, "AUROC": 0.6196256954982297}
# ./yahoo/A1Benchmark/real_39.csv {"Precision": 0.8, "Recall": 0.4, "F1": 0.5333333333333333, "AUROC": 0.7502657555049355}
# ./yahoo/A1Benchmark/real_4.csv {"Precision": 0.003779289493575208, "Recall": 1.0, "F1": 0.007530120481927711, "AUROC": 0.22534142640364188}
# ./yahoo/A1Benchmark/real_40.csv {"Precision": 0.06028636021100226, "Recall": 1.0, "F1": 0.11371712864250177, "AUROC": 0.9906776263031276}
# ./yahoo/A1Benchmark/real_41.csv {"Precision": 0.1111111111111111, "Recall": 0.3333333333333333, "F1": 0.16666666666666666, "AUROC": 0.8681181181181181}
# ./yahoo/A1Benchmark/real_42.csv {"Precision": 0.03283582089552239, "Recall": 1.0, "F1": 0.06358381502890173, "AUROC": 0.9995966610549942}
# ./yahoo/A1Benchmark/real_43.csv {"Precision": 0.5, "Recall": 0.15625, "F1": 0.23809523809523808, "AUROC": 0.46798547400611623}
# ./yahoo/A1Benchmark/real_44.csv {"Precision": 0.8333333333333334, "Recall": 0.5555555555555556, "F1": 0.6666666666666666, "AUROC": 0.8237179487179488}
# ./yahoo/A1Benchmark/real_45.csv {"Precision": 0.0007462686567164179, "Recall": 1.0, "F1": 0.0014914243102162564, "AUROC": 0.6960418222554146}
# ./yahoo/A1Benchmark/real_46.csv {"Precision": 0.6369047619047619, "Recall": 0.981651376146789, "F1": 0.7725631768953068, "AUROC": 0.9887704039080186}
# ./yahoo/A1Benchmark/real_47.csv {"Precision": 0.020202020202020204, "Recall": 0.4, "F1": 0.038461538461538464, "AUROC": 0.5672741078208049}
# ./yahoo/A1Benchmark/real_48.csv {"Precision": 0.14285714285714285, "Recall": 0.2916666666666667, "F1": 0.1917808219178082, "AUROC": 0.8917300380228137}
# ./yahoo/A1Benchmark/real_49.csv {"Precision": 0.5, "Recall": 0.6666666666666666, "F1": 0.5714285714285714, "AUROC": 0.948208149239077}
# ./yahoo/A1Benchmark/real_5.csv {"Precision": 0.125, "Recall": 0.5, "F1": 0.2, "AUROC": 0.93754674644727}
# ./yahoo/A1Benchmark/real_50.csv {"Precision": 0.005227781926811053, "Recall": 1.0, "F1": 0.010401188707280832, "AUROC": 0.004290004290004288}
# ./yahoo/A1Benchmark/real_51.csv {"Precision": 0.012987012987012988, "Recall": 0.25, "F1": 0.024691358024691357, "AUROC": 0.6793272864701436}
# ./yahoo/A1Benchmark/real_52.csv {"Precision": 0.17391304347826086, "Recall": 0.36363636363636365, "F1": 0.23529411764705882, "AUROC": 0.8982864221319937}
# ./yahoo/A1Benchmark/real_53.csv {"Precision": 0.14736842105263157, "Recall": 0.8235294117647058, "F1": 0.25, "AUROC": 0.9496673669467787}
# ./yahoo/A1Benchmark/real_54.csv {"Precision": 0.13333333333333333, "Recall": 1.0, "F1": 0.23529411764705882, "AUROC": 0.9913928012519562}
# ./yahoo/A1Benchmark/real_55.csv {"Precision": 0.00819672131147541, "Recall": 0.8, "F1": 0.016227180527383367, "AUROC": 0.6779122541603632}
# ./yahoo/A1Benchmark/real_56.csv {"Precision": 0.125, "Recall": 0.2, "F1": 0.15384615384615385, "AUROC": 0.8071104387291982}
# ./yahoo/A1Benchmark/real_57.csv {"Precision": 0.002238805970149254, "Recall": 1.0, "F1": 0.004467609828741623, "AUROC": 0.5904334828101644}
# ./yahoo/A1Benchmark/real_58.csv {"Precision": 0.03220973782771536, "Recall": 1.0, "F1": 0.062409288824383166, "AUROC": 0.9832061343509252}
# ./yahoo/A1Benchmark/real_59.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
# ./yahoo/A1Benchmark/real_6.csv {"Precision": 0.00597460791635549, "Recall": 1.0, "F1": 0.011878247958426132, "AUROC": 0.7160030052592036}
# ./yahoo/A1Benchmark/real_60.csv {"Precision": 0.35714285714285715, "Recall": 0.625, "F1": 0.45454545454545453, "AUROC": 0.8842936802973977}
# ./yahoo/A1Benchmark/real_61.csv {"Precision": 0.034161490683229816, "Recall": 0.9166666666666666, "F1": 0.0658682634730539, "AUROC": 0.6950771956466717}
# ./yahoo/A1Benchmark/real_62.csv {"Precision": 0.021621621621621623, "Recall": 0.8, "F1": 0.042105263157894736, "AUROC": 0.8424528301886792}
# ./yahoo/A1Benchmark/real_63.csv {"Precision": 0.00597460791635549, "Recall": 1.0, "F1": 0.011878247958426132, "AUROC": 0.009109691960931629}
# ./yahoo/A1Benchmark/real_64.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.0}
# ./yahoo/A1Benchmark/real_65.csv {"Precision": 0.01283987915407855, "Recall": 1.0, "F1": 0.02535421327367636, "AUROC": 0.9504928214591116}
# ./yahoo/A1Benchmark/real_66.csv {"Precision": 0.015861027190332326, "Recall": 1.0, "F1": 0.031226765799256505, "AUROC": 0.9939334137338742}
# ./yahoo/A1Benchmark/real_67.csv {"Precision": 0.017384731670445956, "Recall": 1.0, "F1": 0.03417533432392273, "AUROC": 0.9616722408026755}
# ./yahoo/A1Benchmark/real_7.csv {"Precision": 0.4107142857142857, "Recall": 0.3770491803278688, "F1": 0.39316239316239315, "AUROC": 0.6212621132212724}
# ./yahoo/A1Benchmark/real_8.csv {"Precision": 0.03255813953488372, "Recall": 0.7, "F1": 0.06222222222222222, "AUROC": 0.7385496183206106}
# ./yahoo/A1Benchmark/real_9.csv {"Precision": 0.2222222222222222, "Recall": 0.5, "F1": 0.3076923076923077, "AUROC": 0.8806356245380634}
#
# # Macro mean (simple average over files)
# {"Precision": 0.1718252844360427, "Recall": 0.7254848659030847, "F1": 0.19614752475737082, "AUROC": 0.6708483154320641}
