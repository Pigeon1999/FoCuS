# %% [markdown]
# # Yahoo A1 · Vanilla RNN (Supervised, Binary) · Point-level Anomaly Detection
#
# - **Dataset path**: `./yahoo/A1Benchmark/real_*.csv`
# - **Model**: PyTorch `nn.RNN(input_size=1, hidden_size=H, num_layers=1, tanh)` → `Linear(H→1)`
# - **Task**: Supervised **binary classification** of anomalies at time `t` using past `L` values (`[t-L..t-1]`).
# - **Metrics**: Precision / Recall / F1 / Accuracy (point-level).
# - **Split per file**: 60% train / 20% val / 20% test (time order preserved).
# - **Scaling**: z-score using **train** μ,σ only.

# %% [markdown]
# ## 0) Requirements
# ```
# pip install torch numpy pandas scikit-learn
# ```

# %%
# 1) Configuration
from dataclasses import dataclass

@dataclass
class Config:
    a1_dir: str = "./TSB-AD-U/WSD"
    seq_len: int = 100
    hidden: int = 256
    lr: float = 1e-3
    batch: int = 256
    epochs: int = 1000
    patience: int = 15
    device: str = "cuda"  # "cuda" or "cpu"

cfg = Config()
cfg
# Out:
# Config(a1_dir='./TSB-AD-U/WSD', seq_len=100, hidden=256, lr=0.001, batch=256, epochs=1000, patience=15, device='cuda')

# %%
# 2) Imports
import random
import os, glob, json
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import RobustScaler
import torch.nn.functional as F
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch: 2.5.1+cu124
# CUDA available: True

# %% [markdown]
# ## 3) Data utilities (Yahoo A1)

# %%
# Defensive column detection and CSV loader
def _find_cols(df: pd.DataFrame):
    ts_candidates = {"timestamp", "time", "ts", "date"}
    val_candidates = {"value", "values", "metric"}
    lab_candidates = {"is_anomaly", "anomaly", "label", "isoutlier"}
    ts_col = next((c for c in df.columns if str(c).lower() in ts_candidates), None)
    val_col = next((c for c in df.columns if str(c).lower() in val_candidates), None)
    lab_col = next((c for c in df.columns if str(c).lower() in lab_candidates), None)
    if val_col is None or lab_col is None:
        raise ValueError(f"Required columns not found in CSV. Columns: {df.columns.tolist()}")
    return ts_col, val_col, lab_col

def load_yahoo_a1(csv_path: str):
    df = pd.read_csv(csv_path)
    ts_col, val_col, lab_col = _find_cols(df)
    if ts_col is not None:
        df = df.sort_values(ts_col)
    x = df[val_col].to_numpy(dtype=np.float32)
    y = df[lab_col].astype(int).to_numpy()
    return x, y

def load_wsd(csv_path: str):
    df = pd.read_csv(csv_path)
    data_col = df.columns[0]
    label_col = df.columns[1]
    x = df[data_col].to_numpy(dtype=np.float32)
    y = df[label_col].astype(int).to_numpy()
    return x, y

def fit_robust_scaler(x_train: np.ndarray, cfg):
    # sklearn expects 2D; our series is 1D → reshape
    rs = RobustScaler()
    rs.fit(x_train.reshape(-1, 1))
    return rs

def apply_scaler(x: np.ndarray, scaler: RobustScaler):
    return scaler.transform(x.reshape(-1, 1)).astype(np.float32).squeeze(-1)

def make_windows(x: np.ndarray, y: np.ndarray, L: int):
    Xs, Ys, idx = [], [], []
    for t in range(L, len(x)):
        Xs.append(x[t - L:t])
        Ys.append(y[t])
        idx.append(t)
    X = np.asarray(Xs, dtype=np.float32)[..., None]  # [N, L, 1]
    Y = np.asarray(Ys, dtype=np.int64)               # [N]
    return X, Y, np.asarray(idx)

class WindowDataset(Dataset):
    def __init__(self, X: np.ndarray, Y: np.ndarray):
        self.X = torch.from_numpy(X)       # [N, L, 1]
        self.Y = torch.from_numpy(Y)       # [N]
    def __len__(self): return self.X.shape[0]
    def __getitem__(self, i):
        return self.X[i], self.Y[i]

def compute_pos_weight(y_train: np.ndarray) -> float:
    pos = int((y_train == 1).sum())
    neg = int((y_train == 0).sum())
    if pos == 0:
        return 1.0
    return float(neg / pos)

# %% [markdown]
# ## 4) Model (Vanilla RNN → Binary)

# %%
# 좌측 패딩으로 인과(미래 정보 누출 방지) 보장하는 1D conv
class CausalConv1d(nn.Module):
    def __init__(self, in_ch, out_ch, kernel_size=3, dilation=1):
        super().__init__()
        self.pad = (dilation * (kernel_size - 1), 0)  # (left, right)
        self.pad_layer = nn.ConstantPad1d(self.pad, 0.0)
        self.conv = nn.Conv1d(in_ch, out_ch, kernel_size,
                              dilation=dilation, padding=0, bias=True)
    def forward(self, x):            # x: [B, C, L]
        return self.conv(self.pad_layer(x))

class TCNBlock(nn.Module):
    def __init__(self, in_ch, out_ch, k=3, d=1, dropout=0.1):
        super().__init__()
        self.conv1 = CausalConv1d(in_ch, out_ch, kernel_size=k, dilation=d)
        self.bn1   = nn.BatchNorm1d(out_ch)
        self.conv2 = CausalConv1d(out_ch, out_ch, kernel_size=k, dilation=d)
        self.bn2   = nn.BatchNorm1d(out_ch)
        self.drop  = nn.Dropout(dropout)
        self.skip  = nn.Conv1d(in_ch, out_ch, 1) if in_ch != out_ch else nn.Identity()

    def forward(self, x):            # x: [B, C, L]
        s = self.skip(x)
        y = F.relu(self.bn1(self.conv1(x)))
        y = self.drop(y)
        y = F.relu(self.bn2(self.conv2(y)))
        return F.relu(y + s)         # residual

class TCNBinary(nn.Module):
    def __init__(self, channels=32, dilations=(1,2,4,8), k=3, dropout=0.1):
        super().__init__()
        self.stem = CausalConv1d(1, channels, kernel_size=k, dilation=1)
        blocks = []
        c = channels
        for d in dilations:
            blocks.append(TCNBlock(c, channels, k=k, d=d, dropout=dropout))
            c = channels
        self.blocks = nn.Sequential(*blocks)
        self.head   = nn.Sequential(
            nn.AdaptiveAvgPool1d(1),   # [B, C, 1]
            nn.Flatten(),              # [B, C]
            nn.Linear(channels, 1)     # logit
        )

    def forward(self, x):             # x: [B, L, 1]
        x = x.transpose(1, 2)         # -> [B, 1, L]
        h = self.stem(x)              # [B, C, L]
        h = self.blocks(h)            # [B, C, L]
        logit = self.head(h).squeeze(-1)  # [B]
        return logit

# %% [markdown]
# ## 5) Train & Evaluation Functions

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total = 0.0
    for X, Y in loader:
        X = X.to(device)
        Y = Y.to(device).float()
        logit = model(X)
        loss = criterion(logit, Y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total += loss.item() * X.size(0)
    return total / max(1, len(loader.dataset))

@torch.no_grad()
def infer_probs(model, loader, device):
    model.eval()
    probs, labels = [], []
    for X, Y in loader:
        X = X.to(device)
        p = torch.sigmoid(model(X)).cpu().numpy()
        probs.append(p)
        labels.append(Y.numpy())
    return np.concatenate(probs), np.concatenate(labels)

def metrics_prfa(y_true: np.ndarray, y_prob: np.ndarray, thr: float = 0.5):
    y_pred = (y_prob >= thr).astype(np.int64)
    P = precision_score(y_true, y_pred, zero_division=0)
    R = recall_score(y_true, y_pred, zero_division=0)
    F1 = f1_score(y_true, y_pred, zero_division=0)
    # AUROC는 예측 확률값(y_prob)을 직접 사용
    try:
        auroc = roc_auc_score(y_true, y_prob)
    except ValueError:  # 단일 클래스만 있는 경우
        auroc = 0.0
    return {
        "Precision": float(P),
        "Recall": float(R),
        "F1": float(F1),
        "AUROC": float(auroc)
    }

# %% [markdown]
# ## 6) Per-file Training & Testing Pipeline

# %%
# === 붙일 함수: F1이 최대가 되는 threshold 탐색 ===
import numpy as np
from sklearn.metrics import f1_score

def find_best_threshold(y_true, y_prob, grid=None):
    if grid is None:
        grid = np.linspace(0.05, 0.95, 19)  # 0.05 ~ 0.95
    best_thr, best_f1 = 0.5, -1.0
    for thr in grid:
        f1 = f1_score(y_true, (y_prob >= thr).astype(int), zero_division=0)
        if f1 > best_f1:
            best_f1, best_thr = f1, thr
    return float(best_thr), float(best_f1)

def run_one_file(csv_path: str, cfg):
    # Load
    x, y = load_wsd(csv_path)
    n = len(x)
    if n < cfg.seq_len + 10:
        raise ValueError(f"Series too short for seq_len={cfg.seq_len}: {csv_path}")

    # Split (time order preserved): 60/20/20
    n_tr, n_va = int(0.6 * n), int(0.8 * n)
    x_tr, x_va, x_te = x[:n_tr], x[n_tr:n_va], x[n_va:]
    y_tr, y_va, y_te = y[:n_tr], y[n_tr:n_va], y[n_va:]

    # Scale using TRAIN only
    rs = fit_robust_scaler(x_tr, cfg)
    x_tr = apply_scaler(x_tr, rs)
    x_va = apply_scaler(x_va, rs)
    x_te = apply_scaler(x_te, rs)

    # Windows (labels at current t)
    L = cfg.seq_len
    Xtr, Ytr, _ = make_windows(x_tr, y_tr, L)
    Xva, Yva, _ = make_windows(np.concatenate([x_tr, x_va]),
                               np.concatenate([y_tr, y_va]), L)
    Xte, Yte, _ = make_windows(np.concatenate([x_tr, x_va, x_te]),
                               np.concatenate([y_tr, y_va, y_te]), L)

    # DataLoaders
    ds_tr, ds_va, ds_te = WindowDataset(Xtr, Ytr), WindowDataset(Xva, Yva), WindowDataset(Xte, Yte)
    dl_tr = DataLoader(ds_tr, batch_size=cfg.batch, shuffle=True)
    dl_va = DataLoader(ds_va, batch_size=cfg.batch, shuffle=False)
    dl_te = DataLoader(ds_te, batch_size=cfg.batch, shuffle=False)

    # Model / Loss / Optim
    device = cfg.device if (cfg.device == "cpu" or torch.cuda.is_available()) else "cpu"
    model = TCNBinary(
        channels=32,           # 32~64 권장
        dilations=(1, 2, 4, 8),# 수용영역 확대
        k=3,                   # 3 또는 5 시도
        dropout=0.1
    ).to(device)
    pos_w = compute_pos_weight(Ytr)
    criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([pos_w], device=device))
    optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=1e-3)

    # Train with early stopping on val F1
    best_f1, best_state, bad = -1.0, None, 0
    for ep in range(1, cfg.epochs + 1):
        _ = train_one_epoch(model, dl_tr, optimizer, criterion, device)
        p_va, y_va = infer_probs(model, dl_va, device)
        f1 = metrics_prfa(y_va, p_va)["F1"]
        if f1 > best_f1:
            best_f1 = f1
            best_state = {k: v.detach().cpu() for k, v in model.state_dict().items()}
            bad = 0
        else:
            bad += 1
        # Simple log
        if ep % 5 == 0 or bad == 0:
            print(f"[{os.path.basename(csv_path)}] epoch {ep} valF1={f1:.4f} best={best_f1:.4f}, bad={bad}")
        if bad >= cfg.patience:
            break

    if best_state is not None:
        model.load_state_dict(best_state)

    p_va, y_va = infer_probs(model, dl_va, device)
    best_thr, best_va_f1 = find_best_threshold(y_va, p_va)

    p_te, y_te = infer_probs(model, dl_te, device)
    return metrics_prfa(y_te, p_te, thr=best_thr)

# %% [markdown]
# ## 7) Evaluate Over All A1 Files

# %%
def evaluate_all(cfg):
    paths = sorted(glob.glob(os.path.join(cfg.a1_dir, "*.csv")))
    if not paths:
        raise FileNotFoundError(f"No files matched: {cfg.a1_dir}/*.csv")
    rows = []
    for p in paths:
        print(f"\n### Processing: {p}")
        m = run_one_file(p, cfg)
        rows.append(m)
        print("=> Test metrics:", json.dumps(m, ensure_ascii=False))
    keys = rows[0].keys()
    macro = {k: float(np.mean([r[k] for r in rows])) for k in keys}
    return paths, rows, macro

paths, rows, macro = evaluate_all(cfg)

print("\n# Per-file metrics (Precision/Recall/F1/Accuracy)")
for p, m in zip(paths, rows):
    print(p, json.dumps(m, ensure_ascii=False))

print("\n# Macro mean (simple average over files)")
print(json.dumps(macro, ensure_ascii=False))
# Out:
# ### Processing: ./TSB-AD-U/WSD/029_WSD_id_1_WebService_tr_4559_1st_10201.csv
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 1 valF1=0.0857 best=0.0857, bad=0
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 5 valF1=0.1106 best=0.1106, bad=0
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 7 valF1=0.1448 best=0.1448, bad=0
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 9 valF1=0.2088 best=0.2088, bad=0
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 10 valF1=0.1590 best=0.2088, bad=1
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 11 valF1=0.2600 best=0.2600, bad=0
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 15 valF1=0.1919 best=0.2600, bad=4
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 18 valF1=0.3490 best=0.3490, bad=0
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 20 valF1=0.1030 best=0.3490, bad=2
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 25 valF1=0.3662 best=0.3662, bad=0
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 30 valF1=0.3355 best=0.3662, bad=5
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 33 valF1=0.4602 best=0.4602, bad=0
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 35 valF1=0.2796 best=0.4602, bad=2
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 40 valF1=0.2680 best=0.4602, bad=7
# [029_WSD_id_1_WebService_tr_4559_1st_10201.csv] epoch 45 valF1=0.1503 best=0.4602, bad=12
# => Test metrics: {"Precision": 0.4482758620689655, "Recall": 1.0, "F1": 0.6190476190476191, "AUROC": 0.9999766384912713}
#
# ### Processing: ./TSB-AD-U/WSD/030_WSD_id_2_WebService_tr_4499_1st_4599.csv
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 1 valF1=0.0240 best=0.0240, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 2 valF1=0.0252 best=0.0252, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 5 valF1=0.0205 best=0.0252, bad=3
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 6 valF1=0.0419 best=0.0419, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 7 valF1=0.2058 best=0.2058, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 9 valF1=0.2906 best=0.2906, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 10 valF1=0.1587 best=0.2906, bad=1
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 15 valF1=0.1124 best=0.2906, bad=6
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 18 valF1=0.3333 best=0.3333, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 19 valF1=0.3550 best=0.3550, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 20 valF1=0.1951 best=0.3550, bad=1
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 22 valF1=0.5172 best=0.5172, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 24 valF1=0.6000 best=0.6000, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 25 valF1=0.2419 best=0.6000, bad=1
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 27 valF1=0.8321 best=0.8321, bad=0
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 30 valF1=0.5530 best=0.8321, bad=3
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 35 valF1=0.6383 best=0.8321, bad=8
# [030_WSD_id_2_WebService_tr_4499_1st_4599.csv] epoch 40 valF1=0.5530 best=0.8321, bad=13
# => Test metrics: {"Precision": 0.7402597402597403, "Recall": 0.6477272727272727, "F1": 0.6909090909090909, "AUROC": 0.8637551052546024}
#
# ### Processing: ./TSB-AD-U/WSD/031_WSD_id_3_WebService_tr_826_1st_926.csv
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 1 valF1=0.0354 best=0.0354, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 2 valF1=0.0411 best=0.0411, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 4 valF1=0.0749 best=0.0749, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 5 valF1=0.2517 best=0.2517, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 7 valF1=0.5909 best=0.5909, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 8 valF1=0.7723 best=0.7723, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 10 valF1=0.7222 best=0.7723, bad=2
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 11 valF1=0.8667 best=0.8667, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 15 valF1=0.5532 best=0.8667, bad=4
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 16 valF1=0.8966 best=0.8966, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 18 valF1=0.9176 best=0.9176, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 20 valF1=0.9176 best=0.9176, bad=2
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 25 valF1=0.9398 best=0.9398, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 30 valF1=0.9398 best=0.9398, bad=5
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 32 valF1=0.9512 best=0.9512, bad=0
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 35 valF1=0.6555 best=0.9512, bad=3
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 40 valF1=0.8966 best=0.9512, bad=8
# [031_WSD_id_3_WebService_tr_826_1st_926.csv] epoch 45 valF1=0.9070 best=0.9512, bad=13
# => Test metrics: {"Precision": 0.975, "Recall": 1.0, "F1": 0.9873417721518988, "AUROC": 0.9999999999999999}
#
# ### Processing: ./TSB-AD-U/WSD/032_WSD_id_4_WebService_tr_4559_1st_11822.csv
# [032_WSD_id_4_WebService_tr_4559_1st_11822.csv] epoch 1 valF1=0.0192 best=0.0192, bad=0
# [032_WSD_id_4_WebService_tr_4559_1st_11822.csv] epoch 2 valF1=0.0396 best=0.0396, bad=0
# [032_WSD_id_4_WebService_tr_4559_1st_11822.csv] epoch 4 valF1=0.0513 best=0.0513, bad=0
# [032_WSD_id_4_WebService_tr_4559_1st_11822.csv] epoch 5 valF1=0.0199 best=0.0513, bad=1
# [032_WSD_id_4_WebService_tr_4559_1st_11822.csv] epoch 6 valF1=0.5941 best=0.5941, bad=0
# [032_WSD_id_4_WebService_tr_4559_1st_11822.csv] epoch 10 valF1=0.4000 best=0.5941, bad=4
# [032_WSD_id_4_WebService_tr_4559_1st_11822.csv] epoch 15 valF1=0.0925 best=0.5941, bad=9
# [032_WSD_id_4_WebService_tr_4559_1st_11822.csv] epoch 20 valF1=0.1725 best=0.5941, bad=14
# => Test metrics: {"Precision": 0.46153846153846156, "Recall": 0.9375, "F1": 0.6185567010309279, "AUROC": 0.9978000047375403}
#
# ### Processing: ./TSB-AD-U/WSD/033_WSD_id_5_WebService_tr_4559_1st_12588.csv
# [033_WSD_id_5_WebService_tr_4559_1st_12588.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [033_WSD_id_5_WebService_tr_4559_1st_12588.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [033_WSD_id_5_WebService_tr_4559_1st_12588.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [033_WSD_id_5_WebService_tr_4559_1st_12588.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.7669762088700396}
#
# ### Processing: ./TSB-AD-U/WSD/034_WSD_id_6_WebService_tr_4559_1st_8461.csv
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 1 valF1=0.5724 best=0.5724, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 5 valF1=0.7554 best=0.7554, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 6 valF1=0.8756 best=0.8756, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 10 valF1=0.6308 best=0.8756, bad=4
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 15 valF1=0.7686 best=0.8756, bad=9
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 18 valF1=0.8844 best=0.8844, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 20 valF1=0.1416 best=0.8844, bad=2
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 25 valF1=0.8224 best=0.8844, bad=7
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 26 valF1=0.8889 best=0.8889, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 30 valF1=0.8980 best=0.8980, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 35 valF1=0.8713 best=0.8980, bad=5
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 37 valF1=0.9119 best=0.9119, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 38 valF1=0.9167 best=0.9167, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 39 valF1=0.9565 best=0.9565, bad=0
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 40 valF1=0.9167 best=0.9565, bad=1
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 45 valF1=0.8341 best=0.9565, bad=6
# [034_WSD_id_6_WebService_tr_4559_1st_8461.csv] epoch 50 valF1=0.8756 best=0.9565, bad=11
# => Test metrics: {"Precision": 0.967032967032967, "Recall": 0.46808510638297873, "F1": 0.6308243727598566, "AUROC": 0.8991969709183505}
#
# ### Processing: ./TSB-AD-U/WSD/035_WSD_id_7_WebService_tr_4555_1st_11911.csv
# [035_WSD_id_7_WebService_tr_4555_1st_11911.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [035_WSD_id_7_WebService_tr_4555_1st_11911.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [035_WSD_id_7_WebService_tr_4555_1st_11911.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [035_WSD_id_7_WebService_tr_4555_1st_11911.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.005314009661835749, "Recall": 0.6875, "F1": 0.010546500479386385, "AUROC": 0.8621764083923042}
#
# ### Processing: ./TSB-AD-U/WSD/036_WSD_id_8_WebService_tr_4504_1st_6898.csv
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 2 valF1=0.0031 best=0.0031, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 3 valF1=0.0032 best=0.0032, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 4 valF1=0.0033 best=0.0033, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 5 valF1=0.0028 best=0.0033, bad=1
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 10 valF1=0.0025 best=0.0033, bad=6
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 11 valF1=0.0042 best=0.0042, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 15 valF1=0.0034 best=0.0042, bad=4
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 18 valF1=0.0047 best=0.0047, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 20 valF1=0.0044 best=0.0047, bad=2
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 22 valF1=0.0059 best=0.0059, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 25 valF1=0.0037 best=0.0059, bad=3
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 30 valF1=0.0037 best=0.0059, bad=8
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 35 valF1=0.0058 best=0.0059, bad=13
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 36 valF1=0.0065 best=0.0065, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 38 valF1=0.0103 best=0.0103, bad=0
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 40 valF1=0.0047 best=0.0103, bad=2
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 45 valF1=0.0064 best=0.0103, bad=7
# [036_WSD_id_8_WebService_tr_4504_1st_6898.csv] epoch 50 valF1=0.0065 best=0.0103, bad=12
# => Test metrics: {"Precision": 0.015789473684210527, "Recall": 1.0, "F1": 0.031088082901554404, "AUROC": 0.9921924436999814}
#
# ### Processing: ./TSB-AD-U/WSD/037_WSD_id_9_WebService_tr_4583_1st_6214.csv
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 1 valF1=0.1030 best=0.1030, bad=0
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 5 valF1=0.0910 best=0.1030, bad=4
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 9 valF1=0.1458 best=0.1458, bad=0
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 10 valF1=0.1550 best=0.1550, bad=0
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 12 valF1=0.1734 best=0.1734, bad=0
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 15 valF1=0.1293 best=0.1734, bad=3
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 20 valF1=0.1100 best=0.1734, bad=8
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 22 valF1=0.1905 best=0.1905, bad=0
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 23 valF1=0.2623 best=0.2623, bad=0
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 25 valF1=0.1468 best=0.2623, bad=2
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 30 valF1=0.1860 best=0.2623, bad=7
# [037_WSD_id_9_WebService_tr_4583_1st_6214.csv] epoch 35 valF1=0.1711 best=0.2623, bad=12
# => Test metrics: {"Precision": 0.49122807017543857, "Recall": 0.6086956521739131, "F1": 0.5436893203883495, "AUROC": 0.89572317151299}
#
# ### Processing: ./TSB-AD-U/WSD/038_WSD_id_10_WebService_tr_4042_1st_4142.csv
# [038_WSD_id_10_WebService_tr_4042_1st_4142.csv] epoch 1 valF1=0.1556 best=0.1556, bad=0
# [038_WSD_id_10_WebService_tr_4042_1st_4142.csv] epoch 5 valF1=0.1931 best=0.1931, bad=0
# [038_WSD_id_10_WebService_tr_4042_1st_4142.csv] epoch 6 valF1=0.3896 best=0.3896, bad=0
# [038_WSD_id_10_WebService_tr_4042_1st_4142.csv] epoch 10 valF1=0.1055 best=0.3896, bad=4
# [038_WSD_id_10_WebService_tr_4042_1st_4142.csv] epoch 12 valF1=0.4286 best=0.4286, bad=0
# [038_WSD_id_10_WebService_tr_4042_1st_4142.csv] epoch 15 valF1=0.0585 best=0.4286, bad=3
# [038_WSD_id_10_WebService_tr_4042_1st_4142.csv] epoch 20 valF1=0.2695 best=0.4286, bad=8
# [038_WSD_id_10_WebService_tr_4042_1st_4142.csv] epoch 25 valF1=0.2920 best=0.4286, bad=13
# => Test metrics: {"Precision": 0.46875, "Recall": 0.45454545454545453, "F1": 0.46153846153846156, "AUROC": 0.8771482545062186}
#
# ### Processing: ./TSB-AD-U/WSD/039_WSD_id_11_WebService_tr_1746_1st_1846.csv
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 1 valF1=0.1878 best=0.1878, bad=0
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 4 valF1=0.2356 best=0.2356, bad=0
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 5 valF1=0.2881 best=0.2881, bad=0
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 6 valF1=0.4222 best=0.4222, bad=0
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 10 valF1=0.1088 best=0.4222, bad=4
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 15 valF1=0.6832 best=0.6832, bad=0
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 20 valF1=0.4080 best=0.6832, bad=5
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 25 valF1=0.6649 best=0.6832, bad=10
# [039_WSD_id_11_WebService_tr_1746_1st_1846.csv] epoch 30 valF1=0.5926 best=0.6832, bad=15
# => Test metrics: {"Precision": 0.7863247863247863, "Recall": 0.696969696969697, "F1": 0.7389558232931727, "AUROC": 0.9802946909468288}
#
# ### Processing: ./TSB-AD-U/WSD/040_WSD_id_12_WebService_tr_4559_1st_9714.csv
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 1 valF1=0.0187 best=0.0187, bad=0
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 2 valF1=0.0486 best=0.0486, bad=0
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 4 valF1=0.0595 best=0.0595, bad=0
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 5 valF1=0.0223 best=0.0595, bad=1
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 10 valF1=0.0588 best=0.0595, bad=6
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 15 valF1=0.0515 best=0.0595, bad=11
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 16 valF1=0.2031 best=0.2031, bad=0
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 20 valF1=0.0476 best=0.2031, bad=4
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 25 valF1=0.0475 best=0.2031, bad=9
# [040_WSD_id_12_WebService_tr_4559_1st_9714.csv] epoch 30 valF1=0.0671 best=0.2031, bad=14
# => Test metrics: {"Precision": 0.203125, "Recall": 0.3170731707317073, "F1": 0.24761904761904763, "AUROC": 0.9272417255811133}
#
# ### Processing: ./TSB-AD-U/WSD/041_WSD_id_13_WebService_tr_4296_1st_5196.csv
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 1 valF1=0.2985 best=0.2985, bad=0
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 4 valF1=0.3698 best=0.3698, bad=0
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 5 valF1=0.1393 best=0.3698, bad=1
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 10 valF1=0.1844 best=0.3698, bad=6
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 14 valF1=0.4160 best=0.4160, bad=0
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 15 valF1=0.2883 best=0.4160, bad=1
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 17 valF1=0.5461 best=0.5461, bad=0
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 20 valF1=0.3319 best=0.5461, bad=3
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 25 valF1=0.4108 best=0.5461, bad=8
# [041_WSD_id_13_WebService_tr_4296_1st_5196.csv] epoch 30 valF1=0.4286 best=0.5461, bad=13
# => Test metrics: {"Precision": 0.7752808988764045, "Recall": 0.4423076923076923, "F1": 0.563265306122449, "AUROC": 0.9088611477122994}
#
# ### Processing: ./TSB-AD-U/WSD/042_WSD_id_14_WebService_tr_3015_1st_3115.csv
# [042_WSD_id_14_WebService_tr_3015_1st_3115.csv] epoch 1 valF1=0.0454 best=0.0454, bad=0
# [042_WSD_id_14_WebService_tr_3015_1st_3115.csv] epoch 4 valF1=0.1674 best=0.1674, bad=0
# [042_WSD_id_14_WebService_tr_3015_1st_3115.csv] epoch 5 valF1=0.0454 best=0.1674, bad=1
# [042_WSD_id_14_WebService_tr_3015_1st_3115.csv] epoch 10 valF1=0.0714 best=0.1674, bad=6
# [042_WSD_id_14_WebService_tr_3015_1st_3115.csv] epoch 15 valF1=0.1464 best=0.1674, bad=11
# => Test metrics: {"Precision": 0.3486238532110092, "Recall": 0.3140495867768595, "F1": 0.33043478260869563, "AUROC": 0.934096769196816}
#
# ### Processing: ./TSB-AD-U/WSD/043_WSD_id_15_WebService_tr_4521_1st_6828.csv
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 1 valF1=0.0022 best=0.0022, bad=0
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 3 valF1=0.0054 best=0.0054, bad=0
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 5 valF1=0.0027 best=0.0054, bad=2
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 10 valF1=0.0037 best=0.0054, bad=7
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 11 valF1=0.0056 best=0.0056, bad=0
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 15 valF1=0.0046 best=0.0056, bad=4
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 16 valF1=0.0068 best=0.0068, bad=0
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 20 valF1=0.0059 best=0.0068, bad=4
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 22 valF1=0.0072 best=0.0072, bad=0
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 25 valF1=0.0069 best=0.0072, bad=3
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 26 valF1=0.0073 best=0.0073, bad=0
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 27 valF1=0.0078 best=0.0078, bad=0
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 28 valF1=0.0094 best=0.0094, bad=0
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 30 valF1=0.0036 best=0.0094, bad=2
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 35 valF1=0.0079 best=0.0094, bad=7
# [043_WSD_id_15_WebService_tr_4521_1st_6828.csv] epoch 40 valF1=0.0076 best=0.0094, bad=12
# => Test metrics: {"Precision": 0.004172461752433936, "Recall": 0.5, "F1": 0.008275862068965517, "AUROC": 0.9470678754843614}
#
# ### Processing: ./TSB-AD-U/WSD/044_WSD_id_16_WebService_tr_4559_1st_6975.csv
# [044_WSD_id_16_WebService_tr_4559_1st_6975.csv] epoch 1 valF1=0.7692 best=0.7692, bad=0
# [044_WSD_id_16_WebService_tr_4559_1st_6975.csv] epoch 5 valF1=0.6809 best=0.7692, bad=4
# [044_WSD_id_16_WebService_tr_4559_1st_6975.csv] epoch 10 valF1=0.3459 best=0.7692, bad=9
# [044_WSD_id_16_WebService_tr_4559_1st_6975.csv] epoch 15 valF1=0.0000 best=0.7692, bad=14
# => Test metrics: {"Precision": 0.2064516129032258, "Recall": 1.0, "F1": 0.3422459893048128, "AUROC": 0.9990868730667256}
#
# ### Processing: ./TSB-AD-U/WSD/045_WSD_id_17_WebService_tr_2566_1st_2666.csv
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 1 valF1=0.0038 best=0.0038, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 2 valF1=0.0131 best=0.0131, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 5 valF1=0.0050 best=0.0131, bad=3
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 10 valF1=0.0052 best=0.0131, bad=8
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 14 valF1=0.0372 best=0.0372, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 15 valF1=0.0275 best=0.0372, bad=1
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 20 valF1=0.0047 best=0.0372, bad=6
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 25 valF1=0.0264 best=0.0372, bad=11
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 27 valF1=0.0388 best=0.0388, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 29 valF1=0.0638 best=0.0638, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 30 valF1=0.0296 best=0.0638, bad=1
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 33 valF1=0.0764 best=0.0764, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 35 valF1=0.0429 best=0.0764, bad=2
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 40 valF1=0.0156 best=0.0764, bad=7
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 45 valF1=0.0686 best=0.0764, bad=12
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 46 valF1=0.0816 best=0.0816, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 47 valF1=0.1558 best=0.1558, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 50 valF1=0.0606 best=0.1558, bad=3
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 53 valF1=0.1739 best=0.1739, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 55 valF1=0.0732 best=0.1739, bad=2
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 60 valF1=0.2553 best=0.2553, bad=0
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 65 valF1=0.2105 best=0.2553, bad=5
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 70 valF1=0.0200 best=0.2553, bad=10
# [045_WSD_id_17_WebService_tr_2566_1st_2666.csv] epoch 75 valF1=0.0471 best=0.2553, bad=15
# => Test metrics: {"Precision": 0.2608695652173913, "Recall": 1.0, "F1": 0.41379310344827586, "AUROC": 0.9997793712079427}
#
# ### Processing: ./TSB-AD-U/WSD/046_WSD_id_18_WebService_tr_2357_1st_2457.csv
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 1 valF1=0.0316 best=0.0316, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 2 valF1=0.0342 best=0.0342, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 3 valF1=0.0347 best=0.0347, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 4 valF1=0.0372 best=0.0372, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 5 valF1=0.0407 best=0.0407, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 8 valF1=0.0446 best=0.0446, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 9 valF1=0.0580 best=0.0580, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 10 valF1=0.0497 best=0.0580, bad=1
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 12 valF1=0.0794 best=0.0794, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 15 valF1=0.0907 best=0.0907, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 16 valF1=0.1659 best=0.1659, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 20 valF1=0.1307 best=0.1659, bad=4
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 25 valF1=0.1277 best=0.1659, bad=9
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 27 valF1=0.2138 best=0.2138, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 28 valF1=0.2279 best=0.2279, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 30 valF1=0.2796 best=0.2796, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 32 valF1=0.2911 best=0.2911, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 33 valF1=0.5280 best=0.5280, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 35 valF1=0.4393 best=0.5280, bad=2
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 36 valF1=0.5351 best=0.5351, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 40 valF1=0.4789 best=0.5351, bad=4
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 42 valF1=0.5574 best=0.5574, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 45 valF1=0.5965 best=0.5965, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 50 valF1=0.5105 best=0.5965, bad=5
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 53 valF1=0.6182 best=0.6182, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 54 valF1=0.6343 best=0.6343, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 55 valF1=0.6115 best=0.6343, bad=1
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 58 valF1=0.6391 best=0.6391, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 60 valF1=0.6439 best=0.6439, bad=0
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 65 valF1=0.2941 best=0.6439, bad=5
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 70 valF1=0.6007 best=0.6439, bad=10
# [046_WSD_id_18_WebService_tr_2357_1st_2457.csv] epoch 75 valF1=0.6415 best=0.6439, bad=15
# => Test metrics: {"Precision": 0.7327586206896551, "Recall": 0.6538461538461539, "F1": 0.6910569105691057, "AUROC": 0.8606071749262411}
#
# ### Processing: ./TSB-AD-U/WSD/047_WSD_id_19_WebService_tr_4559_1st_16362.csv
# [047_WSD_id_19_WebService_tr_4559_1st_16362.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [047_WSD_id_19_WebService_tr_4559_1st_16362.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [047_WSD_id_19_WebService_tr_4559_1st_16362.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [047_WSD_id_19_WebService_tr_4559_1st_16362.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.2484746243713245}
#
# ### Processing: ./TSB-AD-U/WSD/048_WSD_id_20_WebService_tr_4559_1st_11813.csv
# [048_WSD_id_20_WebService_tr_4559_1st_11813.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [048_WSD_id_20_WebService_tr_4559_1st_11813.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [048_WSD_id_20_WebService_tr_4559_1st_11813.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [048_WSD_id_20_WebService_tr_4559_1st_11813.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.4265332079854007}
#
# ### Processing: ./TSB-AD-U/WSD/049_WSD_id_21_WebService_tr_4297_1st_7097.csv
# [049_WSD_id_21_WebService_tr_4297_1st_7097.csv] epoch 1 valF1=0.0275 best=0.0275, bad=0
# [049_WSD_id_21_WebService_tr_4297_1st_7097.csv] epoch 2 valF1=0.0453 best=0.0453, bad=0
# [049_WSD_id_21_WebService_tr_4297_1st_7097.csv] epoch 4 valF1=0.0786 best=0.0786, bad=0
# [049_WSD_id_21_WebService_tr_4297_1st_7097.csv] epoch 5 valF1=0.5000 best=0.5000, bad=0
# [049_WSD_id_21_WebService_tr_4297_1st_7097.csv] epoch 6 valF1=0.5155 best=0.5155, bad=0
# [049_WSD_id_21_WebService_tr_4297_1st_7097.csv] epoch 10 valF1=0.2286 best=0.5155, bad=4
# [049_WSD_id_21_WebService_tr_4297_1st_7097.csv] epoch 15 valF1=0.2295 best=0.5155, bad=9
# [049_WSD_id_21_WebService_tr_4297_1st_7097.csv] epoch 20 valF1=0.1848 best=0.5155, bad=14
# => Test metrics: {"Precision": 0.8333333333333334, "Recall": 0.8064516129032258, "F1": 0.819672131147541, "AUROC": 0.9284055537275103}
#
# ### Processing: ./TSB-AD-U/WSD/050_WSD_id_22_WebService_tr_4559_1st_12816.csv
# [050_WSD_id_22_WebService_tr_4559_1st_12816.csv] epoch 1 valF1=0.0000 best=0.0000, bad=0
# [050_WSD_id_22_WebService_tr_4559_1st_12816.csv] epoch 5 valF1=0.0000 best=0.0000, bad=4
# [050_WSD_id_22_WebService_tr_4559_1st_12816.csv] epoch 10 valF1=0.0000 best=0.0000, bad=9
# [050_WSD_id_22_WebService_tr_4559_1st_12816.csv] epoch 15 valF1=0.0000 best=0.0000, bad=14
# => Test metrics: {"Precision": 0.001949317738791423, "Recall": 1.0, "F1": 0.0038910505836575876, "AUROC": 0.6876228699540805}
#
# ### Processing: ./TSB-AD-U/WSD/051_WSD_id_23_WebService_tr_3919_1st_5154.csv
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 1 valF1=0.0111 best=0.0111, bad=0
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 2 valF1=0.0173 best=0.0173, bad=0
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 3 valF1=0.0243 best=0.0243, bad=0
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 4 valF1=0.0358 best=0.0358, bad=0
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 5 valF1=0.0864 best=0.0864, bad=0
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 9 valF1=0.1270 best=0.1270, bad=0
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 10 valF1=0.0324 best=0.1270, bad=1
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 12 valF1=0.1789 best=0.1789, bad=0
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 15 valF1=0.0856 best=0.1789, bad=3
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 20 valF1=0.1297 best=0.1789, bad=8
# [051_WSD_id_23_WebService_tr_3919_1st_5154.csv] epoch 25 valF1=0.0764 best=0.1789, bad=13
# => Test metrics: {"Precision": 0.7441860465116279, "Recall": 0.5333333333333333, "F1": 0.6213592233009708, "AUROC": 0.9126063418406806}
#
# ### Processing: ./TSB-AD-U/WSD/052_WSD_id_24_WebService_tr_4559_1st_9102.csv
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 1 valF1=0.0006 best=0.0006, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 2 valF1=0.0010 best=0.0010, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 3 valF1=0.0039 best=0.0039, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 5 valF1=0.0014 best=0.0039, bad=2
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 7 valF1=0.0055 best=0.0055, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 10 valF1=0.0035 best=0.0055, bad=3
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 11 valF1=0.0392 best=0.0392, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 15 valF1=0.0183 best=0.0392, bad=4
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 20 valF1=0.0545 best=0.0545, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 21 valF1=0.0600 best=0.0600, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 24 valF1=0.0789 best=0.0789, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 25 valF1=0.0723 best=0.0789, bad=1
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 30 valF1=0.0789 best=0.0789, bad=6
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 32 valF1=0.0833 best=0.0833, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 33 valF1=0.0882 best=0.0882, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 35 valF1=0.1111 best=0.1111, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 40 valF1=0.1000 best=0.1111, bad=5
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 41 valF1=0.1176 best=0.1176, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 44 valF1=0.1277 best=0.1277, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 45 valF1=0.1395 best=0.1395, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 48 valF1=0.1429 best=0.1429, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 49 valF1=0.2609 best=0.2609, bad=0
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 50 valF1=0.1250 best=0.2609, bad=1
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 55 valF1=0.0014 best=0.2609, bad=6
# [052_WSD_id_24_WebService_tr_4559_1st_9102.csv] epoch 60 valF1=0.0092 best=0.2609, bad=11
# => Test metrics: {"Precision": 0.42857142857142855, "Recall": 0.08823529411764706, "F1": 0.14634146341463414, "AUROC": 0.10979937218506894}
#
# ### Processing: ./TSB-AD-U/WSD/053_WSD_id_25_WebService_tr_4559_1st_9198.csv
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 1 valF1=0.0209 best=0.0209, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 4 valF1=0.0236 best=0.0236, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 5 valF1=0.0251 best=0.0251, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 10 valF1=0.0295 best=0.0295, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 11 valF1=0.0423 best=0.0423, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 15 valF1=0.0339 best=0.0423, bad=4
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 20 valF1=0.0000 best=0.0423, bad=9
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 21 valF1=0.0463 best=0.0463, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 25 valF1=0.0655 best=0.0655, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 27 valF1=0.1111 best=0.1111, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 28 valF1=0.2407 best=0.2407, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 30 valF1=0.2921 best=0.2921, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 35 valF1=0.0325 best=0.2921, bad=5
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 40 valF1=0.2241 best=0.2921, bad=10
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 45 valF1=0.4407 best=0.4407, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 50 valF1=0.3824 best=0.4407, bad=5
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 55 valF1=0.2453 best=0.4407, bad=10
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 56 valF1=0.4815 best=0.4815, bad=0
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 60 valF1=0.4561 best=0.4815, bad=4
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 65 valF1=0.4727 best=0.4815, bad=9
# [053_WSD_id_25_WebService_tr_4559_1st_9198.csv] epoch 70 valF1=0.4407 best=0.4815, bad=14
# => Test metrics: {"Precision": 0.5652173913043478, "Recall": 1.0, "F1": 0.7222222222222222, "AUROC": 0.9999363324971668}
#
# ### Processing: ./TSB-AD-U/WSD/054_WSD_id_26_WebService_tr_2409_1st_2509.csv
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 1 valF1=0.0182 best=0.0182, bad=0
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 2 valF1=0.0346 best=0.0346, bad=0
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 4 valF1=0.0618 best=0.0618, bad=0
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 5 valF1=0.0433 best=0.0618, bad=1
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 8 valF1=0.1987 best=0.1987, bad=0
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 10 valF1=0.0492 best=0.1987, bad=2
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 15 valF1=0.2493 best=0.2493, bad=0
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 17 valF1=0.4734 best=0.4734, bad=0
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 20 valF1=0.4537 best=0.4734, bad=3
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 22 valF1=0.4851 best=0.4851, bad=0
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 25 valF1=0.3657 best=0.4851, bad=3
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 26 valF1=0.6174 best=0.6174, bad=0
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 30 valF1=0.3784 best=0.6174, bad=4
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 35 valF1=0.5698 best=0.6174, bad=9
# [054_WSD_id_26_WebService_tr_2409_1st_2509.csv] epoch 40 valF1=0.5537 best=0.6174, bad=14
# => Test metrics: {"Precision": 0.6428571428571429, "Recall": 0.5454545454545454, "F1": 0.5901639344262295, "AUROC": 0.9239048925468679}
#
# ### Processing: ./TSB-AD-U/WSD/055_WSD_id_27_WebService_tr_3768_1st_3868.csv
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 1 valF1=0.0317 best=0.0317, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 3 valF1=0.0336 best=0.0336, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 5 valF1=0.0375 best=0.0375, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 10 valF1=0.0474 best=0.0474, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 12 valF1=0.0493 best=0.0493, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 13 valF1=0.0702 best=0.0702, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 14 valF1=0.1046 best=0.1046, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 15 valF1=0.0554 best=0.1046, bad=1
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 20 valF1=0.0975 best=0.1046, bad=6
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 24 valF1=0.1921 best=0.1921, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 25 valF1=0.2010 best=0.2010, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 27 valF1=0.3291 best=0.3291, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 29 valF1=0.5673 best=0.5673, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 30 valF1=0.5065 best=0.5673, bad=1
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 35 valF1=0.5455 best=0.5673, bad=6
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 38 valF1=0.6023 best=0.6023, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 40 valF1=0.4968 best=0.6023, bad=2
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 45 valF1=0.6070 best=0.6070, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 50 valF1=0.5417 best=0.6070, bad=5
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 52 valF1=0.6118 best=0.6118, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 53 valF1=0.6473 best=0.6473, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 55 valF1=0.6341 best=0.6473, bad=2
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 60 valF1=0.6964 best=0.6964, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 65 valF1=0.6872 best=0.6964, bad=5
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 69 valF1=0.7027 best=0.7027, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 70 valF1=0.5288 best=0.7027, bad=1
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 71 valF1=0.7189 best=0.7189, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 75 valF1=0.6420 best=0.7189, bad=4
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 80 valF1=0.7393 best=0.7393, bad=0
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 85 valF1=0.5909 best=0.7393, bad=5
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 90 valF1=0.6783 best=0.7393, bad=10
# [055_WSD_id_27_WebService_tr_3768_1st_3868.csv] epoch 95 valF1=0.3714 best=0.7393, bad=15
# => Test metrics: {"Precision": 0.8636363636363636, "Recall": 0.7378640776699029, "F1": 0.7958115183246073, "AUROC": 0.938366138374882}
#
# ### Processing: ./TSB-AD-U/WSD/056_WSD_id_28_WebService_tr_4559_1st_9689.csv
# [056_WSD_id_28_WebService_tr_4559_1st_9689.csv] epoch 1 valF1=0.0784 best=0.0784, bad=0
# [056_WSD_id_28_WebService_tr_4559_1st_9689.csv] epoch 2 valF1=0.1037 best=0.1037, bad=0
# [056_WSD_id_28_WebService_tr_4559_1st_9689.csv] epoch 3 valF1=0.6786 best=0.6786, bad=0
# [056_WSD_id_28_WebService_tr_4559_1st_9689.csv] epoch 5 valF1=0.2216 best=0.6786, bad=2
# [056_WSD_id_28_WebService_tr_4559_1st_9689.csv] epoch 10 valF1=0.0160 best=0.6786, bad=7
# [056_WSD_id_28_WebService_tr_4559_1st_9689.csv] epoch 15 valF1=0.5984 best=0.6786, bad=12
# => Test metrics: {"Precision": 0.8260869565217391, "Recall": 1.0, "F1": 0.9047619047619048, "AUROC": 0.9999214801286562}
#
# ### Processing: ./TSB-AD-U/WSD/057_WSD_id_29_WebService_tr_2229_1st_2329.csv
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 1 valF1=0.0271 best=0.0271, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 2 valF1=0.0518 best=0.0518, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 3 valF1=0.2329 best=0.2329, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 5 valF1=0.0600 best=0.2329, bad=2
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 6 valF1=0.4603 best=0.4603, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 7 valF1=0.5370 best=0.5370, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 8 valF1=0.6374 best=0.6374, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 10 valF1=0.2762 best=0.6374, bad=2
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 15 valF1=0.5859 best=0.6374, bad=7
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 16 valF1=0.6824 best=0.6824, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 20 valF1=0.2007 best=0.6824, bad=4
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 25 valF1=0.6444 best=0.6824, bad=9
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 30 valF1=0.6444 best=0.6824, bad=14
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 31 valF1=0.6905 best=0.6905, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 35 valF1=0.7073 best=0.7073, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 38 valF1=0.7160 best=0.7160, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 39 valF1=0.7436 best=0.7436, bad=0
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 40 valF1=0.6517 best=0.7436, bad=1
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 45 valF1=0.5577 best=0.7436, bad=6
# [057_WSD_id_29_WebService_tr_2229_1st_2329.csv] epoch 50 valF1=0.6744 best=0.7436, bad=11
# => Test metrics: {"Precision": 0.7837837837837838, "Recall": 1.0, "F1": 0.8787878787878788, "AUROC": 1.0}
#
# ### Processing: ./TSB-AD-U/WSD/058_WSD_id_30_WebService_tr_1136_1st_1236.csv
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 1 valF1=0.0060 best=0.0060, bad=0
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 2 valF1=0.1119 best=0.1119, bad=0
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 3 valF1=0.1176 best=0.1176, bad=0
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 4 valF1=0.1600 best=0.1600, bad=0
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 5 valF1=0.1553 best=0.1600, bad=1
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 7 valF1=0.2222 best=0.2222, bad=0
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 10 valF1=0.1455 best=0.2222, bad=3
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 15 valF1=0.2162 best=0.2222, bad=8
# [058_WSD_id_30_WebService_tr_1136_1st_1236.csv] epoch 20 valF1=0.2025 best=0.2222, bad=13
# => Test metrics: {"Precision": 0.1951219512195122, "Recall": 1.0, "F1": 0.32653061224489793, "AUROC": 0.9999241504854369}
#
# ### Processing: ./TSB-AD-U/WSD/059_WSD_id_31_WebService_tr_4559_1st_9058.csv
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 1 valF1=0.0138 best=0.0138, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 2 valF1=0.0538 best=0.0538, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 4 valF1=0.3676 best=0.3676, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 5 valF1=0.3185 best=0.3676, bad=1
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 10 valF1=0.1634 best=0.3676, bad=6
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 13 valF1=0.5051 best=0.5051, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 15 valF1=0.5618 best=0.5618, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 18 valF1=0.5682 best=0.5682, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 20 valF1=0.4000 best=0.5682, bad=2
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 25 valF1=0.6173 best=0.6173, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 30 valF1=0.5319 best=0.6173, bad=5
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 33 valF1=0.6944 best=0.6944, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 35 valF1=0.6757 best=0.6944, bad=2
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 36 valF1=0.7143 best=0.7143, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 38 valF1=0.7353 best=0.7353, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 39 valF1=0.7692 best=0.7692, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 40 valF1=0.7463 best=0.7692, bad=1
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 41 valF1=0.7812 best=0.7812, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 42 valF1=0.7937 best=0.7937, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 44 valF1=0.8065 best=0.8065, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 45 valF1=0.6579 best=0.8065, bad=1
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 46 valF1=0.8333 best=0.8333, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 50 valF1=0.8197 best=0.8333, bad=4
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 55 valF1=0.6944 best=0.8333, bad=9
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 59 valF1=0.8621 best=0.8621, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 60 valF1=0.8333 best=0.8621, bad=1
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 62 valF1=0.8929 best=0.8929, bad=0
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 65 valF1=0.7937 best=0.8929, bad=3
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 70 valF1=0.8333 best=0.8929, bad=8
# [059_WSD_id_31_WebService_tr_4559_1st_9058.csv] epoch 75 valF1=0.8621 best=0.8929, bad=13
# => Test metrics: {"Precision": 0.8928571428571429, "Recall": 1.0, "F1": 0.9433962264150944, "AUROC": 1.0}
#
# ### Processing: ./TSB-AD-U/WSD/060_WSD_id_32_WebService_tr_4576_1st_4766.csv
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 1 valF1=0.0313 best=0.0313, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 2 valF1=0.0355 best=0.0355, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 5 valF1=0.0359 best=0.0359, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 6 valF1=0.0386 best=0.0386, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 9 valF1=0.0459 best=0.0459, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 10 valF1=0.0503 best=0.0503, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 11 valF1=0.0840 best=0.0840, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 13 valF1=0.1047 best=0.1047, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 15 valF1=0.2275 best=0.2275, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 17 valF1=0.3766 best=0.3766, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 18 valF1=0.4143 best=0.4143, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 20 valF1=0.3880 best=0.4143, bad=2
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 24 valF1=0.4427 best=0.4427, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 25 valF1=0.7117 best=0.7117, bad=0
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 30 valF1=0.5395 best=0.7117, bad=5
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 35 valF1=0.6270 best=0.7117, bad=10
# [060_WSD_id_32_WebService_tr_4576_1st_4766.csv] epoch 40 valF1=0.6339 best=0.7117, bad=15
# => Test metrics: {"Precision": 0.7671232876712328, "Recall": 0.5490196078431373, "F1": 0.64, "AUROC": 0.7222083220958937}
#
# ### Processing: ./TSB-AD-U/WSD/061_WSD_id_33_WebService_tr_4559_1st_9722.csv
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 1 valF1=0.0104 best=0.0104, bad=0
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 2 valF1=0.0190 best=0.0190, bad=0
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 3 valF1=0.0222 best=0.0222, bad=0
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 5 valF1=0.0487 best=0.0487, bad=0
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 7 valF1=0.1620 best=0.1620, bad=0
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 10 valF1=0.0420 best=0.1620, bad=3
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 14 valF1=0.2571 best=0.2571, bad=0
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 15 valF1=0.1382 best=0.2571, bad=1
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 20 valF1=0.0560 best=0.2571, bad=6
# [061_WSD_id_33_WebService_tr_4559_1st_9722.csv] epoch 25 valF1=0.1077 best=0.2571, bad=11
# => Test metrics: {"Precision": 0.391304347826087, "Recall": 0.3, "F1": 0.33962264150943394, "AUROC": 0.9784564969255126}
#
# ### Processing: ./TSB-AD-U/WSD/062_WSD_id_34_WebService_tr_3371_1st_3471.csv
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 1 valF1=0.1906 best=0.1906, bad=0
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 4 valF1=0.2227 best=0.2227, bad=0
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 5 valF1=0.2654 best=0.2654, bad=0
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 8 valF1=0.2759 best=0.2759, bad=0
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 10 valF1=0.3395 best=0.3395, bad=0
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 12 valF1=0.5561 best=0.5561, bad=0
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 14 valF1=0.5750 best=0.5750, bad=0
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 15 valF1=0.2749 best=0.5750, bad=1
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 20 valF1=0.2462 best=0.5750, bad=6
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 23 valF1=0.6545 best=0.6545, bad=0
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 25 valF1=0.2362 best=0.6545, bad=2
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 30 valF1=0.3619 best=0.6545, bad=7
# [062_WSD_id_34_WebService_tr_3371_1st_3471.csv] epoch 35 valF1=0.5802 best=0.6545, bad=12
# => Test metrics: {"Precision": 0.5828571428571429, "Recall": 0.6375, "F1": 0.608955223880597, "AUROC": 0.9685952798175346}
#
# ### Processing: ./TSB-AD-U/WSD/063_WSD_id_35_WebService_tr_2290_1st_2390.csv
# [063_WSD_id_35_WebService_tr_2290_1st_2390.csv] epoch 1 valF1=0.0167 best=0.0167, bad=0
# ...
# ./TSB-AD-U/WSD/047_WSD_id_19_WebService_tr_4559_1st_16362.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.2484746243713245}
# ./TSB-AD-U/WSD/048_WSD_id_20_WebService_tr_4559_1st_11813.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.4265332079854007}
# ./TSB-AD-U/WSD/049_WSD_id_21_WebService_tr_4297_1st_7097.csv {"Precision": 0.8333333333333334, "Recall": 0.8064516129032258, "F1": 0.819672131147541, "AUROC": 0.9284055537275103}
# ./TSB-AD-U/WSD/050_WSD_id_22_WebService_tr_4559_1st_12816.csv {"Precision": 0.001949317738791423, "Recall": 1.0, "F1": 0.0038910505836575876, "AUROC": 0.6876228699540805}
# ./TSB-AD-U/WSD/051_WSD_id_23_WebService_tr_3919_1st_5154.csv {"Precision": 0.7441860465116279, "Recall": 0.5333333333333333, "F1": 0.6213592233009708, "AUROC": 0.9126063418406806}
# ./TSB-AD-U/WSD/052_WSD_id_24_WebService_tr_4559_1st_9102.csv {"Precision": 0.42857142857142855, "Recall": 0.08823529411764706, "F1": 0.14634146341463414, "AUROC": 0.10979937218506894}
# ./TSB-AD-U/WSD/053_WSD_id_25_WebService_tr_4559_1st_9198.csv {"Precision": 0.5652173913043478, "Recall": 1.0, "F1": 0.7222222222222222, "AUROC": 0.9999363324971668}
# ./TSB-AD-U/WSD/054_WSD_id_26_WebService_tr_2409_1st_2509.csv {"Precision": 0.6428571428571429, "Recall": 0.5454545454545454, "F1": 0.5901639344262295, "AUROC": 0.9239048925468679}
# ./TSB-AD-U/WSD/055_WSD_id_27_WebService_tr_3768_1st_3868.csv {"Precision": 0.8636363636363636, "Recall": 0.7378640776699029, "F1": 0.7958115183246073, "AUROC": 0.938366138374882}
# ./TSB-AD-U/WSD/056_WSD_id_28_WebService_tr_4559_1st_9689.csv {"Precision": 0.8260869565217391, "Recall": 1.0, "F1": 0.9047619047619048, "AUROC": 0.9999214801286562}
# ./TSB-AD-U/WSD/057_WSD_id_29_WebService_tr_2229_1st_2329.csv {"Precision": 0.7837837837837838, "Recall": 1.0, "F1": 0.8787878787878788, "AUROC": 1.0}
# ./TSB-AD-U/WSD/058_WSD_id_30_WebService_tr_1136_1st_1236.csv {"Precision": 0.1951219512195122, "Recall": 1.0, "F1": 0.32653061224489793, "AUROC": 0.9999241504854369}
# ./TSB-AD-U/WSD/059_WSD_id_31_WebService_tr_4559_1st_9058.csv {"Precision": 0.8928571428571429, "Recall": 1.0, "F1": 0.9433962264150944, "AUROC": 1.0}
# ./TSB-AD-U/WSD/060_WSD_id_32_WebService_tr_4576_1st_4766.csv {"Precision": 0.7671232876712328, "Recall": 0.5490196078431373, "F1": 0.64, "AUROC": 0.7222083220958937}
# ./TSB-AD-U/WSD/061_WSD_id_33_WebService_tr_4559_1st_9722.csv {"Precision": 0.391304347826087, "Recall": 0.3, "F1": 0.33962264150943394, "AUROC": 0.9784564969255126}
# ./TSB-AD-U/WSD/062_WSD_id_34_WebService_tr_3371_1st_3471.csv {"Precision": 0.5828571428571429, "Recall": 0.6375, "F1": 0.608955223880597, "AUROC": 0.9685952798175346}
# ./TSB-AD-U/WSD/063_WSD_id_35_WebService_tr_2290_1st_2390.csv {"Precision": 0.8148148148148148, "Recall": 0.3283582089552239, "F1": 0.46808510638297873, "AUROC": 0.9850919733063059}
# ./TSB-AD-U/WSD/064_WSD_id_36_WebService_tr_4559_1st_10195.csv {"Precision": 0.8333333333333334, "Recall": 1.0, "F1": 0.9090909090909091, "AUROC": 0.9999845397824527}
# ./TSB-AD-U/WSD/065_WSD_id_37_WebService_tr_3451_1st_3551.csv {"Precision": 0.9771428571428571, "Recall": 0.8592964824120602, "F1": 0.9144385026737968, "AUROC": 0.8992083683175872}
# ./TSB-AD-U/WSD/066_WSD_id_38_WebService_tr_3320_1st_3420.csv {"Precision": 0.24896265560165975, "Recall": 0.5357142857142857, "F1": 0.33994334277620397, "AUROC": 0.9671281489378505}
# ./TSB-AD-U/WSD/067_WSD_id_39_WebService_tr_4559_1st_13973.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.9438013692319032}
# ./TSB-AD-U/WSD/068_WSD_id_40_WebService_tr_4549_1st_13322.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.392181261594131}
# ./TSB-AD-U/WSD/069_WSD_id_41_WebService_tr_4548_1st_13988.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.554344819956856}
# ./TSB-AD-U/WSD/070_WSD_id_42_WebService_tr_2102_1st_2202.csv {"Precision": 0.6210526315789474, "Recall": 0.7468354430379747, "F1": 0.6781609195402298, "AUROC": 0.9974731946322162}
# ./TSB-AD-U/WSD/071_WSD_id_43_WebService_tr_3387_1st_3487.csv {"Precision": 0.9594460929772503, "Recall": 0.9260143198090692, "F1": 0.9424338110274472, "AUROC": 0.9621719939314218}
# ./TSB-AD-U/WSD/072_WSD_id_44_WebService_tr_1691_1st_1791.csv {"Precision": 0.9920634920634921, "Recall": 0.6684491978609626, "F1": 0.7987220447284346, "AUROC": 0.8711445811883629}
# ./TSB-AD-U/WSD/073_WSD_id_45_WebService_tr_3392_1st_3492.csv {"Precision": 0.8, "Recall": 0.04477611940298507, "F1": 0.08480565371024736, "AUROC": 0.06759107007336201}
# ./TSB-AD-U/WSD/074_WSD_id_46_WebService_tr_990_1st_1090.csv {"Precision": 0.7420814479638009, "Recall": 0.5655172413793104, "F1": 0.6418786692759295, "AUROC": 0.9083772273898912}
# ./TSB-AD-U/WSD/075_WSD_id_47_WebService_tr_3296_1st_3468.csv {"Precision": 0.7714285714285715, "Recall": 0.7714285714285715, "F1": 0.7714285714285715, "AUROC": 0.9982376829361734}
# ./TSB-AD-U/WSD/076_WSD_id_48_WebService_tr_3821_1st_7083.csv {"Precision": 0.5, "Recall": 1.0, "F1": 0.6666666666666666, "AUROC": 0.9997949979499796}
# ./TSB-AD-U/WSD/077_WSD_id_49_WebService_tr_3310_1st_3716.csv {"Precision": 0.8125, "Recall": 0.6610169491525424, "F1": 0.7289719626168224, "AUROC": 0.769795169672883}
# ./TSB-AD-U/WSD/078_WSD_id_50_WebService_tr_2449_1st_2549.csv {"Precision": 0.7714285714285715, "Recall": 0.7397260273972602, "F1": 0.7552447552447552, "AUROC": 0.9980424079736139}
# ./TSB-AD-U/WSD/079_WSD_id_51_WebService_tr_4559_1st_10672.csv {"Precision": 0.30666666666666664, "Recall": 0.8518518518518519, "F1": 0.45098039215686275, "AUROC": 0.9986031091558729}
# ./TSB-AD-U/WSD/080_WSD_id_52_WebService_tr_1538_1st_1638.csv {"Precision": 0.39436619718309857, "Recall": 0.2916666666666667, "F1": 0.33532934131736525, "AUROC": 0.9146162323081736}
# ./TSB-AD-U/WSD/081_WSD_id_53_WebService_tr_4559_1st_8448.csv {"Precision": 0.695364238410596, "Recall": 0.5147058823529411, "F1": 0.5915492957746479, "AUROC": 0.9799181439249802}
# ./TSB-AD-U/WSD/082_WSD_id_54_WebService_tr_4437_1st_4805.csv {"Precision": 0.9888888888888889, "Recall": 0.6312056737588653, "F1": 0.7705627705627706, "AUROC": 0.9230423332186881}
# ./TSB-AD-U/WSD/083_WSD_id_55_WebService_tr_4599_1st_4863.csv {"Precision": 1.0, "Recall": 0.9951298701298701, "F1": 0.9975589910496339, "AUROC": 0.9999865032315121}
# ./TSB-AD-U/WSD/084_WSD_id_56_WebService_tr_4559_1st_9616.csv {"Precision": 0.9130434782608695, "Recall": 1.0, "F1": 0.9545454545454546, "AUROC": 0.9999841910980073}
# ./TSB-AD-U/WSD/085_WSD_id_57_WebService_tr_780_1st_880.csv {"Precision": 0.7658227848101266, "Recall": 0.5960591133004927, "F1": 0.6703601108033241, "AUROC": 0.9408113398362313}
# ./TSB-AD-U/WSD/086_WSD_id_58_WebService_tr_4436_1st_9529.csv {"Precision": 0.1796875, "Recall": 1.0, "F1": 0.304635761589404, "AUROC": 0.996536147179205}
# ./TSB-AD-U/WSD/087_WSD_id_59_WebService_tr_4559_1st_12600.csv {"Precision": 0.0006441035250029278, "Recall": 1.0, "F1": 0.0012873778453976242, "AUROC": 0.5084664576802508}
# ./TSB-AD-U/WSD/088_WSD_id_60_WebService_tr_4548_1st_5596.csv {"Precision": 0.3939393939393939, "Recall": 0.6610169491525424, "F1": 0.4936708860759494, "AUROC": 0.9687802512391848}
# ./TSB-AD-U/WSD/089_WSD_id_61_WebService_tr_1010_1st_1110.csv {"Precision": 0.8511904761904762, "Recall": 0.5933609958506224, "F1": 0.6992665036674817, "AUROC": 0.9250229711563864}
# ./TSB-AD-U/WSD/090_WSD_id_62_WebService_tr_2281_1st_2381.csv {"Precision": 0.7878787878787878, "Recall": 0.6933333333333334, "F1": 0.7375886524822695, "AUROC": 0.9614210175060321}
# ./TSB-AD-U/WSD/091_WSD_id_63_WebService_tr_500_1st_363.csv {"Precision": 0.7207207207207207, "Recall": 0.5063291139240507, "F1": 0.5947955390334573, "AUROC": 0.8456618171163583}
# ./TSB-AD-U/WSD/092_WSD_id_64_WebService_tr_500_1st_118.csv {"Precision": 0.36, "Recall": 0.627906976744186, "F1": 0.4576271186440678, "AUROC": 0.9670622943320779}
# ./TSB-AD-U/WSD/093_WSD_id_65_WebService_tr_1125_1st_1225.csv {"Precision": 0.8622754491017964, "Recall": 0.8135593220338984, "F1": 0.8372093023255814, "AUROC": 0.8618242951107946}
# ./TSB-AD-U/WSD/094_WSD_id_66_WebService_tr_3309_1st_3914.csv {"Precision": 0.7777777777777778, "Recall": 0.6, "F1": 0.6774193548387096, "AUROC": 0.8379178751335674}
# ./TSB-AD-U/WSD/095_WSD_id_67_WebService_tr_2182_1st_2282.csv {"Precision": 0.6086956521739131, "Recall": 1.0, "F1": 0.7567567567567568, "AUROC": 0.9998659876708658}
# ./TSB-AD-U/WSD/096_WSD_id_68_WebService_tr_1341_1st_1441.csv {"Precision": 0.3103448275862069, "Recall": 0.5454545454545454, "F1": 0.3956043956043956, "AUROC": 0.9716646247604687}
# ./TSB-AD-U/WSD/097_WSD_id_69_WebService_tr_4520_1st_6465.csv {"Precision": 0.6666666666666666, "Recall": 0.5, "F1": 0.5714285714285714, "AUROC": 0.7597071388391975}
# ./TSB-AD-U/WSD/098_WSD_id_70_WebService_tr_3575_1st_3675.csv {"Precision": 0.024, "Recall": 0.3333333333333333, "F1": 0.04477611940298507, "AUROC": 0.6621981942222467}
# ./TSB-AD-U/WSD/099_WSD_id_71_WebService_tr_4559_1st_14411.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.5215225874281402}
# ./TSB-AD-U/WSD/100_WSD_id_72_WebService_tr_4559_1st_10254.csv {"Precision": 0.8048780487804879, "Recall": 0.66, "F1": 0.7252747252747253, "AUROC": 0.9627413468981534}
# ./TSB-AD-U/WSD/101_WSD_id_73_WebService_tr_1513_1st_1613.csv {"Precision": 0.4797297297297297, "Recall": 1.0, "F1": 0.6484018264840182, "AUROC": 0.9992920712762597}
# ./TSB-AD-U/WSD/102_WSD_id_74_WebService_tr_3306_1st_3639.csv {"Precision": 0.575, "Recall": 0.7931034482758621, "F1": 0.6666666666666666, "AUROC": 0.9990811969187189}
# ./TSB-AD-U/WSD/103_WSD_id_75_WebService_tr_1375_1st_1475.csv {"Precision": 0.9239130434782609, "Recall": 0.794392523364486, "F1": 0.8542713567839196, "AUROC": 0.9309965033874085}
# ./TSB-AD-U/WSD/104_WSD_id_76_WebService_tr_3047_1st_3147.csv {"Precision": 0.7956989247311828, "Recall": 0.578125, "F1": 0.669683257918552, "AUROC": 0.8309140222474238}
# ./TSB-AD-U/WSD/105_WSD_id_77_WebService_tr_2348_1st_2448.csv {"Precision": 0.6666666666666666, "Recall": 0.6666666666666666, "F1": 0.6666666666666666, "AUROC": 0.8927588585203109}
# ./TSB-AD-U/WSD/106_WSD_id_78_WebService_tr_3363_1st_3463.csv {"Precision": 0.08419314898885678, "Recall": 0.9230769230769231, "F1": 0.15431164901664146, "AUROC": 0.9020000176802725}
# ./TSB-AD-U/WSD/107_WSD_id_79_WebService_tr_1095_1st_1195.csv {"Precision": 0.8072625698324022, "Recall": 0.8865030674846626, "F1": 0.8450292397660819, "AUROC": 0.9447756309786671}
# ./TSB-AD-U/WSD/108_WSD_id_80_WebService_tr_2368_1st_2468.csv {"Precision": 0.797979797979798, "Recall": 0.40932642487046633, "F1": 0.541095890410959, "AUROC": 0.7990535016652163}
# ./TSB-AD-U/WSD/109_WSD_id_81_WebService_tr_3175_1st_3275.csv {"Precision": 0.07828282828282829, "Recall": 0.47692307692307695, "F1": 0.13449023861171366, "AUROC": 0.8475063303655491}
# ./TSB-AD-U/WSD/110_WSD_id_82_WebService_tr_500_1st_375.csv {"Precision": 0.9704142011834319, "Recall": 0.9010989010989011, "F1": 0.9344729344729344, "AUROC": 0.9966376221528277}
# ./TSB-AD-U/WSD/111_WSD_id_83_WebService_tr_3934_1st_7531.csv {"Precision": 0.008620689655172414, "Recall": 1.0, "F1": 0.017094017094017096, "AUROC": 0.9817693341009404}
# ./TSB-AD-U/WSD/112_WSD_id_84_WebService_tr_2442_1st_2542.csv {"Precision": 0.7674418604651163, "Recall": 0.5238095238095238, "F1": 0.6226415094339622, "AUROC": 0.7790682172852673}
# ./TSB-AD-U/WSD/113_WSD_id_85_WebService_tr_500_1st_335.csv {"Precision": 0.6564885496183206, "Recall": 0.7610619469026548, "F1": 0.7049180327868853, "AUROC": 0.9202091811766392}
# ./TSB-AD-U/WSD/114_WSD_id_86_WebService_tr_500_1st_403.csv {"Precision": 0.8390804597701149, "Recall": 0.8795180722891566, "F1": 0.8588235294117647, "AUROC": 0.9361258989446156}
# ./TSB-AD-U/WSD/115_WSD_id_87_WebService_tr_2252_1st_2352.csv {"Precision": 0.34523809523809523, "Recall": 0.48066298342541436, "F1": 0.4018475750577367, "AUROC": 0.8962870697652064}
# ./TSB-AD-U/WSD/116_WSD_id_88_WebService_tr_3934_1st_13861.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.6165824323459791}
# ./TSB-AD-U/WSD/117_WSD_id_89_WebService_tr_3251_1st_3351.csv {"Precision": 0.016574585635359115, "Recall": 1.0, "F1": 0.03260869565217391, "AUROC": 0.9900243757553412}
# ./TSB-AD-U/WSD/118_WSD_id_90_WebService_tr_4559_1st_6317.csv {"Precision": 1.0, "Recall": 1.0, "F1": 1.0, "AUROC": 1.0}
# ./TSB-AD-U/WSD/119_WSD_id_91_WebService_tr_4559_1st_12353.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.5327068182261303}
# ./TSB-AD-U/WSD/120_WSD_id_92_WebService_tr_2329_1st_2429.csv {"Precision": 0.7529411764705882, "Recall": 0.6736842105263158, "F1": 0.7111111111111111, "AUROC": 0.8437816108443701}
# ./TSB-AD-U/WSD/121_WSD_id_93_WebService_tr_4559_1st_11749.csv {"Precision": 0.0023709748566387297, "Recall": 1.0, "F1": 0.004730733263655867, "AUROC": 0.3218416733183462}
# ./TSB-AD-U/WSD/122_WSD_id_94_WebService_tr_4559_1st_8618.csv {"Precision": 0.7236842105263158, "Recall": 0.9821428571428571, "F1": 0.8333333333333334, "AUROC": 0.9997432048040455}
# ./TSB-AD-U/WSD/123_WSD_id_95_WebService_tr_4559_1st_4901.csv {"Precision": 0.3103448275862069, "Recall": 0.5, "F1": 0.3829787234042553, "AUROC": 0.9786203192142419}
# ./TSB-AD-U/WSD/124_WSD_id_96_WebService_tr_4559_1st_14350.csv {"Precision": 0.0, "Recall": 0.0, "F1": 0.0, "AUROC": 0.5006344477546067}
# ./TSB-AD-U/WSD/125_WSD_id_97_WebService_tr_2217_1st_2317.csv {"Precision": 0.8095238095238095, "Recall": 0.5246913580246914, "F1": 0.6367041198501873, "AUROC": 0.8499514079345079}
# ./TSB-AD-U/WSD/126_WSD_id_98_WebService_tr_657_1st_757.csv {"Precision": 0.6432160804020101, "Recall": 0.5079365079365079, "F1": 0.5676274944567627, "AUROC": 0.8184293072183634}
# ./TSB-AD-U/WSD/127_WSD_id_99_WebService_tr_1164_1st_1264.csv {"Precision": 0.768595041322314, "Recall": 0.7948717948717948, "F1": 0.7815126050420168, "AUROC": 0.9850250209121851}
# ./TSB-AD-U/WSD/128_WSD_id_100_WebService_tr_4068_1st_4168.csv {"Precision": 0.5821428571428572, "Recall": 0.815, "F1": 0.6791666666666667, "AUROC": 0.9953870706958073}
# ./TSB-AD-U/WSD/129_WSD_id_101_WebService_tr_4448_1st_9592.csv {"Precision": 0.48, "Recall": 0.6, "F1": 0.5333333333333333, "AUROC": 0.9984921353400475}
# ./TSB-AD-U/WSD/130_WSD_id_102_WebService_tr_2362_1st_2462.csv {"Precision": 0.6859504132231405, "Recall": 0.8512820512820513, "F1": 0.7597254004576659, "AUROC": 0.9826794092888514}
# ./TSB-AD-U/WSD/131_WSD_id_103_WebService_tr_4573_1st_7021.csv {"Precision": 0.11711711711711711, "Recall": 1.0, "F1": 0.20967741935483872, "AUROC": 0.9949313103705051}
# ./TSB-AD-U/WSD/132_WSD_id_104_WebService_tr_4037_1st_4137.csv {"Precision": 0.775, "Recall": 0.6739130434782609, "F1": 0.7209302325581395, "AUROC": 0.9428521642992765}
# ./TSB-AD-U/WSD/133_WSD_id_105_WebService_tr_3934_1st_5937.csv {"Precision": 1.0, "Recall": 0.6666666666666666, "F1": 0.8, "AUROC": 0.98864349273414}
# ./TSB-AD-U/WSD/134_WSD_id_106_WebService_tr_4559_1st_7990.csv {"Precision": 0.9789473684210527, "Recall": 0.8773584905660378, "F1": 0.9253731343283582, "AUROC": 0.9970787680909177}
# ./TSB-AD-U/WSD/135_WSD_id_107_WebService_tr_3779_1st_3879.csv {"Precision": 0.527027027027027, "Recall": 0.78, "F1": 0.6290322580645161, "AUROC": 0.998549101328471}
# ./TSB-AD-U/WSD/136_WSD_id_108_WebService_tr_3414_1st_3514.csv {"Precision": 0.7291666666666666, "Recall": 0.7650273224043715, "F1": 0.7466666666666667, "AUROC": 0.9202571742427632}
# ./TSB-AD-U/WSD/137_WSD_id_109_WebService_tr_4559_1st_14404.csv {"Precision": 0.00014058765640376775, "Recall": 0.01694915254237288, "F1": 0.0002788622420524261, "AUROC": 0.4042837466468769}
# ./TSB-AD-U/WSD/138_WSD_id_110_WebService_tr_4584_1st_6039.csv {"Precision": 0.5909090909090909, "Recall": 1.0, "F1": 0.7428571428571429, "AUROC": 0.9999746727508347}
# ./TSB-AD-U/WSD/139_WSD_id_111_WebService_tr_1701_1st_1801.csv {"Precision": 0.5833333333333334, "Recall": 0.40229885057471265, "F1": 0.47619047619047616, "AUROC": 0.8126501221193294}
#
# # Macro mean (simple average over files)
# {"Precision": 0.5363944403641522, "Recall": 0.6458945549227514, "F1": 0.52191942263982, "AUROC": 0.8694419351897683}
